# %%
import os
import time
#mysys="jupyter" #
mysys="colab"
split="_90_5_5b_"
sn='sn_'
test_ratio=0.05

training_samples=167400
testing_samples=9300
validation_samples=9300

if mysys=="colab":
    from google.colab import drive
    drive.mount('/content/drive')
    in_path='/content/drive/MyDrive/UNSW_Data/'
    datapath='/content/drive/MyDrive/ANN_Edge/unsw_data/final4/'
    modelpath='/content/drive/MyDrive/ANN_Edge/unsw_data/final4/models14003/'
    slash="/"
    ML_path=datapath+'ml2/'
    STDN_path=ML_path+ '/ml/stdn/'
else:
    current_folder = os.getcwd() + kkk
    print(current_folder)
    slash="\\"
    path=current_folder.replace('Model_05', "") + 'ANN_Edge\\final\\'
    print(path)
    ML_path=current_folder.replace('Model_05', "") + 'ANN_Edge\\final\ml\\'
    STDN_path=current_folder.replace('Model_05', "") + 'ANN_Edge\\final\ml\stdn\\'

print(in_path)
print(datapath)
performance_metrics=[]
hp_array=[]

in_f_train= in_path + 'UNSW_NB15_training-set.csv'
in_f_test=in_path+'UNSW_NB15_testing-set.csv'
f_features=in_path+ 'UNSW_NB15_f.csv'
out_f_train=datapath+'unsw-nb15_training' + split +'.csv'
out_f_test=datapath+'unsw-nb15_testing' + split+ '.csv'
out_f_validation=datapath+'unsw-nb15_validation' + split+ '.csv'

shallow_model_path=modelpath+ 'shallow_model_ANN5.keras'
deep_model_path=modelpath+ 'deep_model_ANN5.keras'

shallow_model_path_best_hp=modelpath+ 'shallow_model_ANN5_hp.keras'
deep_model_path_best_hp=modelpath+ 'deep_model_ANN5_hp.keras'

in_f_features=in_path + 'UNSW_NB15_f.csv'

f_performance_path=modelpath+ 'cp2_data_performance.csv'
f_hp_path=modelpath+ 'cp2_hp.csv'


print(in_f_train)
print(in_f_test)
print(in_f_features)
print(out_f_train)
print(out_f_test)
print(out_f_validation)
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/UNSW_Data/
# /content/drive/MyDrive/ANN_Edge/unsw_data/final4/
# /content/drive/MyDrive/UNSW_Data/UNSW_NB15_training-set.csv
# /content/drive/MyDrive/UNSW_Data/UNSW_NB15_testing-set.csv
# /content/drive/MyDrive/UNSW_Data/UNSW_NB15_f.csv
# /content/drive/MyDrive/ANN_Edge/unsw_data/final4/unsw-nb15_training_90_5_5b_.csv
# /content/drive/MyDrive/ANN_Edge/unsw_data/final4/unsw-nb15_testing_90_5_5b_.csv
# /content/drive/MyDrive/ANN_Edge/unsw_data/final4/unsw-nb15_validation_90_5_5b_.csv

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Define the features
features = ['ct_state_ttl', 'sload', 'rate', 'sttl', 'smean', 'dload', 'sbytes', 'ct_srv_dst', 'ct_dst_src_ltm', 'dbytes', 'ackdat', 'dttl', 'ct_dst_sport_ltm', 'dmean','ct_srv_src', 'dinpkt', 'tcprtt', 'dur', 'synack', 'sinpkt']
#features2= ['ct_state_ttl', 'sload', 'rate', 'sttl', 'smean', 'dload', 'sbytes', 'ct_srv_dst', 'ct_dst_src_ltm', 'dbytes', 'ackdat', 'dttl', 'ct_dst_sport_ltm', 'dmean', 'ct_srv_src', 'dinpkt', 'tcprtt', 'dur', 'synack', 'sinpkt'], 'proto', 'dport', 'stime']

# Load preprocessed data for training and testing
df_train = pd.read_csv(out_f_train)
df_test = pd.read_csv(out_f_test)
df_val = pd.read_csv(out_f_validation)
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167400 entries, 0 to 167399
# Data columns (total 45 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 167400 non-null  int64
#  1   dur                167400 non-null  float64
#  2   proto              167400 non-null  object
#  3   service            167400 non-null  object
#  4   state              167400 non-null  object
#  5   spkts              167400 non-null  int64
#  6   dpkts              167400 non-null  int64
#  7   sbytes             167400 non-null  int64
#  8   dbytes             167400 non-null  int64
#  9   rate               167400 non-null  float64
#  10  sttl               167400 non-null  int64
#  11  dttl               167400 non-null  int64
#  12  sload              167400 non-null  float64
#  13  dload              167400 non-null  float64
#  14  sloss              167400 non-null  int64
#  15  dloss              167400 non-null  int64
#  16  sinpkt             167400 non-null  float64
#  17  dinpkt             167400 non-null  float64
#  18  sjit               167400 non-null  float64
#  19  djit               167400 non-null  float64
#  20  swin               167400 non-null  int64
#  21  stcpb              167400 non-null  int64
#  22  dtcpb              167400 non-null  int64
#  23  dwin               167400 non-null  int64
#  24  tcprtt             167400 non-null  float64
#  25  synack             167400 non-null  float64
#  26  ackdat             167400 non-null  float64
#  27  smean              167400 non-null  int64
#  28  dmean              167400 non-null  int64
#  29  trans_depth        167400 non-null  int64
#  30  response_body_len  167400 non-null  int64
#  31  ct_srv_src         167400 non-null  int64
#  32  ct_state_ttl       167400 non-null  int64
#  33  ct_dst_ltm         167400 non-null  int64
#  34  ct_src_dport_ltm   167400 non-null  int64
#  35  ct_dst_sport_ltm   167400 non-null  int64
#  36  ct_dst_src_ltm     167400 non-null  int64
#  37  is_ftp_login       167400 non-null  int64
#  38  ct_ftp_cmd         167400 non-null  int64
#  39  ct_flw_http_mthd   167400 non-null  int64
#  40  ct_src_ltm         167400 non-null  int64
#  41  ct_srv_dst         167400 non-null  int64
#  42  is_sm_ips_ports    167400 non-null  int64
#  43  attack_cat         167400 non-null  object
#  44  label              167400 non-null  int64
# dtypes: float64(11), int64(30), object(4)
# memory usage: 57.5+ MB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9300 entries, 0 to 9299
# Data columns (total 45 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 9300 non-null   int64
#  1   dur                9300 non-null   float64
#  2   proto              9300 non-null   object
#  3   service            9300 non-null   object
#  4   state              9300 non-null   object
#  5   spkts              9300 non-null   int64
#  6   dpkts              9300 non-null   int64
#  7   sbytes             9300 non-null   int64
#  8   dbytes             9300 non-null   int64
#  9   rate               9300 non-null   float64
#  10  sttl               9300 non-null   int64
#  11  dttl               9300 non-null   int64
#  12  sload              9300 non-null   float64
#  13  dload              9300 non-null   float64
#  14  sloss              9300 non-null   int64
#  15  dloss              9300 non-null   int64
#  16  sinpkt             9300 non-null   float64
#  17  dinpkt             9300 non-null   float64
#  18  sjit               9300 non-null   float64
#  19  djit               9300 non-null   float64
#  20  swin               9300 non-null   int64
#  21  stcpb              9300 non-null   int64
#  22  dtcpb              9300 non-null   int64
#  23  dwin               9300 non-null   int64
#  24  tcprtt             9300 non-null   float64
#  25  synack             9300 non-null   float64
#  26  ackdat             9300 non-null   float64
#  27  smean              9300 non-null   int64
#  28  dmean              9300 non-null   int64
#  29  trans_depth        9300 non-null   int64
#  30  response_body_len  9300 non-null   int64
#  31  ct_srv_src         9300 non-null   int64
#  32  ct_state_ttl       9300 non-null   int64
#  33  ct_dst_ltm         9300 non-null   int64
#  34  ct_src_dport_ltm   9300 non-null   int64
#  35  ct_dst_sport_ltm   9300 non-null   int64
#  36  ct_dst_src_ltm     9300 non-null   int64
#  37  is_ftp_login       9300 non-null   int64
#  38  ct_ftp_cmd         9300 non-null   int64
#  39  ct_flw_http_mthd   9300 non-null   int64
#  40  ct_src_ltm         9300 non-null   int64
#  41  ct_srv_dst         9300 non-null   int64
#  42  is_sm_ips_ports    9300 non-null   int64
#  43  attack_cat         9300 non-null   object
#  44  label              9300 non-null   int64
# dtypes: float64(11), int64(30), object(4)
# memory usage: 3.2+ MB

# %%
df_val.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9300 entries, 0 to 9299
# Data columns (total 45 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 9300 non-null   int64
#  1   dur                9300 non-null   float64
#  2   proto              9300 non-null   object
#  3   service            9300 non-null   object
#  4   state              9300 non-null   object
#  5   spkts              9300 non-null   int64
#  6   dpkts              9300 non-null   int64
#  7   sbytes             9300 non-null   int64
#  8   dbytes             9300 non-null   int64
#  9   rate               9300 non-null   float64
#  10  sttl               9300 non-null   int64
#  11  dttl               9300 non-null   int64
#  12  sload              9300 non-null   float64
#  13  dload              9300 non-null   float64
#  14  sloss              9300 non-null   int64
#  15  dloss              9300 non-null   int64
#  16  sinpkt             9300 non-null   float64
#  17  dinpkt             9300 non-null   float64
#  18  sjit               9300 non-null   float64
#  19  djit               9300 non-null   float64
#  20  swin               9300 non-null   int64
#  21  stcpb              9300 non-null   int64
#  22  dtcpb              9300 non-null   int64
#  23  dwin               9300 non-null   int64
#  24  tcprtt             9300 non-null   float64
#  25  synack             9300 non-null   float64
#  26  ackdat             9300 non-null   float64
#  27  smean              9300 non-null   int64
#  28  dmean              9300 non-null   int64
#  29  trans_depth        9300 non-null   int64
#  30  response_body_len  9300 non-null   int64
#  31  ct_srv_src         9300 non-null   int64
#  32  ct_state_ttl       9300 non-null   int64
#  33  ct_dst_ltm         9300 non-null   int64
#  34  ct_src_dport_ltm   9300 non-null   int64
#  35  ct_dst_sport_ltm   9300 non-null   int64
#  36  ct_dst_src_ltm     9300 non-null   int64
#  37  is_ftp_login       9300 non-null   int64
#  38  ct_ftp_cmd         9300 non-null   int64
#  39  ct_flw_http_mthd   9300 non-null   int64
#  40  ct_src_ltm         9300 non-null   int64
#  41  ct_srv_dst         9300 non-null   int64
#  42  is_sm_ips_ports    9300 non-null   int64
#  43  attack_cat         9300 non-null   object
#  44  label              9300 non-null   int64
# dtypes: float64(11), int64(30), object(4)
# memory usage: 3.2+ MB

# %%
# Separate features and labels for training set
X_train = df_train[features].values # assuming 'label' is the column containing labels
y_train = df_train['label'].values

# Separate features and labels for testing set
X_test = df_test[features].values  # assuming 'label' is the column containing labels
y_test = df_test['label'].values

# Separate features and labels for testing set
X_val =df_val[features].values  # assuming 'label' is the column containing labels
y_val =df_val['label'].values

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape,y_val.shape)
print(X_train.shape[0]/(X_train.shape[0]+ X_test.shape[0]))
print(X_test.shape[0]/(X_test.shape[0]+ X_test.shape[0]))
print(X_val.shape[0]/(X_val.shape[0]+ X_val.shape[0]))
# Out:
# (167400, 20) (167400,) (9300, 20) (9300,) (9300, 20) (9300,)
# 0.9473684210526315
# 0.5
# 0.5

# %%
# Standardize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_val = scaler.transform(X_val)

# %%
import time
import psutil
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, average_precision_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.metrics import confusion_matrix


def get_system_info():
    # Get CPU and memory usage
    cpu_usage = psutil.cpu_percent()
    memory_usage = psutil.virtual_memory().percent
    return cpu_usage, memory_usage

# Define function to calculate training and testing time
def calculate_time(start_time):
    end_time = time.time()
    elapsed_time = end_time - start_time
    return elapsed_time

def evaluate_performance(title, test_loss, test_accuracy, y_test, y_preds, cpu_use, mem_use, training_time, test_time,  prt):
    #accuracy = accuracy_score(y_test, y_preds)
    precision = precision_score(y_test, y_preds)
    recall = recall_score(y_test, y_preds)
    f1 = f1_score(y_test, y_preds)
    roc_auc = roc_auc_score(y_test, y_preds)
    avg_precision = average_precision_score(y_test, y_preds)
    conf_matrix = confusion_matrix(y_test, y_preds)

    metrics ={
        'data': title,
        'time': time.time(),
        'Training time':  training_time,
        'test time':test_time,
        'memory usage':mem_use,
        'cpu usage': cpu_use,
        'accuracy': test_accuracy,
        'loss' :test_loss,
        'precision':  precision,
        'recall' : recall,
        'f1_score':   f1,
        'roc_auc' :roc_auc,
        'avg_precision':avg_precision,
        'conf_matrix':  conf_matrix,
    }

    if prt == 1:
        print(title, "Model Performance: ")
        print ('Training time',  training_time)
        print ('Testing time',  test_time)
        print ('Memory Usage', mem_use)
        print ('CPU usage', cpu_use)
        print("Test Accuracy:", test_accuracy)
        print("Test Loss:", test_loss)
        print("Precision:", precision)
        print("Recall:", recall)
        print("F1-score:", f1)
        print("roc_auc", roc_auc)
        print("avg_precision",avg_precision)
        print("Confusion Matrix:")
        print(conf_matrix)

    return metrics

# Define function to display performance metrics
def display_metrics(test_loss, test_accuracy, val_accuracy, precision, recall, f1, roc_auc, avg_precision):
    print("Test Loss:", test_loss)
    print("Test Accuracy:", test_accuracy)
    print("Validation Accuracy:", val_accuracy)
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1 Score:", f1)
    print("ROC-AUC Score:", roc_auc)
    print("Average Precision Score:", avg_precision)

# %% [markdown]
# ## Shallow *ANN* Model

# %%
# Define Shallow model hyperparameters
shallow_hyperparameters = {
    'input_dim': len(features),
    'neurons_layer1': 512,
    'activation_layer1': 'relu',
    'learning_rate': 0.0001
}

# Define paths and model name
modelpath = shallow_model_path
model_name = 'shallow_model_ANN'

# %%
from sklearn.metrics import confusion_matrix
# Define shallow ANN model function
def create_shallow_ann_model(input_dim, neurons_layer1, activation_layer1, learning_rate):
    model = Sequential()

    # hidden layer 1
    model.add(Dense(neurons_layer1, input_dim=input_dim, activation=activation_layer1))

    # Output layer
    model.add(Dense(1, activation='sigmoid'))

    # Compile model
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    return model


# Create the shallow ANN model with the best hyperparameters
start_time = time.time()
shallow_model = create_shallow_ann_model(**shallow_hyperparameters)
train_time = calculate_time(start_time)

# Train the model on the training data
start_time = time.time()
history = shallow_model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2)
cpu_usage, memory_usage=get_system_info()
train_time += calculate_time(start_time)

# Evaluate the model on the test set
start_time = time.time()
test_loss, test_accuracy = shallow_model.evaluate(X_test, y_test)
test_time = calculate_time(start_time)

# Calculate additional performance metrics on the validation set
y_pred_val = shallow_model.predict(X_test)

val_accuracy = accuracy_score(y_test, np.round(y_pred_val))
precision = precision_score(y_test, np.round(y_pred_val))
recall = recall_score(y_test, np.round(y_pred_val))
f1 = f1_score(y_test, np.round(y_pred_val))
roc_auc = roc_auc_score(y_test, y_pred_val)
avg_precision = average_precision_score(y_test, y_pred_val)
# Calculate the confusion matrix
conf_matrix = confusion_matrix(y_test, np.round(y_pred_val))

# Display performance metrics
display_metrics(test_loss, test_accuracy, val_accuracy, precision, recall, f1, roc_auc, avg_precision)
summary=shallow_model.summary()
print(summary)

# Save the trained model for inference
#joblib.dump(shallow_model, modelpath)
tf.keras.models.save_model(shallow_model, modelpath)
# Collect memory usage, CPU usage, and append to an array
metrics = {
    'Time':time.time(),
    'Model': model_name,
    'Training Time': train_time,
    'Testing Time': test_time,
    'Memory Usage': memory_usage,
    'CPU Usage': cpu_usage,
    'Test Loss': test_loss,
    'Test Accuracy': test_accuracy,
    'Validation Accuracy': val_accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1 Score': f1,
    'ROC-AUC Score': roc_auc,
    'Average Precision Score': avg_precision,
    "Confusion Matrix" : conf_matrix
}
# Out:
# Epoch 1/20
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.2688 - accuracy: 0.8716 - val_loss: 0.2242 - val_accuracy: 0.8896
# Epoch 2/20
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.2119 - accuracy: 0.8948 - val_loss: 0.2056 - val_accuracy: 0.8971
# Epoch 3/20
# 4185/4185 [==============================] - 8s 2ms/step - loss: 0.1990 - accuracy: 0.8997 - val_loss: 0.1966 - val_accuracy: 0.9012
# Epoch 4/20
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1913 - accuracy: 0.9056 - val_loss: 0.1908 - val_accuracy: 0.9038
# Epoch 5/20
# 4185/4185 [==============================] - 8s 2ms/step - loss: 0.1860 - accuracy: 0.9093 - val_loss: 0.1851 - val_accuracy: 0.9114
# Epoch 6/20
# 4185/4185 [==============================] - 8s 2ms/step - loss: 0.1820 - accuracy: 0.9124 - val_loss: 0.1821 - val_accuracy: 0.9117
# Epoch 7/20
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1789 - accuracy: 0.9140 - val_loss: 0.1791 - val_accuracy: 0.9150
# Epoch 8/20
# 4185/4185 [==============================] - 8s 2ms/step - loss: 0.1763 - accuracy: 0.9156 - val_loss: 0.1770 - val_accuracy: 0.9172
# Epoch 9/20
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1744 - accuracy: 0.9171 - val_loss: 0.1756 - val_accuracy: 0.9163
# Epoch 10/20
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1726 - accuracy: 0.9181 - val_loss: 0.1732 - val_accuracy: 0.9188
# Epoch 11/20
# 4185/4185 [==============================] - 8s 2ms/step - loss: 0.1709 - accuracy: 0.9189 - val_loss: 0.1717 - val_accuracy: 0.9203
# Epoch 12/20
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1699 - accuracy: 0.9202 - val_loss: 0.1699 - val_accuracy: 0.9217
# Epoch 13/20
# 4185/4185 [==============================] - 8s 2ms/step - loss: 0.1687 - accuracy: 0.9207 - val_loss: 0.1692 - val_accuracy: 0.9202
# Epoch 14/20
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1675 - accuracy: 0.9210 - val_loss: 0.1689 - val_accuracy: 0.9210
# Epoch 15/20
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1666 - accuracy: 0.9217 - val_loss: 0.1675 - val_accuracy: 0.9195
# Epoch 16/20
# 4185/4185 [==============================] - 8s 2ms/step - loss: 0.1657 - accuracy: 0.9221 - val_loss: 0.1664 - val_accuracy: 0.9217
# Epoch 17/20
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1650 - accuracy: 0.9224 - val_loss: 0.1668 - val_accuracy: 0.9212
# Epoch 18/20
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1643 - accuracy: 0.9228 - val_loss: 0.1651 - val_accuracy: 0.9226
# Epoch 19/20
# 4185/4185 [==============================] - 8s 2ms/step - loss: 0.1636 - accuracy: 0.9234 - val_loss: 0.1641 - val_accuracy: 0.9227
# Epoch 20/20
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1630 - accuracy: 0.9238 - val_loss: 0.1647 - val_accuracy: 0.9219
# 291/291 [==============================] - 1s 2ms/step - loss: 0.1577 - accuracy: 0.9280
# 291/291 [==============================] - 1s 2ms/step
# Test Loss: 0.15767952799797058
# Test Accuracy: 0.9279569983482361
# Validation Accuracy: 0.9279569892473118
# Precision: 0.945389435989257
# Recall: 0.9083870967741936
# F1 Score: 0.926518973459092
# ROC-AUC Score: 0.9841405017921148
# Average Precision Score: 0.9849527651001276
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               10752
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 11265 (44.00 KB)
# Trainable params: 11265 (44.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
import matplotlib.pyplot as plt

# Create a figure with subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plot accuracy
axes[0].plot(history.history['accuracy'], label='Training Accuracy')
axes[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
axes[0].set_title('Model Accuracy')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Plot loss
axes[1].plot(history.history['loss'], label='Training Loss')
axes[1].plot(history.history['val_loss'], label='Validation Loss')
axes[1].set_title('Model Loss')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

# Calculate ROC curve
fpr, tpr, thresholds_roc = roc_curve(y_test, y_pred_val)
roc_auc = auc(fpr, tpr)

# Calculate Precision-Recall curve
precision, recall, thresholds_pr = precision_recall_curve(y_test, y_pred_val)
average_precision = average_precision_score(y_test, y_pred_val)

# Plot ROC curve and Precision-Recall curve as subplots
plt.figure(figsize=(15, 6))

# Plot ROC curve
plt.subplot(1, 2, 1)
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) - Shallow Model')
plt.legend(loc="lower right")

# Plot Precision-Recall curve
plt.subplot(1, 2, 2)
plt.plot(recall, precision, color='blue', lw=2, label='Precision-Recall curve (AP = %0.2f)' % average_precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

plt.tight_layout()
plt.show()

# %%
#Append the metrics to an array
performance_metrics.append(metrics)

# Convert performance_metrics array to DataFrame
df_performance_data = pd.DataFrame(performance_metrics)
# Display the DataFrame
print(df_performance_data)
# Out:
#            Time              Model  Training Time  Testing Time  Memory Usage  \
# 0  1.712164e+09  shallow_model_ANN     202.791085      0.688525          12.8
#
#    CPU Usage  Test Loss  Test Accuracy  Validation Accuracy  Precision  \
# 0       40.7    0.15768       0.927957             0.927957   0.945389
#
#      Recall  F1 Score  ROC-AUC Score  Average Precision Score  \
# 0  0.908387  0.926519       0.984141                 0.984953
#
#              Confusion Matrix
# 0  [[4406, 244], [426, 4224]]

# %% [markdown]
# ## Deep Model ANN

# %%
# Define deep model hyperparameters
deep_hyperparameters = {
    'input_dim': len(features),
    'neurons_layer1': 256,
    'activation_layer1': 'relu',
    'neurons_layer2': 128,
    'activation_layer2': 'relu',
    'neurons_layer3': 64,
    'activation_layer3': 'relu',
    'neurons_layer4': 32,
    'activation_layer4': 'relu',
    'neurons_layer5': 16,
    'activation_layer5': 'relu',
    'neurons_layer6': 8,
    'activation_layer6': 'relu',
    'neurons_layer7': 4,
    'activation_layer7': 'relu',
    'learning_rate': 0.0001
}

# Define paths and model name
modelpath = deep_model_path
model_name = 'deep_model_ANN'

# %%
def create_deep_ann_model(input_dim, neurons_layer1, activation_layer1, neurons_layer2, activation_layer2, neurons_layer3, activation_layer3,
                          neurons_layer4, activation_layer4, neurons_layer5, activation_layer5, neurons_layer6, activation_layer6,
                          neurons_layer7, activation_layer7, learning_rate):
    model = Sequential()

    # Hidden layer 1
    model.add(Dense(neurons_layer1, input_dim=input_dim, activation=activation_layer1))

    # Hidden layer 2
    model.add(Dense(neurons_layer2, activation=activation_layer2))

    # Hidden layer 3
    model.add(Dense(neurons_layer3, activation=activation_layer3))

    # Hidden layer 4
    model.add(Dense(neurons_layer4, activation=activation_layer4))

    # Hidden layer 5
    model.add(Dense(neurons_layer5, activation=activation_layer5))

    # Hidden layer 6
    model.add(Dense(neurons_layer6, activation=activation_layer6))

    # Hidden layer 7
    model.add(Dense(neurons_layer7, activation=activation_layer7))

    # Output layer
    model.add(Dense(1, activation='sigmoid'))

    # Compile model
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    return model

# Create the deep ANN model with the best hyperparameters
start_time = time.time()
deep_model = create_deep_ann_model(**deep_hyperparameters)
train_time = calculate_time(start_time)

# Train the model on the training data
start_time = time.time()
history = deep_model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2)
train_time += calculate_time(start_time)
cpu_usage, memory_usage=get_system_info()

# Evaluate the model on the test set
start_time = time.time()
test_loss, test_accuracy = deep_model.evaluate(X_test, y_test)
test_time = calculate_time(start_time)

# Calculate additional performance metrics on the validation set
y_pred_val = deep_model.predict(X_test)
val_accuracy = accuracy_score(y_test, np.round(y_pred_val))
precision = precision_score(y_test, np.round(y_pred_val))
recall = recall_score(y_test, np.round(y_pred_val))
f1 = f1_score(y_test, np.round(y_pred_val))
roc_auc = roc_auc_score(y_test, y_pred_val)
avg_precision = average_precision_score(y_test, y_pred_val)

# Calculate the confusion matrix
conf_matrix = confusion_matrix(y_test, np.round(y_pred_val))

# Display performance metrics
display_metrics(test_loss, test_accuracy, val_accuracy, precision, recall, f1, roc_auc, avg_precision)

summary=deep_model.summary()
print(summary)

# Save the trained model for inference
#tf.keras.models.save_model(deep_model, modelpath)


# Collect memory usage, CPU usage, and append to an array
metrics = {
    'Time':time.time(),
    'Model': model_name,
    'Training Time': train_time,
    'Testing Time': test_time,
    'Memory Usage': memory_usage,
    'CPU Usage': cpu_usage,
    'Test Loss': test_loss,
    'Test Accuracy': test_accuracy,
    'Validation Accuracy': val_accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1 Score': f1,
    'ROC-AUC Score': roc_auc,
    'Average Precision Score': avg_precision,
    'Confusion Matrix' : conf_matrix
}
# Out:
# Epoch 1/20
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.2412 - accuracy: 0.8911 - val_loss: 0.1831 - val_accuracy: 0.9095
# Epoch 2/20
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1771 - accuracy: 0.9125 - val_loss: 0.1716 - val_accuracy: 0.9159
# Epoch 3/20
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1680 - accuracy: 0.9182 - val_loss: 0.1652 - val_accuracy: 0.9203
# Epoch 4/20
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1619 - accuracy: 0.9224 - val_loss: 0.1606 - val_accuracy: 0.9234
# Epoch 5/20
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1584 - accuracy: 0.9240 - val_loss: 0.1625 - val_accuracy: 0.9237
# Epoch 6/20
# 4185/4185 [==============================] - 11s 3ms/step - loss: 0.1555 - accuracy: 0.9258 - val_loss: 0.1664 - val_accuracy: 0.9226
# Epoch 7/20
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1530 - accuracy: 0.9275 - val_loss: 0.1514 - val_accuracy: 0.9288
# Epoch 8/20
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1512 - accuracy: 0.9281 - val_loss: 0.1549 - val_accuracy: 0.9251
# Epoch 9/20
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1495 - accuracy: 0.9292 - val_loss: 0.1495 - val_accuracy: 0.9299
# Epoch 10/20
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1483 - accuracy: 0.9297 - val_loss: 0.1484 - val_accuracy: 0.9296
# Epoch 11/20
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1469 - accuracy: 0.9307 - val_loss: 0.1477 - val_accuracy: 0.9324
# Epoch 12/20
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1460 - accuracy: 0.9310 - val_loss: 0.1451 - val_accuracy: 0.9322
# Epoch 13/20
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1451 - accuracy: 0.9318 - val_loss: 0.1453 - val_accuracy: 0.9319
# Epoch 14/20
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1442 - accuracy: 0.9327 - val_loss: 0.1453 - val_accuracy: 0.9326
# Epoch 15/20
# 4185/4185 [==============================] - 11s 3ms/step - loss: 0.1431 - accuracy: 0.9327 - val_loss: 0.1472 - val_accuracy: 0.9311
# Epoch 16/20
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1429 - accuracy: 0.9326 - val_loss: 0.1453 - val_accuracy: 0.9332
# Epoch 17/20
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1421 - accuracy: 0.9333 - val_loss: 0.1445 - val_accuracy: 0.9331
# Epoch 18/20
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1411 - accuracy: 0.9342 - val_loss: 0.1434 - val_accuracy: 0.9332
# Epoch 19/20
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1407 - accuracy: 0.9344 - val_loss: 0.1430 - val_accuracy: 0.9346
# Epoch 20/20
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1400 - accuracy: 0.9348 - val_loss: 0.1438 - val_accuracy: 0.9335
# 291/291 [==============================] - 1s 2ms/step - loss: 0.1343 - accuracy: 0.9372
# 291/291 [==============================] - 1s 2ms/step
# Test Loss: 0.13430242240428925
# Test Accuracy: 0.9372043013572693
# Validation Accuracy: 0.9372043010752689
# Precision: 0.9587093862815884
# Recall: 0.9137634408602151
# F1 Score: 0.9356969830433824
# ROC-AUC Score: 0.9882975604116083
# Average Precision Score: 0.9890139871936507
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 256)               5376
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 32)                2080
#
#  dense_6 (Dense)             (None, 16)                528
#
#  dense_7 (Dense)             (None, 8)                 136
#
#  dense_8 (Dense)             (None, 4)                 36
#
#  dense_9 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 49313 (192.63 KB)
# Trainable params: 49313 (192.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
import matplotlib.pyplot as plt

# Create a figure with subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plot accuracy
axes[0].plot(history.history['accuracy'], label='Training Accuracy')
axes[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
axes[0].set_title('Model Accuracy')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Plot loss
axes[1].plot(history.history['loss'], label='Training Loss')
axes[1].plot(history.history['val_loss'], label='Validation Loss')
axes[1].set_title('Model Loss')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

# Calculate ROC curve
fpr, tpr, thresholds_roc = roc_curve(y_test, y_pred_val)
roc_auc = auc(fpr, tpr)

# Calculate Precision-Recall curve
precision, recall, thresholds_pr = precision_recall_curve(y_test, y_pred_val)
average_precision = average_precision_score(y_test, y_pred_val)

# Plot ROC curve and Precision-Recall curve as subplots
plt.figure(figsize=(15, 6))

# Plot ROC curve
plt.subplot(1, 2, 1)
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) - Shallow Model')
plt.legend(loc="lower right")

# Plot Precision-Recall curve
plt.subplot(1, 2, 2)
plt.plot(recall, precision, color='blue', lw=2, label='Precision-Recall curve (AP = %0.2f)' % average_precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

plt.tight_layout()
plt.show()

# %%
#Append the metrics to an array
performance_metrics.append(metrics)

# Convert performance_metrics array to DataFrame
df_performance_data = pd.DataFrame(performance_metrics)

# Display the DataFrame
print(df_performance_data)
df_performance_data.to_csv(f_performance_path, index=False)
print(f_performance_path, "Saved")
# Out:
#            Time              Model  Training Time  Testing Time  Memory Usage  \
# 0  1.712164e+09  shallow_model_ANN     202.791085      0.688525          12.8
# 1  1.712164e+09     deep_model_ANN     263.399727      0.729605          13.1
#
#    CPU Usage  Test Loss  Test Accuracy  Validation Accuracy  Precision  \
# 0       40.7   0.157680       0.927957             0.927957   0.945389
# 1       57.2   0.134302       0.937204             0.937204   0.958709
#
#      Recall  F1 Score  ROC-AUC Score  Average Precision Score  \
# 0  0.908387  0.926519       0.984141                 0.984953
# 1  0.913763  0.935697       0.988298                 0.989014
#
#              Confusion Matrix
# 0  [[4406, 244], [426, 4224]]
# 1  [[4467, 183], [401, 4249]]
# /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/cp2_small_data_performance.csv Saved

# %% [markdown]
# ## Hyperparameter Tuning

# %%
# !pip install keras-tuner
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (24.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2024.2.2)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.7 kt-legacy-1.0.5

# %%
from kerastuner.tuners import RandomSearch, Hyperband
# Out:
# <ipython-input-9-e64760501d7e>:1: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner.tuners import RandomSearch, Hyperband

# %% [markdown]
# ## Hyperparameter tuning - shallow model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.regularizers import l1, l2  # Import l1 and l2 functions

from kerastuner import RandomSearch
from kerastuner import HyperParameters

modelname="shallow_model"
hpt_method="random search"


# Define a learning rate scheduler function
def lr_scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

def build_shallow_ann_model(hp):
    model = Sequential()

    # Input layer
    model.add(Dense(units=512,
                    input_dim=len(features),
                    activation=hp['activation_layer1'],
                    kernel_initializer=hp['weight_initializer'],
                    kernel_regularizer=l1(hp['regularization_strength']) if hp['regularization_type'] == 'l1' else
                                     l2(hp['regularization_strength']) if hp['regularization_type'] == 'l2' else None))

    # Dropout layer (optional)
    if hp['use_dropout']:
        model.add(Dropout(rate=hp['dropout_rate']))

    # Output layer
    model.add(Dense(1, activation='sigmoid'))

    # Define the learning rate scheduler
    lr_schedule = LearningRateScheduler(lr_scheduler)

    # Choose the optimizer based on the hyperparameter value
    optimizer = None
    if hp['optimizer'] == 'adam':
        optimizer = tf.keras.optimizers.Adam(learning_rate=hp['learning_rate'])
    elif hp['optimizer'] == 'rmsprop':
        optimizer = tf.keras.optimizers.RMSprop(learning_rate=hp['learning_rate'])
    elif hp['optimizer'] == 'sgd':
        optimizer = tf.keras.optimizers.SGD(learning_rate=hp['learning_rate'], momentum=0.9)

    model.compile(optimizer=optimizer,
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    return model



# Create a HyperParameters object
hp = HyperParameters()

# Add hyperparameters to the object
hp.Choice('activation_layer1', ['relu', 'tanh', 'leaky_relu'])
hp.Choice('optimizer', ['adam', 'rmsprop', 'sgd'])  # Hyperparameter for choosing the optimizer
hp.Choice('learning_rate', [0.01, 0.001, 0.0001])
hp.Choice('weight_initializer', ['random_normal', 'glorot_uniform', 'he_normal'])
hp.Choice('batch_size', [8, 16, 32, 64, 128, 256])
hp.Choice('regularization_type', ['','l1', 'l2'])
hp.Choice('regularization_strength', [0.0, 0.001, 0.01, 0.1])
hp.Choice('use_lr_scheduler', [True, False])  # Hyperparameter for choosing whether to use the learning rate scheduler
hp.Choice('use_dropout', [True, False])  # Hyperparameter for choosing whether to use dropout
hp.Float('dropout_rate', 0.0, 0.5, step=0.1)  # Dropout rate hyperparameter
# Out:
# 0.0

# %%
# Instantiate the RandomSearch tuner with the HyperParameters object
tuner = RandomSearch(
    build_shallow_ann_model,
    objective='val_accuracy',
    max_trials=100,
    executions_per_trial=1,
    directory='my_dir',
    project_name='shallow_ann_hp_tuning_RS',
    hyperparameters=hp,  # Use the HyperParameters object
    overwrite=False  # Set to True if you want to overwrite existing results
)

# Record start time
start_time = time.time()

# Perform hyperparameter tuning
tuner.search(X_train, y_train,
             epochs=10,
             validation_split=0.2)

# Record end time
end_time = time.time()
elapsed_time = end_time - start_time

# Get the best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# Build the model with the best hyperparameters and train it
best_model = tuner.hypermodel.build(best_hps)
history = best_model.fit(X_train, y_train, epochs=200, validation_split=0.2)

cpu_usage, memory_usage=get_system_info()


# Evaluate the best model on the test set
print("Best Hyperparameters:")
print(best_hps.values)


# Evaluate the best model on the test set
test_metrics = best_model.evaluate(X_test, y_test)

# Additional classification metrics
y_pred = best_model.predict(X_test)
y_pred_classes = np.round(y_pred)

precision = precision_score(y_test, np.round(y_pred))
recall = recall_score(y_test, np.round(y_pred))
f1 = f1_score(y_test, np.round(y_pred))
roc_auc = roc_auc_score(y_test, y_pred)
avg_precision = average_precision_score(y_test, y_pred)

confusion_matrix = tf.math.confusion_matrix(y_test, y_pred_classes).numpy()

# Display metrics
print("Test Metrics:")
print(" - Loss:", test_metrics[0])
print(" - Accuracy:", test_metrics[1])
print(" - elapsed_time", elapsed_time)
print("- memory_usage", memory_usage)
print(" - Other Metrics:")
print("   - Precision:", precision)
print("   - Recall:", recall)
print("   - F1 Score:", f1)
print("   - ROC-AUC:", roc_auc)
print("   - Precision Score", avg_precision)
print("   - Confusion Matrix:")
print(confusion_matrix)


# Save experiment details in hp_array
experiment_details = {
    'model': modelname,
    'hpt_method':hpt_method,
    'best_hyperparameters': best_hps.values,
    'elapsed_time': elapsed_time,
    'memory_usage': memory_usage,
    'cpu_usage': cpu_usage,
    'precision': precision,
    'recall': recall,
    'f1_score': f1,
    'roc_auc': roc_auc,
    'confusion_matrix': confusion_matrix.tolist(),
}
print(experiment_details)
hp_array.append(experiment_details)
# Out:
# Trial 100 Complete [00h 01m 23s]
# val_accuracy: 0.8907108902931213
#
# Best val_accuracy So Far: 0.9283751249313354
# Total elapsed time: 02h 03m 27s
# Epoch 1/200
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.2089 - accuracy: 0.8966 - val_loss: 0.1922 - val_accuracy: 0.8978
# Epoch 2/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1810 - accuracy: 0.9123 - val_loss: 0.1855 - val_accuracy: 0.9122
# Epoch 3/200
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1736 - accuracy: 0.9175 - val_loss: 0.1747 - val_accuracy: 0.9144
# Epoch 4/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1693 - accuracy: 0.9195 - val_loss: 0.1701 - val_accuracy: 0.9184
# Epoch 5/200
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1655 - accuracy: 0.9220 - val_loss: 0.1659 - val_accuracy: 0.9193
# Epoch 6/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1627 - accuracy: 0.9237 - val_loss: 0.1621 - val_accuracy: 0.9237
# Epoch 7/200
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1606 - accuracy: 0.9250 - val_loss: 0.1613 - val_accuracy: 0.9232
# Epoch 8/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1581 - accuracy: 0.9265 - val_loss: 0.1569 - val_accuracy: 0.9265
# Epoch 9/200
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1560 - accuracy: 0.9274 - val_loss: 0.1579 - val_accuracy: 0.9251
# Epoch 10/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1547 - accuracy: 0.9277 - val_loss: 0.1551 - val_accuracy: 0.9280
# Epoch 11/200
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1534 - accuracy: 0.9295 - val_loss: 0.1560 - val_accuracy: 0.9282
# Epoch 12/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1520 - accuracy: 0.9297 - val_loss: 0.1516 - val_accuracy: 0.9300
# Epoch 13/200
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1517 - accuracy: 0.9300 - val_loss: 0.1521 - val_accuracy: 0.9287
# Epoch 14/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1505 - accuracy: 0.9307 - val_loss: 0.1499 - val_accuracy: 0.9307
# Epoch 15/200
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1501 - accuracy: 0.9309 - val_loss: 0.1526 - val_accuracy: 0.9317
# Epoch 16/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1489 - accuracy: 0.9309 - val_loss: 0.1512 - val_accuracy: 0.9293
# Epoch 17/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1479 - accuracy: 0.9317 - val_loss: 0.1485 - val_accuracy: 0.9320
# Epoch 18/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1474 - accuracy: 0.9322 - val_loss: 0.1509 - val_accuracy: 0.9312
# Epoch 19/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1470 - accuracy: 0.9321 - val_loss: 0.1493 - val_accuracy: 0.9311
# Epoch 20/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1467 - accuracy: 0.9328 - val_loss: 0.1482 - val_accuracy: 0.9328
# Epoch 21/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1465 - accuracy: 0.9327 - val_loss: 0.1476 - val_accuracy: 0.9317
# Epoch 22/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1455 - accuracy: 0.9332 - val_loss: 0.1483 - val_accuracy: 0.9315
# Epoch 23/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1454 - accuracy: 0.9324 - val_loss: 0.1500 - val_accuracy: 0.9318
# Epoch 24/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1450 - accuracy: 0.9335 - val_loss: 0.1469 - val_accuracy: 0.9325
# Epoch 25/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1449 - accuracy: 0.9334 - val_loss: 0.1518 - val_accuracy: 0.9285
# Epoch 26/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.
200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1288 - accuracy: 0.9412 - val_loss: 0.1434 - val_accuracy: 0.9371
# Epoch 179/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1292 - accuracy: 0.9411 - val_loss: 0.1443 - val_accuracy: 0.9386
# Epoch 180/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1290 - accuracy: 0.9411 - val_loss: 0.1438 - val_accuracy: 0.9377
# Epoch 181/200
# 4185/4185 [==============================] - 8s 2ms/step - loss: 0.1290 - accuracy: 0.9412 - val_loss: 0.1445 - val_accuracy: 0.9381
# Epoch 182/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1289 - accuracy: 0.9412 - val_loss: 0.1438 - val_accuracy: 0.9385
# Epoch 183/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1289 - accuracy: 0.9413 - val_loss: 0.1452 - val_accuracy: 0.9378
# Epoch 184/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1288 - accuracy: 0.9415 - val_loss: 0.1438 - val_accuracy: 0.9382
# Epoch 185/200
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1301 - accuracy: 0.9410 - val_loss: 0.1440 - val_accuracy: 0.9375
# Epoch 186/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1286 - accuracy: 0.9414 - val_loss: 0.1447 - val_accuracy: 0.9378
# Epoch 187/200
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1296 - accuracy: 0.9416 - val_loss: 0.1468 - val_accuracy: 0.9369
# Epoch 188/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1290 - accuracy: 0.9415 - val_loss: 0.1434 - val_accuracy: 0.9372
# Epoch 189/200
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1293 - accuracy: 0.9414 - val_loss: 0.1435 - val_accuracy: 0.9393
# Epoch 190/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1286 - accuracy: 0.9413 - val_loss: 0.1744 - val_accuracy: 0.9343
# Epoch 191/200
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1298 - accuracy: 0.9405 - val_loss: 0.1417 - val_accuracy: 0.9373
# Epoch 192/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1282 - accuracy: 0.9417 - val_loss: 0.1434 - val_accuracy: 0.9397
# Epoch 193/200
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1282 - accuracy: 0.9416 - val_loss: 0.1443 - val_accuracy: 0.9373
# Epoch 194/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1287 - accuracy: 0.9417 - val_loss: 0.1438 - val_accuracy: 0.9365
# Epoch 195/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1286 - accuracy: 0.9415 - val_loss: 0.1421 - val_accuracy: 0.9389
# Epoch 196/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1285 - accuracy: 0.9419 - val_loss: 0.1432 - val_accuracy: 0.9394
# Epoch 197/200
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1290 - accuracy: 0.9415 - val_loss: 0.1418 - val_accuracy: 0.9390
# Epoch 198/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1293 - accuracy: 0.9411 - val_loss: 0.1461 - val_accuracy: 0.9375
# Epoch 199/200
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1291 - accuracy: 0.9418 - val_loss: 0.1429 - val_accuracy: 0.9386
# Epoch 200/200
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1282 - accuracy: 0.9420 - val_loss: 0.1465 - val_accuracy: 0.9387
# Best Hyperparameters:
# {'activation_layer1': 'relu', 'optimizer': 'adam', 'learning_rate': 0.001, 'weight_initializer': 'he_normal', 'batch_size': 128, 'regularization_type': '', 'regularization_strength': 0.1, 'use_lr_scheduler': 1, 'use_dropout': 1, 'dropout_rate': 0.0}
# 291/291 [==============================] - 0s 993us/step - loss: 0.1338 - accuracy: 0.9417
# 291/291 [==============================] - 0s 928us/step
# Test Metrics:
#  - Loss: 0.13377662003040314
#  - Accuracy: 0.9417204260826111
#  - elapsed_time 7407.352438926697
# - memory_usage 15.5
#  - Other Metrics:
#    - Precision: 0.9617805755395683
#    - Recall: 0.92
#    - F1 Score: 0.9404264673554626
#    - ROC-AUC: 0.9890702046479362
#    - Precision Score 0.9895303149307773
#    - Confusion Matrix:
# [[4480  170]
#  [ 372 4278]]
# {'model': 'shallow_model', 'hpt_method': 'random search', 'best_hyperparameters': {'activation_layer1': 'relu', 'optimizer': 'adam', 'learning_rate': 0.001, 'weight_initializer': 'he_normal', 'batch_size': 128, 'regularization_type': '', 'regularization_strength': 0.1, 'use_lr_scheduler': 1, 'use_dropout': 1, 'dropout_rate': 0.0}, 'elapsed_time': 7407.352438926697, 'memory_usage': 15.5, 'cpu_usage': 62.6, 'precision': 0.9617805755395683, 'recall': 0.92, 'f1_score': 0.9404264673554626, 'roc_auc': 0.9890702046479362, 'confusion_matrix': [[4480, 170], [372, 4278]]}

# %%
max_val_acc_epoch = np.argmax(history.history['val_accuracy'])
max_val_acc = history.history['val_accuracy'][max_val_acc_epoch]
min_val_loss_epoch = np.argmin(history.history['val_loss'])
min_val_loss = history.history['val_loss'][min_val_loss_epoch]

print("Epoch with maximum validation accuracy:", max_val_acc_epoch)
print("Maximum validation accuracy:", max_val_acc)
print("Epoch with minimum validation loss:", min_val_loss_epoch)
print("Minimum validation loss:", min_val_loss)
# Out:
# Epoch with maximum validation accuracy: 191
# Maximum validation accuracy: 0.9396654963493347
# Epoch with minimum validation loss: 130
# Minimum validation loss: 0.13996560871601105

# %%
import matplotlib.pyplot as plt

# Create a figure with subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plot accuracy
axes[0].plot(history.history['accuracy'], label='Training Accuracy')
axes[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
axes[0].axvline(x=191, color='g', linestyle='--', label='Epoch 191')  # Vertical line at epoch 60
axes[0].set_title('Model Accuracy')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Plot loss
axes[1].plot(history.history['loss'], label='Training Loss')
axes[1].plot(history.history['val_loss'], label='Validation Loss')
axes[1].axvline(x=130, color='g', linestyle='--', label='Epoch 130')  # Vertical line at epoch 60
axes[1].set_title('Model Loss')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt


# Calculate ROC curve
fpr, tpr, thresholds_roc = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Calculate Precision-Recall curve
precision, recall, thresholds_pr = precision_recall_curve(y_test, y_pred)
average_precision = average_precision_score(y_test, y_pred)

# Plot ROC curve and Precision-Recall curve as subplots
plt.figure(figsize=(15, 6))

# Plot ROC curve
plt.subplot(1, 2, 1)
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) - Shallow Model')
plt.legend(loc="lower right")

# Plot Precision-Recall curve
plt.subplot(1, 2, 2)
plt.plot(recall, precision, color='blue', lw=2, label='Precision-Recall curve (AP = %0.2f)' % average_precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

plt.tight_layout()
plt.show()

# %% [markdown]
# #Creating the final shallow model

# %%
from keras.callbacks import ModelCheckpoint

# Define the filepath to save the model
checkpoint_filepath = shallow_model_path_best_hp

# Define a ModelCheckpoint callback to save the model with the highest validation accuracy
checkpoint = ModelCheckpoint(checkpoint_filepath,
                             monitor='val_accuracy',
                             save_best_only=True,
                             mode='max',
                             verbose=1)

# Build the model with the best hyperparameters
best_model = tuner.hypermodel.build(best_hps)

# Train the model with early stopping and ModelCheckpoint callback
history = best_model.fit(X_train, y_train,
                          epochs=max_val_acc_epoch,
                          validation_split=0.2,
                          callbacks=[checkpoint])
# Out:
# Epoch 1/191
# 4182/4185 [============================>.] - ETA: 0s - loss: 0.2087 - accuracy: 0.8978
# Epoch 1: val_accuracy improved from -inf to 0.91284, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.2087 - accuracy: 0.8979 - val_loss: 0.1918 - val_accuracy: 0.9128
# Epoch 2/191
# 4150/4185 [============================>.] - ETA: 0s - loss: 0.1816 - accuracy: 0.9128
# Epoch 2: val_accuracy improved from 0.91284 to 0.91771, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1814 - accuracy: 0.9129 - val_loss: 0.1782 - val_accuracy: 0.9177
# Epoch 3/191
# 4160/4185 [============================>.] - ETA: 0s - loss: 0.1743 - accuracy: 0.9171
# Epoch 3: val_accuracy did not improve from 0.91771
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1744 - accuracy: 0.9170 - val_loss: 0.1751 - val_accuracy: 0.9175
# Epoch 4/191
# 4144/4185 [============================>.] - ETA: 0s - loss: 0.1701 - accuracy: 0.9198
# Epoch 4: val_accuracy improved from 0.91771 to 0.92157, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1700 - accuracy: 0.9200 - val_loss: 0.1701 - val_accuracy: 0.9216
# Epoch 5/191
# 4147/4185 [============================>.] - ETA: 0s - loss: 0.1665 - accuracy: 0.9217
# Epoch 5: val_accuracy improved from 0.92157 to 0.92387, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1664 - accuracy: 0.9217 - val_loss: 0.1627 - val_accuracy: 0.9239
# Epoch 6/191
# 4175/4185 [============================>.] - ETA: 0s - loss: 0.1627 - accuracy: 0.9242
# Epoch 6: val_accuracy improved from 0.92387 to 0.92832, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1627 - accuracy: 0.9242 - val_loss: 0.1580 - val_accuracy: 0.9283
# Epoch 7/191
# 4177/4185 [============================>.] - ETA: 0s - loss: 0.1600 - accuracy: 0.9252
# Epoch 7: val_accuracy did not improve from 0.92832
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1600 - accuracy: 0.9253 - val_loss: 0.1692 - val_accuracy: 0.9264
# Epoch 8/191
# 4172/4185 [============================>.] - ETA: 0s - loss: 0.1580 - accuracy: 0.9265
# Epoch 8: val_accuracy did not improve from 0.92832
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1579 - accuracy: 0.9266 - val_loss: 0.1606 - val_accuracy: 0.9251
# Epoch 9/191
# 4161/4185 [============================>.] - ETA: 0s - loss: 0.1559 - accuracy: 0.9279
# Epoch 9: val_accuracy did not improve from 0.92832
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1559 - accuracy: 0.9279 - val_loss: 0.1526 - val_accuracy: 0.9280
# Epoch 10/191
# 4162/4185 [============================>.] - ETA: 0s - loss: 0.1544 - accuracy: 0.9281
# Epoch 10: val_accuracy did not improve from 0.92832
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1544 - accuracy: 0.9280 - val_loss: 0.1535 - val_accuracy: 0.9277
# Epoch 11/191
# 4177/4185 [============================>.] - ETA: 0s - loss: 0.1534 - accuracy: 0.9289
# Epoch 11: val_accuracy did not improve from 0.92832
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1533 - accuracy: 0.9290 - val_loss: 0.1539 - val_accuracy: 0.9276
# Epoch 12/191
# 4178/4185 [============================>.] - ETA: 0s - loss: 0.1519 - accuracy: 0.9298
# Epoch 12: val_accuracy improved from 0.92832 to 0.92978, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1519 - accuracy: 0.9298 - val_loss: 0.1510 - val_accuracy: 0.9298
# Epoch 13/191
# 4151/4185 [============================>.] - ETA: 0s - loss: 0.1513 - accuracy: 0.9300
# Epoch 13: val_accuracy did not improve from 0.92978
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1513 - accuracy: 0.9301 - val_loss: 0.1497 - val_accuracy: 0.9297
# Epoch 14/191
# 4176/4185 [============================>.] - ETA: 0s - loss: 0.1502 - accuracy: 0.9301
# Epoch 14: val_accuracy improved from 0.92978 to 0.93059, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1502 - accuracy: 0.9301 - val_loss: 0.1513 - val_accuracy: 0.9306
# Epoch 15/191
# 4153/4185 [============================>.] - ETA: 0s - loss: 0.1495 - accuracy: 0.9309
# Epoch 15: val_accuracy did not improve from 0.93059
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1495 - accuracy: 0.9308 - val_loss: 0.1522 - val_accuracy: 0.9280
# Epoch 16/191
# 4180/4185 [============================>.] - ETA: 0s - loss: 0.1485 - accuracy: 0.9314
# Epoch 16: val_accuracy improved from 0.93059 to 0.93199, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1485 - accuracy: 0.9314 - val_loss: 0.1477 - val_accuracy: 0.9320
# Epoch 17/191
# 4152/4185 [============================>.] - ETA: 0s - loss: 0.1486 - accuracy: 0.9315
# Epoch 17: val_accuracy did not improve from 0.93199
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1484 - accuracy: 0.9316 - val_loss: 0.1523 - val_accuracy: 0.9277
# Epoch 18/191
# 4167/4185 [============================>.] - ETA: 0s - loss: 0.1472 - accuracy: 0.9318
# Epoch 18: val_accuracy improved from 0.93199 to 0.93297, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1472 - accuracy: 0.9318 - val_loss: 0.1468 - val_accuracy: 0.9330
# Epoch 19/191
# 4167/4185 [============================>.] - ETA: 0s - loss: 0.1466 - accuracy: 0.9328
# Epoch 19: val_accuracy did not improve from 0.93297
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1466 - accuracy: 0.9328 - val_loss: 0.1612 - val_accuracy: 0.9207
# Epoch 20/191
# 4181/4185 [============================>.] - ETA: 0s - loss: 0.1463 - accuracy: 0.9322
# Epoch 20: val_accuracy did not improve from 0.93297
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1464 - accuracy: 0.9321 - val_loss: 0.1483 - val_accuracy: 0.9322
# Epoch 21/191
# 4146/4185 [============================>.] - ETA: 0s - loss: 0.1458 - accuracy: 0.9328
# Epoch 21: val_accuracy did not improve from 0.93297
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1459 - accuracy: 0.9327 - val_loss: 0.1461 - val_accuracy: 0.9329
# Epoch 22/191
# 4183/4185 [============================>.] - ETA: 0s - loss: 0.1451 - accuracy: 0.9331
# Epoch 22: val_accuracy did not improve from 0.93297
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1451 - accuracy: 0.9330 - val_loss: 0.1470 - val_accuracy: 0.9319
# Epoch 23/191
# 4152/4185 [============================>.] - ETA: 0s - loss: 0.1452 - accuracy: 0.9330
# Epoch 23: val_accuracy improved from 0.93297 to 0.93300, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1452 - accuracy: 0.9330 - val_loss: 0.1455 - val_accuracy: 0.9330
# Epoch 24/191
# 4175/4185 [============================>.] - ETA: 0s - loss: 0.1446 - accuracy: 0.9332
# Epoch 24: val_accuracy did not improve from 0.93300
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1446 - accuracy: 0.9332 - val_loss: 0.1466 - val_accuracy: 0.9320
# Epoch 25/191
# 4151/4185 [============================>.] - ETA: 0s - loss: 0.1442 - accuracy: 0.9336
# Epoch 25: val_accuracy did not improve from 0.93300
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1443 - accuracy: 0.9334 - val_loss: 0.1531 - val_accuracy: 0.9283
# Epoch 26/191
# 4163/4185 [============================>.] - ETA: 0s - loss: 0.1441 - accuracy: 0.9338
# Epoch 26: val_accuracy did not improve from 0.93300
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1441 - accuracy: 0.9338 - val_loss: 0.1463 - val_accuracy: 0.9316
# Epoch 27/191
# 4152/4185 [============================>.] - ETA: 0s - loss: 0.1438 - accuracy: 0.9336
# Epoch 27: val_accuracy did not improve from 0.93300
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1438 - accuracy: 0.9337 - val_loss: 0.1463 - val_accuracy: 0.9323
# Epoch 28/191
# 4179/4185 [============================>.] - ETA: 0s - loss: 0.1433 - accuracy: 0.9346
# Epoch 28: val_accuracy did not improve from 0.93300
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1434 - accuracy: 0.9346 - val_loss: 0.1484 - val_accuracy: 0.9326
# Epoch 29/191
# 4163/4185 [============================>.] - ETA: 0s - loss: 0.1431 - accuracy: 0.9345
# Epoch 29: val_accuracy improved from 0.93300 to 0.93432, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1432 - accuracy: 0.9345 - val_loss: 0.1453 - val_accuracy: 0.9343
# Epoch 30/191
# 4175/4185 [============================>.] - ETA: 0s - loss: 0.1433 - accuracy: 0.9346
# Epoch 30: val_accuracy did not improve from 0.93432
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1433 - accuracy: 0.9346 - val_loss: 0.1486 - val_accuracy: 0.9325
# Epoch 31/191
# 4180/4185 [============================>.] - ETA: 0s - loss: 0.1423 - accuracy: 0.9348
# Epoch 31: val_accuracy improved from 0.93432 to 0.93450, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1423 - accuracy: 0.9348 - val_loss: 0.1443 - val_accuracy: 0.9345
# Epoch 32/191
# 4154/4185 [============================>.] - ETA: 0s - loss: 0.1425 - accuracy: 0.9344
# Epoch 32: val_accuracy did not improve from 0.93450
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1426 - accuracy: 0.9344 - val_loss: 0.1529 - val_accuracy: 0.9307
# Epoch 33/191
# 4184/4185 [============================>.] - ETA: 0s - loss: 0.1420 - accuracy: 0.9345
# Epoch 33: val_accuracy did not improve from 0.93450
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1420 - accuracy: 0.9345 - val_loss: 0.1492 - val_accuracy: 0.9324
# Epoch 34/191
# 4167/4185 [============================>.] - ETA: 0s - loss: 0.1417 - accuracy: 0.9351
# Epoch 34: val_accuracy did not improve from 0.93450
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1417 - accuracy: 0.9351 - val_loss: 0.1453 - val_accuracy: 0.9332
# Epoch 35/191
# 4180/4185 [============================>.] - ETA: 0s - loss: 0.1413 - accuracy: 0.9347
# Epoch 35: val_accuracy improved from 0.93450 to 0.93465, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1414 - accuracy: 0.9347 - val_loss: 0.1431 - val_accuracy: 0.9346
# Epoch 36/191
# 4144/4185 [============================>.] - ETA: 0s - loss: 0.1416 - accuracy: 0.9351
# Epoch 36: val_accuracy did not improve from 0.93465
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1416 - accuracy: 0.9352 - val_loss: 0.1466 - val_accuracy: 0.9332
# Epoch 37/191
# 4182/4185 [============================>.] - ETA: 0s - loss: 0.1411 - accuracy: 0.9349
# Epoch 37: val_accuracy improved from 0.93465 to 0.93536, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1412 - accuracy: 0.9349 - val_loss: 0.1450 - val_accuracy: 0.9354
# Epoch 38/191
# 4169/4185 [============================>.] - ETA: 0s - loss: 0.1409 - accuracy: 0.9355
# Epoch 38: val_accuracy did not improve from 0.93536
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1410 - accuracy: 0.9354 - val_loss: 0.1425 - val_accuracy: 0.9352
# Epoch 39/191
# 4169/4185 [============================>.] - ETA: 0s - loss: 0.1408 - accuracy: 0.9353
# Epoch 39: val_accuracy did not improve from 0.93536
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1408 - accuracy: 0.9353 - val_loss: 0.1490 - val_accuracy: 0.9312
# Epoch 40/191
# 4164/4185 [============================>.] - ETA: 0s - loss: 0.1408 - accuracy: 0.9356
# Epoch 40: val_accuracy did not improve from 0.93536
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1408 - accuracy: 0.9356 - val_loss: 0.1451 - val_accuracy: 0.9325
# Epoch 41/191
# 4181/4185 [============================>.] - ETA: 0s - loss: 0.1403 - accuracy: 0.9355
# Epoch 41: val_accuracy did not improve from 0.93536
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1403 - accuracy: 0.9355 - val_loss: 0.1485 - val_accuracy: 0.9335
# Epoch 42/191
# 4156/4185 [============================>.] - ETA: 0s - loss: 0.1403 - accuracy: 0.9353
# Epoch 42: val_accuracy improved from 0.93536 to 0.93566, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1403 - accuracy: 0.9353 - val_loss: 0.1441 - val_accuracy: 0.9357
# Epoch 43/191
# 4184/4185 [============================>.] - ETA: 0s - loss: 0.1401 - accuracy: 0.9357
# Epoch 43: val_accuracy did not improve from 0.93566
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1401 - accuracy: 0.9357 - val_loss: 0.1442 - val_accuracy: 0.9346
# Epoch 44/191
# 4174/4185 [============================>.] - ETA: 0s - loss: 0.1402 - accuracy: 0.9354
# Epoch 44: val_accuracy did not improve from 0.93566
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1402 - accuracy: 0.9353 - val_loss: 0.1519 - val_accuracy: 0.9305
# Epoch 45/191
# 4171/4185 [============================>.] - ETA: 0s - loss: 0.1402 - accuracy: 0.9361
# Epoch 45: val_accuracy did not improve from 0.93566
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1403 - accuracy: 0.9360 - val_loss: 0.1454 - val_accuracy: 0.9356
# Epoch 46/191
# 4164/4185 [============================>.] - ETA: 0s - loss: 0.1398 - accuracy: 0.9355
# Epoch 46: val_accuracy did not improve from 0.93566
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1398 - accuracy: 0.9355 - val_loss: 0.1450 - val_accuracy: 0.9341
# Epoch 47/191
# 4154/4185 [============================>.] - ETA: 0s - loss: 0.1396 - accuracy: 0.9362
# Epoch 47: val_accuracy did not improve from 0.93566
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1395 - accuracy: 0.9362 - val_loss: 0.1470 - val_accuracy: 0.9344
# Epoch 48/191
# 4166/4185 [============================>.] - ETA: 0s - loss: 0.1394 - accuracy: 0.9363
# Epoch 48: val_accuracy did not improve from 0.93566
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1394 - accuracy: 0.9362 - val_loss: 0.1428 - val_accuracy: 0.9349
# Epoch 49/191
# 4146/4185 [============================>.] - ETA: 0s - loss: 0.1396 - accuracy: 0.9361
# Epoch 49: val_accuracy improved from 0.93566 to 0.93575, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1396 - accuracy: 0.9360 - val_loss: 0.1434 - val_accuracy: 0.9358
# Epoch 50/191
# 4179/4185 [============================>.] - ETA: 0s - loss: 0.1391 - accuracy: 0.9362
# Epoch 50: val_accuracy did not improve from 0.93575
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1391 - accuracy: 0.9362 - val_loss: 0.1452 - val_accuracy: 0.9340
# Epoch 51/191
# 4175/4185 [============================>.] - ETA: 0s - loss: 0.1389 - accuracy: 0.9361
# Epoch 51: val_accuracy did not improve from 0.93575
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1389 - accuracy: 0.9362 - val_loss: 0.1444 - val_accuracy: 0.9350
# Epoch 52/191
# 4161/4185 [============================>.] - ETA: 0s - loss: 0.1383 - accuracy: 0.9367
# Epoch 52: val_accuracy did not improve from 0.93575
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1384 - accuracy: 0.9367 - val_loss: 0.1449 - val_accuracy: 0.9345
# Epoch 53/191
# 4153/4185 [============================>.] - ETA: 0s - loss: 0.1385 - accuracy: 0.9366
# Epoch 53: val_accuracy did not improve from 0.93575
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1384 - accuracy: 0.9365 - val_loss: 0.1453 - val_accuracy: 0.9357
# Epoch 54/191
# 4145/4185 [============================>.] - ETA: 0s - loss: 0.1388 - accuracy: 0.9364
# Epoch 54: val_accuracy did not improve from 0.93575
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1389 - accuracy: 0.9363 - val_loss: 0.1439 - val_accuracy: 0.9343
# Epoch 55/191
# 4181/4185 [============================>.] - ETA: 0s - loss: 0.1390 - accuracy: 0.9362
# Epoch 55: val_accuracy did not improve from 0.93575
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1390 - accuracy: 0.9362 - val_loss: 0.1465 - val_accuracy: 0.9353
# Epoch 56/191
# 4161/4185 [============================>.] - ETA: 0s - loss: 0.1381 - accuracy: 0.9367
# Epoch 56: val_accuracy did not improve from 0.93575
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1381 - accuracy: 0.9367 - val_loss: 0.1459 - val_accuracy: 0.9344
# Epoch 57/191
# 4172/4185 [============================>.] - ETA: 0s - loss: 0.1381 - accuracy: 0.9363
# Epoch 57: val_accuracy improved from 0.93575 to 0.93641, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1381 - accuracy: 0.9363 - val_loss: 0.1441 - val_accuracy: 0.9364
# Epoch 58/191
# 4185/4185 [==============================] - ETA: 0s - loss: 0.1384 - accuracy: 0.9371
# Epoch 58: val_accuracy did not improve from 0.93641
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1384 - accuracy: 0.9371 - val_loss: 0.1441 - val_accuracy: 0.9363
# Epoch 59/191
# 4152/4185 [============================>.] - ETA: 0s - loss: 0.1380 - accuracy: 0.9369
# Epoch 59: val_accuracy did not improve from 0.93641
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1379 - accuracy: 0.9369 - val_loss: 0.1454 - val_accuracy: 0.9352
# Epoch 60/191
# 4156/4185 [============================>.] - ETA: 0s - loss: 0.1382 - accuracy: 0.9367
# Epoch 60: val_accuracy did not improve from 0.93641
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1381 - accuracy: 0.9367 - val_loss: 0.1421 - val_accuracy: 0.9361
# Epoch 61/191
# 4172/4185 [============================>.] - ETA: 0s - loss: 0.1374 - accuracy: 0.9371
# Epoch 61: val_accuracy did not improve from 0.93641
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1372 - accuracy: 0.9372 - val_loss: 0.1443 - val_accuracy: 0.9352
# Epoch 62/191
# 4153/4185 [============================>.] - ETA: 0s - loss: 0.1380 - accuracy: 0.9369
# Epoch 62: val_accuracy did not improve from 0.93641
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1380 - accuracy: 0.9369 - val_loss: 0.1434 - val_accuracy: 0.9353
# Epoch 63/191
# 4179/4185 [============================>.] - ETA: 0s - loss: 0.1377 - accuracy: 0.9369
# Epoch 63: val_accuracy did not improve from 0.93641
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1377 - accuracy: 0.9369 - val_loss: 0.1428 - val_accuracy: 0.9361
# Epoch 64/191
# 4141/4185 [============================>.] - ETA: 0s - loss: 0.1374 - accuracy: 0.9370
# Epoch 64: val_accuracy did not improve from 0.93641
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1374 - accuracy: 0.9370 - val_loss: 0.1461 - val_accuracy: 0.9336
# Epoch 65/191
# 4151/4185 [============================>.] - ETA: 0s - loss: 0.1376 - accuracy: 0.9373
# Epoch 65: val_accuracy did not improve from 0.93641
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1377 - accuracy: 0.9373 - val_loss: 0.1435 - val_accuracy: 0.9354
# Epoch 66/191
# 4145/4185 [============================>.] - ETA: 0s - loss: 0.1370 - accuracy: 0.9370
# Epoch 66: val_accuracy did not improve from 0.93641
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1371 - accuracy: 0.9370 - val_loss: 0.1433 - val_accuracy: 0.9357
# Epoch 67/191
# 4173/4185 [============================>.] - ETA: 0s - loss: 0.1374 - accuracy: 0.9376
# Epoch 67: val_accuracy improved from 0.93641 to 0.93695, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1375 - accuracy: 0.9376 - val_loss: 0.1431 - val_accuracy: 0.9369
# Epoch 68/191
# 4143/4185 [============================>.] - ETA: 0s - loss: 0.1364 - accuracy: 0.9371
# Epoch 68: val_accuracy did not improve from 0.93695
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1364 - accuracy: 0.9372 - val_loss: 0.1443 - val_accuracy: 0.9338
# Epoch 69/191
# 4169/4185 [============================>.] - ETA: 0s - loss: 0.1369 - accuracy: 0.9372
# Epoch 69: val_accuracy improved from 0.93695 to 0.93737, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1368 - accuracy: 0.9372 - val_loss: 0.1412 - val_accuracy: 0.9374
# Epoch 70/191
# 4148/4185 [============================>.] - ETA: 0s - loss: 0.1362 - accuracy: 0.9375
# Epoch 70: val_accuracy did not improve from 0.93737
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1363 - accuracy: 0.9375 - val_loss: 0.1577 - val_accuracy: 0.9309
# Epoch 71/191
# 4151/4185 [============================>.] - ETA: 0s - loss: 0.1370 - accuracy: 0.9374
# Epoch 71: val_accuracy did not improve from 0.93737
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1369 - accuracy: 0.9375 - val_loss: 0.1433 - val_accuracy: 0.9349
# Epoch 72/191
# 4171/4185 [============================>.] - ETA: 0s - loss: 0.1365 - accuracy: 0.9381
# Epoch 72: val_accuracy did not improve from 0.93737
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1364 - accuracy: 0.9381 - val_loss: 0.1436 - val_accuracy: 0.9355
# Epoch 73/191
# 4146/4185 [============================>.] - ETA: 0s - loss: 0.1362 - accuracy: 0.9377
# Epoch 73: val_accuracy did not improve from 0.93737
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1361 - accuracy: 0.9377 - val_loss: 0.1477 - val_accuracy: 0.9326
# Epoch 74/191
# 4162/4185 [============================>.] - ETA: 0s - loss: 0.1364 - accuracy: 0.9370
# Epoch 74: val_accuracy did not improve from 0.93737
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1364 - accuracy: 0.9370 - val_loss: 0.1441 - val_accuracy: 0.9349
# Epoch 75/191
# 4163/4185 [============================>.] - ETA: 0s - loss: 0.1360 - accuracy: 0.9377
# Epoch 75: val_accuracy did not improve from 0.93737
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1359 - accuracy: 0.9378 - val_loss: 0.1429 - val_accuracy: 0.9353
# Epoch 76/191
# 4180/4185 [============================>.] - ETA: 0s - loss: 0.1357 - accuracy: 0.9381
# Epoch 76: val_accuracy did not improve from 0.93737
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1357 - accuracy: 0.9381 - val_loss: 0.1472 - val_accuracy: 0.9348
# Epoch 77/191
# 4174/4185 [============================>.] - ETA: 0s - loss: 0.1367 - accuracy: 0.9379
# Epoch 77: val_accuracy did not improve from 0.93737
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1368 - accuracy: 0.9378 - val_loss: 0.1443 - val_accuracy: 0.9352
# Epoch 78/191
# 4168/4185 [============================>.] - ETA: 0s - loss: 0.1358 - accuracy: 0.9379
# Epoch 78: val_accuracy did not improve from 0.93737
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1359 - accuracy: 0.9378 - val_loss: 0.1418 - val_accuracy: 0.9355
# Epoch 79/191
# 4169/4185 [============================>.] - ETA: 0s - loss: 0.1369 - accuracy: 0.9379
# Epoch 79: val_accuracy did not improve from 0.93737
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1370 - accuracy: 0.9378 - val_loss: 0.1457 - val_accuracy: 0.9356
# Epoch 80/191
# 4159/4185 [============================>.] - ETA: 0s - loss: 0.1357 - accuracy: 0.9378
# Epoch 80: val_accuracy did not improve from 0.93737
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1357 - accuracy: 0.9378 - val_loss: 0.1470 - val_accuracy: 0.9326
# Epoch 81/191
# 4156/4185 [============================>.] - ETA: 0s - loss: 0.1352 - accuracy: 0.9380
# Epoch 81: val_accuracy did not improve from 0.93737
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1353 - accuracy: 0.9379 - val_loss: 0.1443 - val_accuracy: 0.9349
# Epoch 82/191
# 4175/4185 [============================>.] - ETA: 0s - loss: 0.1353 - accuracy: 0.9376
# Epoch 82: val_accuracy improved from 0.93737 to 0.93754, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1353 - accuracy: 0.9376 - val_loss: 0.1425 - val_accuracy: 0.9375
# Epoch 83/191
# 4161/4185 [============================>.] - ETA: 0s - loss: 0.1357 - accuracy: 0.9376
# Epoch 83: val_accuracy did not improve from 0.93754
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1357 - accuracy: 0.9376 - val_loss: 0.1443 - val_accuracy: 0.9365
# Epoch 84/191
# 4152/4185 [============================>.] - ETA: 0s - loss: 0.1354 - accuracy: 0.9381
# Epoch 84: val_accuracy did not improve from 0.93754
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1356 - accuracy: 0.9380 - val_loss: 0.1428 - val_accuracy: 0.9351
# Epoch 85/191
# 4152/4185 [============================>.] - ETA: 0s - loss: 0.1355 - accuracy: 0.9378
# Epoch 85: val_accuracy did not improve from 0.93754
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1354 - accuracy: 0.9379 - val_loss: 0.1425 - val_accuracy: 0.9359
# Epoch 86/191
# 4158/4185 [============================>.] - ETA: 0s - loss: 0.1348 - accuracy: 0.9381
# Epoch 86: val_accuracy did not improve from 0.93754
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1348 - accuracy: 0.9381 - val_loss: 0.1454 - val_accuracy: 0.9337
# Epoch 87/191
# 4150/4185 [============================>.] - ETA: 0s - loss: 0.1348 - accuracy: 0.9376
# Epoch 87: val_accuracy did not improve from 0.93754
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1348 - accuracy: 0.9377 - val_loss: 0.1419 - val_accuracy: 0.9361
# Epoch 88/191
# 4174/4185 [============================>.] - ETA: 0s - loss: 0.1347 - accuracy: 0.9379
# Epoch 88: val_accuracy did not improve from 0.93754
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1347 - accuracy: 0.9378 - val_loss: 0.1422 - val_accuracy: 0.9364
# Epoch 89/191
# 4168/4185 [============================>.] - ETA: 0s - loss: 0.1350 - accuracy: 0.9377
# Epoch 89: val_accuracy did not improve from 0.93754
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1349 - accuracy: 0.9378 - val_loss: 0.1434 - val_accuracy: 0.9356
# Epoch 90/191
# 4167/4185 [============================>.] - ETA: 0s - loss: 0.1357 - accuracy: 0.9380
# Epoch 90: val_accuracy did not improve from 0.93754
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1357 - accuracy: 0.9380 - val_loss: 0.1418 - val_accuracy: 0.9363
# Epoch 91/191
# 4172/4185 [============================>.] - ETA: 0s - loss: 0.1347 - accuracy: 0.9380
# Epoch 91: val_accuracy did not improve from 0.93754
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1346 - accuracy: 0.9381 - val_loss: 0.1425 - val_accuracy: 0.9371
# Epoch 92/191
# 4185/4185 [==============================] - ETA: 0s - loss: 0.1344 - accuracy: 0.9384
# Epoch 92: val_accuracy did not improve from 0.93754
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1344 - accuracy: 0.9384 - val_loss: 0.1435 - val_accuracy: 0.9353
# Epoch 93/191
# 4175/4185 [============================>.] - ETA: 0s - loss: 0.1351 - accuracy: 0.9378
# Epoch 93: val_accuracy did not improve from 0.93754
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1351 - accuracy: 0.9378 - val_loss: 0.1417 - val_accuracy: 0.9371
# Epoch 94/191
# 4183/4185 [============================>.] - ETA: 0s - loss: 0.1337 - accuracy: 0.9384
# Epoch 94: val_accuracy did not improve from 0.93754
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1337 - accuracy: 0.9384 - val_loss: 0.1418 - val_accuracy: 0.9361
# Epoch 95/191
# 4176/4185 [============================>.] - ETA: 0s - loss: 0.1341 - accuracy: 0.9381
# Epoch 95: val_accuracy did not improve from 0.93754
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1341 - accuracy: 0.9381 - val_loss: 0.1441 - val_accuracy: 0.9358
# Epoch 96/191
# 4175/4185 [============================>.] - ETA: 0s - loss: 0.1337 - accuracy: 0.9383
# Epoch 96: val_accuracy did not improve from 0.93754
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1337 - accuracy: 0.9383 - val_loss: 0.1415 - val_accuracy: 0.9366
# Epoch 97/191
# 4183/4185 [============================>.] - ETA: 0s - loss: 0.1343 - accuracy: 0.9386
# Epoch 97: val_accuracy did not improve from 0.93754
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1342 - accuracy: 0.9386 - val_loss: 0.1441 - val_accuracy: 0.9367
# Epoch 98/191
# 4172/4185 [============================>.] - ETA: 0s - loss: 0.1341 - accuracy: 0.9386
# Epoch 98: val_accuracy did not improve from 0.93754
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1341 - accuracy: 0.9386 - val_loss: 0.1409 - val_accuracy: 0.9374
# Epoch 99/191
# 4149/4185 [============================>.] - ETA: 0s - loss: 0.1345 - accuracy: 0.9382
# Epoch 99: val_accuracy did not improve from 0.93754
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1345 - accuracy: 0.9381 - val_loss: 0.1476 - val_accuracy: 0.9323
# Epoch 100/191
# 4182/4185 [============================>.] - ETA: 0s - loss: 0.1339 - accuracy: 0.9387
# Epoch 100: val_accuracy did not improve from 0.93754
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1338 - accuracy: 0.9387 - val_loss: 0.1436 - val_accuracy: 0.9356
# Epoch 101/191
# 4163/4185 [============================>.] - ETA: 0s - loss: 0.1338 - accuracy: 0.9384
# Epoch 101: val_accuracy did not improve from 0.93754
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1338 - accuracy: 0.9384 - val_loss: 0.1430 - val_accuracy: 0.9370
# Epoch 102/191
# 4143/4185 [============================>.] - ETA: 0s - loss: 0.1338 - accuracy: 0.9389
# Epoch 102: val_accuracy did not improve from 0.93754
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1338 - accuracy: 0.9389 - val_loss: 0.1425 - val_accuracy: 0.9365
# Epoch 103/191
# 4142/4185 [============================>.] - ETA: 0s - loss: 0.1349 - accuracy: 0.9387
# Epoch 103: val_accuracy did not improve from 0.93754
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1351 - accuracy: 0.9386 - val_loss: 0.1428 - val_accuracy: 0.9362
# Epoch 104/191
# 4164/4185 [============================>.] - ETA: 0s - loss: 0.1340 - accuracy: 0.9391
# Epoch 104: val_accuracy did not improve from 0.93754
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1340 - accuracy: 0.9391 - val_loss: 0.1394 - val_accuracy: 0.9372
# Epoch 105/191
# 4172/4185 [============================>.] - ETA: 0s - loss: 0.1330 - accuracy: 0.9392
# Epoch 105: val_accuracy did not improve from 0.93754
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1331 - accuracy: 0.9391 - val_loss: 0.1403 - val_accuracy: 0.9369
# Epoch 106/191
# 4166/4185 [============================>.] - ETA: 0s - loss: 0.1334 - accuracy: 0.9386
# Epoch 106: val_accuracy did not improve from 0.93754
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1333 - accuracy: 0.9387 - val_loss: 0.1443 - val_accuracy: 0.9357
# Epoch 107/191
# 4173/4185 [============================>.] - ETA: 0s - loss: 0.1332 - accuracy: 0.9382
# Epoch 107: val_accuracy did not improve from 0.93754
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1332 - accuracy: 0.9383 - val_loss: 0.1557 - val_accuracy: 0.9360
# Epoch 108/191
# 4178/4185 [============================>.] - ETA: 0s - loss: 0.1333 - accuracy: 0.9387
# Epoch 108: val_accuracy did not improve from 0.93754
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1334 - accuracy: 0.9387 - val_loss: 0.1415 - val_accuracy: 0.9374
# Epoch 109/191
# 4153/4185 [============================>.] - ETA: 0s - loss: 0.1331 - accuracy: 0.9390
# Epoch 109: val_accuracy did not improve from 0.93754
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1330 - accuracy: 0.9390 - val_loss: 0.1443 - val_accuracy: 0.9360
# Epoch 110/191
# 4143/4185 [============================>.] - ETA: 0s - loss: 0.1334 - accuracy: 0.9384
# Epoch 110: val_accuracy did not improve from 0.93754
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1332 - accuracy: 0.9385 - val_loss: 0.1438 - val_accuracy: 0.9348
# Epoch 111/191
# 4145/4185 [============================>.] - ETA: 0s - loss: 0.1330 - accuracy: 0.9392
# Epoch 111: val_accuracy improved from 0.93754 to 0.93784, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1328 - accuracy: 0.9394 - val_loss: 0.1426 - val_accuracy: 0.9378
# Epoch 112/191
# 4176/4185 [============================>.] - ETA: 0s - loss: 0.1334 - accuracy: 0.9391
# Epoch 112: val_accuracy did not improve from 0.93784
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1334 - accuracy: 0.9391 - val_loss: 0.1436 - val_accuracy: 0.9371
# Epoch 113/191
# 4145/4185 [============================>.] - ETA: 0s - loss: 0.1331 - accuracy: 0.9390
# Epoch 113: val_accuracy did not improve from 0.93784
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1332 - accuracy: 0.9389 - val_loss: 0.1419 - val_accuracy: 0.9374
# Epoch 114/191
# 4151/4185 [============================>.] - ETA: 0s - loss: 0.1337 - accuracy: 0.9392
# Epoch 114: val_accuracy did not improve from 0.93784
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1336 - accuracy: 0.9392 - val_loss: 0.1410 - val_accuracy: 0.9364
# Epoch 115/191
# 4142/4185 [============================>.] - ETA: 0s - loss: 0.1323 - accuracy: 0.9394
# Epoch 115: val_accuracy did not improve from 0.93784
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1323 - accuracy: 0.9394 - val_loss: 0.1439 - val_accuracy: 0.9366
# Epoch 116/191
# 4169/4185 [============================>.] - ETA: 0s - loss: 0.1325 - accuracy: 0.9392
# Epoch 116: val_accuracy did not improve from 0.93784
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1324 - accuracy: 0.9392 - val_loss: 0.1416 - val_accuracy: 0.9366
# Epoch 117/191
# 4163/4185 [============================>.] - ETA: 0s - loss: 0.1329 - accuracy: 0.9390
# Epoch 117: val_accuracy did not improve from 0.93784
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1328 - accuracy: 0.9391 - val_loss: 0.1415 - val_accuracy: 0.9365
# Epoch 118/191
# 4149/4185 [============================>.] - ETA: 0s - loss: 0.1324 - accuracy: 0.9392
# Epoch 118: val_accuracy did not improve from 0.93784
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1326 - accuracy: 0.9391 - val_loss: 0.1429 - val_accuracy: 0.9372
# Epoch 119/191
# 4163/4185 [============================>.] - ETA: 0s - loss: 0.1324 - accuracy: 0.9388
# Epoch 119: val_accuracy did not improve from 0.93784
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1325 - accuracy: 0.9387 - val_loss: 0.1418 - val_accuracy: 0.9368
# Epoch 120/191
# 4168/4185 [============================>.] - ETA: 0s - loss: 0.1336 - accuracy: 0.9399
# Epoch 120: val_accuracy did not improve from 0.93784
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1336 - accuracy: 0.9398 - val_loss: 0.1427 - val_accuracy: 0.9375
# Epoch 121/191
# 4161/4185 [============================>.] - ETA: 0s - loss: 0.1326 - accuracy: 0.9387
# Epoch 121: val_accuracy improved from 0.93784 to 0.93787, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1327 - accuracy: 0.9387 - val_loss: 0.1403 - val_accuracy: 0.9379
# Epoch 122/191
# 4180/4185 [============================>.] - ETA: 0s - loss: 0.1322 - accuracy: 0.9391
# Epoch 122: val_accuracy did not improve from 0.93787
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1322 - accuracy: 0.9391 - val_loss: 0.1435 - val_accuracy: 0.9366
# Epoch 123/191
# 4176/4185 [============================>.] - ETA: 0s - loss: 0.1330 - accuracy: 0.9393
# Epoch 123: val_accuracy did not improve from 0.93787
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1330 - accuracy: 0.9393 - val_loss: 0.1476 - val_accuracy: 0.9332
# Epoch 124/191
# 4153/4185 [============================>.] - ETA: 0s - loss: 0.1322 - accuracy: 0.9392
# Epoch 124: val_accuracy did not improve from 0.93787
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1322 - accuracy: 0.9392 - val_loss: 0.1457 - val_accuracy: 0.9346
# Epoch 125/191
# 4164/4185 [============================>.] - ETA: 0s - loss: 0.1323 - accuracy: 0.9393
# Epoch 125: val_accuracy did not improve from 0.93787
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1322 - accuracy: 0.9393 - val_loss: 0.1471 - val_accuracy: 0.9341
# Epoch 126/191
# 4170/4185 [============================>.] - ETA: 0s - loss: 0.1318 - accuracy: 0.9394
# Epoch 126: val_accuracy did not improve from 0.93787
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1319 - accuracy: 0.9394 - val_loss: 0.1431 - val_accuracy: 0.9368
# Epoch 127/191
# 4158/4185 [============================>.] - ETA: 0s - loss: 0.1323 - accuracy: 0.9394
# Epoch 127: val_accuracy did not improve from 0.93787
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1322 - accuracy: 0.9394 - val_loss: 0.1431 - val_accuracy: 0.9363
# Epoch 128/191
# 4165/4185 [============================>.] - ETA: 0s - loss: 0.1328 - accuracy: 0.9394
# Epoch 128: val_accuracy did not improve from 0.93787
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1329 - accuracy: 0.9393 - val_loss: 0.1425 - val_accuracy: 0.9362
# Epoch 129/191
# 4152/4185 [============================>.] - ETA: 0s - loss: 0.1317 - accuracy: 0.9395
# Epoch 129: val_accuracy did not improve from 0.93787
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1316 - accuracy: 0.9395 - val_loss: 0.1469 - val_accuracy: 0.9366
# Epoch 130/191
# 4159/4185 [============================>.] - ETA: 0s - loss: 0.1317 - accuracy: 0.9397
# Epoch 130: val_accuracy did not improve from 0.93787
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1317 - accuracy: 0.9397 - val_loss: 0.1421 - val_accuracy: 0.9365
# Epoch 131/191
# 4182/4185 [============================>.] - ETA: 0s - loss: 0.1320 - accuracy: 0.9397
# Epoch 131: val_accuracy did not improve from 0.93787
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1321 - accuracy: 0.9397 - val_loss: 0.1440 - val_accuracy: 0.9361
# Epoch 132/191
# 4152/4185 [============================>.] - ETA: 0s - loss: 0.1323 - accuracy: 0.9392
# Epoch 132: val_accuracy did not improve from 0.93787
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1324 - accuracy: 0.9391 - val_loss: 0.1443 - val_accuracy: 0.9361
# Epoch 133/191
# 4182/4185 [============================>.] - ETA: 0s - loss: 0.1322 - accuracy: 0.9401
# Epoch 133: val_accuracy did not improve from 0.93787
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1321 - accuracy: 0.9401 - val_loss: 0.1448 - val_accuracy: 0.9359
# Epoch 134/191
# 4149/4185 [============================>.] - ETA: 0s - loss: 0.1316 - accuracy: 0.9392
# Epoch 134: val_accuracy did not improve from 0.93787
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1315 - accuracy: 0.9393 - val_loss: 0.1415 - val_accuracy: 0.9370
# Epoch 135/191
# 4164/4185 [============================>.] - ETA: 0s - loss: 0.1317 - accuracy: 0.9401
# Epoch 135: val_accuracy did not improve from 0.93787
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1318 - accuracy: 0.9401 - val_loss: 0.1410 - val_accuracy: 0.9379
# Epoch 136/191
# 4159/4185 [============================>.] - ETA: 0s - loss: 0.1324 - accuracy: 0.9397
# Epoch 136: val_accuracy did not improve from 0.93787
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1324 - accuracy: 0.9397 - val_loss: 0.1425 - val_accuracy: 0.9358
# Epoch 137/191
# 4150/4185 [============================>.] - ETA: 0s - loss: 0.1316 - accuracy: 0.9396
# Epoch 137: val_accuracy did not improve from 0.93787
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1316 - accuracy: 0.9397 - val_loss: 0.1416 - val_accuracy: 0.9376
# Epoch 138/191
# 4175/4185 [============================>.] - ETA: 0s - loss: 0.1319 - accuracy: 0.9395
# Epoch 138: val_accuracy did not improve from 0.93787
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1320 - accuracy: 0.9394 - val_loss: 0.1446 - val_accuracy: 0.9345
# Epoch 139/191
# 4155/4185 [============================>.] - ETA: 0s - loss: 0.1328 - accuracy: 0.9399
# Epoch 139: val_accuracy improved from 0.93787 to 0.93844, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1327 - accuracy: 0.9400 - val_loss: 0.1419 - val_accuracy: 0.9384
# Epoch 140/191
# 4151/4185 [============================>.] - ETA: 0s - loss: 0.1310 - accuracy: 0.9400
# Epoch 140: val_accuracy did not improve from 0.93844
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1310 - accuracy: 0.9400 - val_loss: 0.1401 - val_accuracy: 0.9384
# Epoch 141/191
# 4167/4185 [============================>.] - ETA: 0s - loss: 0.1313 - accuracy: 0.9400
# Epoch 141: val_accuracy did not improve from 0.93844
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1313 - accuracy: 0.9399 - val_loss: 0.1441 - val_accuracy: 0.9342
# Epoch 142/191
# 4149/4185 [============================>.] - ETA: 0s - loss: 0.1311 - accuracy: 0.9397
# Epoch 142: val_accuracy did not improve from 0.93844
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1310 - accuracy: 0.9398 - val_loss: 0.1403 - val_accuracy: 0.9384
# Epoch 143/191
# 4142/4185 [============================>.] - ETA: 0s - loss: 0.1313 - accuracy: 0.9397
# Epoch 143: val_accuracy did not improve from 0.93844
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1312 - accuracy: 0.9397 - val_loss: 0.1449 - val_accuracy: 0.9358
# Epoch 144/191
# 4155/4185 [============================>.] - ETA: 0s - loss: 0.1317 - accuracy: 0.9400
# Epoch 144: val_accuracy did not improve from 0.93844
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1316 - accuracy: 0.9400 - val_loss: 0.1412 - val_accuracy: 0.9376
# Epoch 145/191
# 4146/4185 [============================>.] - ETA: 0s - loss: 0.1315 - accuracy: 0.9397
# Epoch 145: val_accuracy did not improve from 0.93844
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1316 - accuracy: 0.9397 - val_loss: 0.1444 - val_accuracy: 0.9372
# Epoch 146/191
# 4178/4185 [============================>.] - ETA: 0s - loss: 0.1305 - accuracy: 0.9400
# Epoch 146: val_accuracy did not improve from 0.93844
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1305 - accuracy: 0.9399 - val_loss: 0.1412 - val_accuracy: 0.9382
# Epoch 147/191
# 4170/4185 [============================>.] - ETA: 0s - loss: 0.1309 - accuracy: 0.9400
# Epoch 147: val_accuracy did not improve from 0.93844
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1309 - accuracy: 0.9400 - val_loss: 0.1414 - val_accuracy: 0.9369
# Epoch 148/191
# 4165/4185 [============================>.] - ETA: 0s - loss: 0.1309 - accuracy: 0.9396
# Epoch 148: val_accuracy did not improve from 0.93844
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1309 - accuracy: 0.9396 - val_loss: 0.1440 - val_accuracy: 0.9370
# Epoch 149/191
# 4175/4185 [============================>.] - ETA: 0s - loss: 0.1309 - accuracy: 0.9394
# Epoch 149: val_accuracy did not improve from 0.93844
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1309 - accuracy: 0.9394 - val_loss: 0.1449 - val_accuracy: 0.9372
# Epoch 150/191
# 4185/4185 [==============================] - ETA: 0s - loss: 0.1317 - accuracy: 0.9398
# Epoch 150: val_accuracy did not improve from 0.93844
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1317 - accuracy: 0.9398 - val_loss: 0.1434 - val_accuracy: 0.9364
# Epoch 151/191
# 4179/4185 [============================>.] - ETA: 0s - loss: 0.1308 - accuracy: 0.9402
# Epoch 151: val_accuracy did not improve from 0.93844
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1308 - accuracy: 0.9402 - val_loss: 0.1436 - val_accuracy: 0.9365
# Epoch 152/191
# 4183/4185 [============================>.] - ETA: 0s - loss: 0.1308 - accuracy: 0.9399
# Epoch 152: val_accuracy did not improve from 0.93844
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1308 - accuracy: 0.9400 - val_loss: 0.1412 - val_accuracy: 0.9380
# Epoch 153/191
# 4153/4185 [============================>.] - ETA: 0s - loss: 0.1308 - accuracy: 0.9399
# Epoch 153: val_accuracy did not improve from 0.93844
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1307 - accuracy: 0.9399 - val_loss: 0.1476 - val_accuracy: 0.9367
# Epoch 154/191
# 4179/4185 [============================>.] - ETA: 0s - loss: 0.1305 - accuracy: 0.9399
# Epoch 154: val_accuracy did not improve from 0.93844
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1305 - accuracy: 0.9399 - val_loss: 0.1423 - val_accuracy: 0.9363
# Epoch 155/191
# 4165/4185 [============================>.] - ETA: 0s - loss: 0.1307 - accuracy: 0.9402
# Epoch 155: val_accuracy did not improve from 0.93844
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1307 - accuracy: 0.9402 - val_loss: 0.1473 - val_accuracy: 0.9351
# Epoch 156/191
# 4184/4185 [============================>.] - ETA: 0s - loss: 0.1304 - accuracy: 0.9403
# Epoch 156: val_accuracy improved from 0.93844 to 0.93886, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1304 - accuracy: 0.9403 - val_loss: 0.1409 - val_accuracy: 0.9389
# Epoch 157/191
# 4154/4185 [============================>.] - ETA: 0s - loss: 0.1303 - accuracy: 0.9402
# Epoch 157: val_accuracy did not improve from 0.93886
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1303 - accuracy: 0.9402 - val_loss: 0.1457 - val_accuracy: 0.9361
# Epoch 158/191
# 4156/4185 [============================>.] - ETA: 0s - loss: 0.1305 - accuracy: 0.9402
# Epoch 158: val_accuracy did not improve from 0.93886
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1306 - accuracy: 0.9401 - val_loss: 0.1431 - val_accuracy: 0.9366
# Epoch 159/191
# 4168/4185 [============================>.] - ETA: 0s - loss: 0.1308 - accuracy: 0.9399
# Epoch 159: val_accuracy did not improve from 0.93886
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1307 - accuracy: 0.9399 - val_loss: 0.1475 - val_accuracy: 0.9376
# Epoch 160/191
# 4164/4185 [============================>.] - ETA: 0s - loss: 0.1303 - accuracy: 0.9402
# Epoch 160: val_accuracy did not improve from 0.93886
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1303 - accuracy: 0.9402 - val_loss: 0.1426 - val_accuracy: 0.9367
# Epoch 161/191
# 4184/4185 [============================>.] - ETA: 0s - loss: 0.1312 - accuracy: 0.9400
# Epoch 161: val_accuracy did not improve from 0.93886
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1312 - accuracy: 0.9400 - val_loss: 0.1418 - val_accuracy: 0.9380
# Epoch 162/191
# 4159/4185 [============================>.] - ETA: 0s - loss: 0.1314 - accuracy: 0.9403
# Epoch 162: val_accuracy did not improve from 0.93886
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1313 - accuracy: 0.9403 - val_loss: 0.1406 - val_accuracy: 0.9382
# Epoch 163/191
# 4156/4185 [============================>.] - ETA: 0s - loss: 0.1316 - accuracy: 0.9403
# Epoch 163: val_accuracy did not improve from 0.93886
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1315 - accuracy: 0.9403 - val_loss: 0.1483 - val_accuracy: 0.9330
# Epoch 164/191
# 4145/4185 [============================>.] - ETA: 0s - loss: 0.1299 - accuracy: 0.9404
# Epoch 164: val_accuracy did not improve from 0.93886
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1298 - accuracy: 0.9404 - val_loss: 0.1434 - val_accuracy: 0.9376
# Epoch 165/191
# 4166/4185 [============================>.] - ETA: 0s - loss: 0.1300 - accuracy: 0.9403
# Epoch 165: val_accuracy did not improve from 0.93886
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1299 - accuracy: 0.9403 - val_loss: 0.1455 - val_accuracy: 0.9368
# Epoch 166/191
# 4176/4185 [============================>.] - ETA: 0s - loss: 0.1299 - accuracy: 0.9407
# Epoch 166: val_accuracy did not improve from 0.93886
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1300 - accuracy: 0.9406 - val_loss: 0.1423 - val_accuracy: 0.9378
# Epoch 167/191
# 4182/4185 [============================>.] - ETA: 0s - loss: 0.1307 - accuracy: 0.9404
# Epoch 167: val_accuracy did not improve from 0.93886
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1307 - accuracy: 0.9404 - val_loss: 0.1439 - val_accuracy: 0.9352
# Epoch 168/191
# 4150/4185 [============================>.] - ETA: 0s - loss: 0.1297 - accuracy: 0.9407
# Epoch 168: val_accuracy did not improve from 0.93886
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1299 - accuracy: 0.9406 - val_loss: 0.1432 - val_accuracy: 0.9378
# Epoch 169/191
# 4173/4185 [============================>.] - ETA: 0s - loss: 0.1296 - accuracy: 0.9401
# Epoch 169: val_accuracy did not improve from 0.93886
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1296 - accuracy: 0.9401 - val_loss: 0.1421 - val_accuracy: 0.9378
# Epoch 170/191
# 4147/4185 [============================>.] - ETA: 0s - loss: 0.1301 - accuracy: 0.9400
# Epoch 170: val_accuracy did not improve from 0.93886
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1300 - accuracy: 0.9400 - val_loss: 0.1416 - val_accuracy: 0.9380
# Epoch 171/191
# 4168/4185 [============================>.] - ETA: 0s - loss: 0.1299 - accuracy: 0.9403
# Epoch 171: val_accuracy did not improve from 0.93886
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1300 - accuracy: 0.9402 - val_loss: 0.1423 - val_accuracy: 0.9376
# Epoch 172/191
# 4173/4185 [============================>.] - ETA: 0s - loss: 0.1296 - accuracy: 0.9409
# Epoch 172: val_accuracy did not improve from 0.93886
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1296 - accuracy: 0.9409 - val_loss: 0.1425 - val_accuracy: 0.9388
# Epoch 173/191
# 4147/4185 [============================>.] - ETA: 0s - loss: 0.1303 - accuracy: 0.9405
# Epoch 173: val_accuracy did not improve from 0.93886
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1303 - accuracy: 0.9405 - val_loss: 0.1452 - val_accuracy: 0.9378
# Epoch 174/191
# 4176/4185 [============================>.] - ETA: 0s - loss: 0.1299 - accuracy: 0.9406
# Epoch 174: val_accuracy did not improve from 0.93886
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1300 - accuracy: 0.9406 - val_loss: 0.1485 - val_accuracy: 0.9340
# Epoch 175/191
# 4182/4185 [============================>.] - ETA: 0s - loss: 0.1298 - accuracy: 0.9405
# Epoch 175: val_accuracy did not improve from 0.93886
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1298 - accuracy: 0.9405 - val_loss: 0.1453 - val_accuracy: 0.9369
# Epoch 176/191
# 4155/4185 [============================>.] - ETA: 0s - loss: 0.1293 - accuracy: 0.9404
# Epoch 176: val_accuracy improved from 0.93886 to 0.93913, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1295 - accuracy: 0.9403 - val_loss: 0.1409 - val_accuracy: 0.9391
# Epoch 177/191
# 4151/4185 [============================>.] - ETA: 0s - loss: 0.1299 - accuracy: 0.9406
# Epoch 177: val_accuracy did not improve from 0.93913
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1299 - accuracy: 0.9406 - val_loss: 0.1420 - val_accuracy: 0.9381
# Epoch 178/191
# 4179/4185 [============================>.] - ETA: 0s - loss: 0.1307 - accuracy: 0.9410
# Epoch 178: val_accuracy did not improve from 0.93913
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1306 - accuracy: 0.9410 - val_loss: 0.1500 - val_accuracy: 0.9357
# Epoch 179/191
# 4178/4185 [============================>.] - ETA: 0s - loss: 0.1301 - accuracy: 0.9407
# Epoch 179: val_accuracy did not improve from 0.93913
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1301 - accuracy: 0.9407 - val_loss: 0.1434 - val_accuracy: 0.9380
# Epoch 180/191
# 4175/4185 [============================>.] - ETA: 0s - loss: 0.1293 - accuracy: 0.9404
# Epoch 180: val_accuracy did not improve from 0.93913
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1293 - accuracy: 0.9404 - val_loss: 0.1418 - val_accuracy: 0.9380
# Epoch 181/191
# 4178/4185 [============================>.] - ETA: 0s - loss: 0.1294 - accuracy: 0.9409
# Epoch 181: val_accuracy did not improve from 0.93913
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1294 - accuracy: 0.9409 - val_loss: 0.1421 - val_accuracy: 0.9369
# Epoch 182/191
# 4181/4185 [============================>.] - ETA: 0s - loss: 0.1294 - accuracy: 0.9404
# Epoch 182: val_accuracy did not improve from 0.93913
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1294 - accuracy: 0.9404 - val_loss: 0.1439 - val_accuracy: 0.9380
# Epoch 183/191
# 4172/4185 [============================>.] - ETA: 0s - loss: 0.1296 - accuracy: 0.9411
# Epoch 183: val_accuracy did not improve from 0.93913
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1295 - accuracy: 0.9411 - val_loss: 0.1424 - val_accuracy: 0.9371
# Epoch 184/191
# 4172/4185 [============================>.] - ETA: 0s - loss: 0.1293 - accuracy: 0.9404
# Epoch 184: val_accuracy did not improve from 0.93913
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1293 - accuracy: 0.9404 - val_loss: 0.1432 - val_accuracy: 0.9379
# Epoch 185/191
# 4152/4185 [============================>.] - ETA: 0s - loss: 0.1293 - accuracy: 0.9407
# Epoch 185: val_accuracy did not improve from 0.93913
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1292 - accuracy: 0.9408 - val_loss: 0.1425 - val_accuracy: 0.9387
# Epoch 186/191
# 4170/4185 [============================>.] - ETA: 0s - loss: 0.1289 - accuracy: 0.9412
# Epoch 186: val_accuracy did not improve from 0.93913
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1290 - accuracy: 0.9412 - val_loss: 0.1438 - val_accuracy: 0.9367
# Epoch 187/191
# 4164/4185 [============================>.] - ETA: 0s - loss: 0.1303 - accuracy: 0.9409
# Epoch 187: val_accuracy did not improve from 0.93913
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1303 - accuracy: 0.9408 - val_loss: 0.1492 - val_accuracy: 0.9337
# Epoch 188/191
# 4166/4185 [============================>.] - ETA: 0s - loss: 0.1301 - accuracy: 0.9407
# Epoch 188: val_accuracy did not improve from 0.93913
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1300 - accuracy: 0.9407 - val_loss: 0.1465 - val_accuracy: 0.9382
# Epoch 189/191
# 4160/4185 [============================>.] - ETA: 0s - loss: 0.1290 - accuracy: 0.9407
# Epoch 189: val_accuracy did not improve from 0.93913
# 4185/4185 [==============================] - 6s 1ms/step - loss: 0.1289 - accuracy: 0.9408 - val_loss: 0.1444 - val_accuracy: 0.9374
# Epoch 190/191
# 4184/4185 [============================>.] - ETA: 0s - loss: 0.1295 - accuracy: 0.9408
# Epoch 190: val_accuracy did not improve from 0.93913
# 4185/4185 [==============================] - 7s 2ms/step - loss: 0.1295 - accuracy: 0.9408 - val_loss: 0.1418 - val_accuracy: 0.9381
# Epoch 191/191
# 4167/4185 [============================>.] - ETA: 0s - loss: 0.1293 - accuracy: 0.9411
# Epoch 191: val_accuracy did not improve from 0.93913
# 4185/4185 [==============================] - 6s 2ms/step - loss: 0.1293 - accuracy: 0.9411 - val_loss: 0.1419 - val_accuracy: 0.9384

# %%
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import load_model, Model

best_model =load_model(checkpoint_filepath)

# Display the summary of the loaded model
best_model.summary()

# Plot the architecture of the loaded model
plot_model(best_model, to_file='shallow_model_best_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 512)               10752
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 11265 (44.00 KB)
# Trainable params: 11265 (44.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## ANN Shallow Model Testing

# %%
import psutil
import time
from keras.models import load_model
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, average_precision_score
import tensorflow as tf

# Load the saved model
saved_model = load_model(checkpoint_filepath)

# Measure CPU and memory usage before prediction
cpu_usage_before = psutil.cpu_percent()
memory_usage_before = psutil.virtual_memory().used

# Record start time for prediction
start_time = time.time()

# Assuming X_test and y_test are your test data
# Predict on the test data
y_pred = saved_model.predict(X_test)

# Convert predicted probabilities to binary predictions (0 or 1)
y_pred_classes = (y_pred > 0.5).astype(int)

# Record end time for prediction
end_time = time.time()

# Measure CPU and memory usage after prediction
cpu_usage_after = psutil.cpu_percent()
memory_usage_after = psutil.virtual_memory().used

# Calculate prediction time
prediction_time = end_time - start_time

# Calculate performance metrics
accuracy = accuracy_score(y_test, y_pred_classes)
precision = precision_score(y_test, y_pred_classes)
recall = recall_score(y_test, y_pred_classes)
f1 = f1_score(y_test, y_pred_classes)
roc_auc = roc_auc_score(y_test, y_pred)
avg_precision = average_precision_score(y_test, y_pred)

# Compute confusion matrix
confusion_matrix = tf.math.confusion_matrix(y_test, y_pred_classes).numpy()

# Print performance metrics
print("Test Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("ROC AUC Score:", roc_auc)
print("Average Precision:", avg_precision)
print("Confusion Matrix:\n", confusion_matrix)

# Print CPU and memory usage, and prediction time
print("CPU usage before prediction:", cpu_usage_before)
print("Memory usage before prediction:", memory_usage_before)
print("CPU usage after prediction:", cpu_usage_after)
print("Memory usage after prediction:", memory_usage_after)
print("Prediction time:", prediction_time)
# Out:
# 291/291 [==============================] - 0s 833us/step
# Test Accuracy: 0.9418279569892473
# Precision: 0.9584914081678196
# Recall: 0.9236559139784947
# F1 Score: 0.9407512868251012
# ROC AUC Score: 0.9888913631633715
# Average Precision: 0.9895265353470281
# Confusion Matrix:
#  [[4464  186]
#  [ 355 4295]]
# CPU usage before prediction: 31.4
# Memory usage before prediction: 2148798464
# CPU usage after prediction: 37.7
# Memory usage after prediction: 2148798464
# Prediction time: 0.6886448860168457

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

# Calculate ROC curve
fpr, tpr, thresholds_roc = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Calculate Precision-Recall curve
precision, recall, thresholds_pr = precision_recall_curve(y_test, y_pred)
average_precision = average_precision_score(y_test, y_pred)

# Plot ROC curve and Precision-Recall curve as subplots
plt.figure(figsize=(15, 6))

# Plot ROC curve
plt.subplot(1, 2, 1)
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) - Shallow Model')
plt.legend(loc="lower right")

# Plot Precision-Recall curve
plt.subplot(1, 2, 2)
plt.plot(recall, precision, color='blue', lw=2, label='Precision-Recall curve (AP = %0.2f)' % average_precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## ANN Shallow Model Validation

# %%
import psutil
import time
import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, average_precision_score
import tensorflow as tf
from keras.models import load_model

# Load the best model saved by ModelCheckpoint
best_model = load_model(checkpoint_filepath)

# Measure CPU and memory usage before validation
cpu_usage_before = psutil.cpu_percent()
memory_usage_before = psutil.virtual_memory().used

# Record start time for validation
start_time = time.time()

# Validate the loaded best model using validation data
evaluation = best_model.evaluate(X_val, y_val)

# Record end time for validation
end_time = time.time()

# Measure CPU and memory usage after validation
cpu_usage_after = psutil.cpu_percent()
memory_usage_after = psutil.virtual_memory().used

# Calculate validation time
validation_time = end_time - start_time

# Print the evaluation metrics
print("Validation Loss:", evaluation[0])
print("Validation Accuracy:", evaluation[1])

# Assuming y_pred is the predicted probabilities and y_pred_classes are the predicted classes
y_pred = best_model.predict(X_val)
y_pred_classes = np.round(y_pred)

# Compute additional performance metrics
precision = precision_score(y_val, y_pred_classes)
recall = recall_score(y_val, y_pred_classes)
f1 = f1_score(y_val, y_pred_classes)
roc_auc = roc_auc_score(y_val, y_pred)
avg_precision = average_precision_score(y_val, y_pred)

# Compute confusion matrix
confusion_matrix = tf.math.confusion_matrix(y_val, y_pred_classes).numpy()

# Print additional performance metrics
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("ROC AUC Score:", roc_auc)
print("Average Precision:", avg_precision)
print("Confusion Matrix:\n", confusion_matrix)

# Print CPU and memory usage, and validation time
print("CPU usage before validation:", cpu_usage_before)
print("Memory usage before validation:", memory_usage_before)
print("CPU usage after validation:", cpu_usage_after)
print("Memory usage after validation:", memory_usage_after)
print("Validation time:", validation_time)
# Out:
# 291/291 [==============================] - 1s 1ms/step - loss: 0.1443 - accuracy: 0.9384
# Validation Loss: 0.14429712295532227
# Validation Accuracy: 0.9383870959281921
# 291/291 [==============================] - 0s 907us/step
# Precision: 0.9588116137744767
# Recall: 0.9161290322580645
# F1 Score: 0.9369844935664796
# ROC AUC Score: 0.9869503063938027
# Average Precision: 0.9877107064880837
# Confusion Matrix:
#  [[4467  183]
#  [ 390 4260]]
# CPU usage before validation: 10.9
# Memory usage before validation: 2164989952
# CPU usage after validation: 89.9
# Memory usage after validation: 2136326144
# Validation time: 0.8937404155731201

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

# Calculate ROC curve
fpr, tpr, thresholds_roc = roc_curve(y_val, y_pred)
roc_auc = auc(fpr, tpr)

# Calculate Precision-Recall curve
precision, recall, thresholds_pr = precision_recall_curve(y_val, y_pred)
average_precision = average_precision_score(y_val, y_pred)

# Plot ROC curve and Precision-Recall curve as subplots
plt.figure(figsize=(15, 6))

# Plot ROC curve
plt.subplot(1, 2, 1)
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) - Shallow Model')
plt.legend(loc="lower right")

# Plot Precision-Recall curve
plt.subplot(1, 2, 2)
plt.plot(recall, precision, color='blue', lw=2, label='Precision-Recall curve (AP = %0.2f)' % average_precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Deep model Hyperparameter tuning

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.regularizers import l1, l2  # Import l1 and l2 functions
from kerastuner import RandomSearch
from kerastuner import HyperParameters
import numpy as np
import time
import psutil
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, average_precision_score

modelname = "deep_ann_model"
hpt_method = "random search"

# Define a learning rate scheduler function
def lr_scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

# Update the model building function to include the new hyperparameters and configurations
def build_deep_ann_model(hp):
    model = Sequential()
    lu = hp['units']  # layer units
    # Input layer
    model.add(Dense(units=lu,
                    input_dim=len(features),
                    activation=hp['activation_layer1'],
                    kernel_initializer=hp['weight_initializer'],
                    kernel_regularizer=l1(hp['regularization_strength']) if hp['regularization_type'] == 'l1' else
                    l2(hp['regularization_strength']) if hp['regularization_type'] == 'l2' else None))

    # Hidden layers
    for i in range(1, 7):
        lu = lu / 2
        model.add(Dense(units=lu,
                        activation=hp[f'activation_layer{i + 1}'],
                        kernel_initializer=hp['weight_initializer'],
                        kernel_regularizer=l1(hp['regularization_strength']) if hp['regularization_type'] == 'l1' else
                        l2(hp['regularization_strength']) if hp['regularization_type'] == 'l2' else None))

        # Dropout layer (optional)
        if hp['use_dropout']:
            model.add(Dropout(rate=hp['dropout_rate']))

    # Output layer
    model.add(Dense(1, activation='sigmoid'))

    # Define the learning rate scheduler
    lr_schedule = LearningRateScheduler(lr_scheduler)

    # Choose the optimizer based on the hyperparameter value
    optimizer = None
    if hp['optimizer'] == 'adam':
        optimizer = tf.keras.optimizers.Adam(learning_rate=hp['learning_rate'])
    elif hp['optimizer'] == 'rmsprop':
        optimizer = tf.keras.optimizers.RMSprop(learning_rate=hp['learning_rate'])
    elif hp['optimizer'] == 'sgd':
        optimizer = tf.keras.optimizers.SGD(learning_rate=hp['learning_rate'], momentum=0.9)

    model.compile(optimizer=optimizer,
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    return model

# Create a HyperParameters object
hp = HyperParameters()
hp.Choice('units', [256])
# Add hyperparameters to the object
hp.Choice('activation_layer1', ['relu', 'tanh', 'leaky_relu'])
hp.Choice('activation_layer2', ['relu', 'tanh', 'leaky_relu'])
hp.Choice('activation_layer3', ['relu', 'tanh', 'leaky_relu'])
hp.Choice('activation_layer4', ['relu', 'tanh', 'leaky_relu'])
hp.Choice('activation_layer5', ['relu', 'tanh', 'leaky_relu'])
hp.Choice('activation_layer6', ['relu', 'tanh', 'leaky_relu'])
hp.Choice('activation_layer7', ['relu', 'tanh', 'leaky_relu'])
hp.Choice('optimizer', ['adam', 'rmsprop', 'sgd'])  # Hyperparameter for choosing the optimizer
hp.Choice('learning_rate', [0.01, 0.001, 0.0001])
hp.Choice('weight_initializer', ['random_normal', 'glorot_uniform', 'he_normal'])
hp.Choice('batch_size', [8, 16, 32, 64, 128, 256])
hp.Choice('regularization_type', ['','l1', 'l2'])
hp.Choice('regularization_strength', [0.0, 0.001, 0.01, 0.1])
hp.Choice('use_lr_scheduler', [True, False])  # Hyperparameter for choosing whether to use the learning rate scheduler
hp.Choice('use_dropout', [True, False])  # Hyperparameter for choosing whether to use dropout
hp.Float('dropout_rate', 0.0, 0.5, step=0.1)  # Dropout rate hyperparameter
# Out:
# 0.0

# %%
# Instantiate the RandomSearch tuner with the HyperParameters object
tuner = RandomSearch(
    build_deep_ann_model,
    objective='val_accuracy',
    max_trials=60,
    executions_per_trial=1,
    directory='my_dir',
    project_name='deep_ann_hy_tuning_RS2',
    hyperparameters=hp,  # Use the HyperParameters object
    overwrite=True  # Set to True if you want to overwrite existing results
)

# Record start time
start_time = time.time()

# Perform hyperparameter tuning
tuner.search(X_train, y_train,
             epochs=10,
             validation_split=0.2)

# Record end time
end_time = time.time()
elapsed_time = end_time - start_time

# Get the best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# Build the model with the best hyperparameters and train it
best_model = tuner.hypermodel.build(best_hps)
# Evaluate the best model on the test set
# Out:
# Trial 60 Complete [00h 02m 24s]
# val_accuracy: 0.9213560223579407
#
# Best val_accuracy So Far: 0.9312723875045776
# Total elapsed time: 02h 15m 11s

# %%
print("Best Hyperparameters:")
print(best_hps.values)
# Out:
# Best Hyperparameters:
# {'units': 256, 'activation_layer1': 'relu', 'activation_layer2': 'leaky_relu', 'activation_layer3': 'tanh', 'activation_layer4': 'relu', 'activation_layer5': 'leaky_relu', 'activation_layer6': 'leaky_relu', 'activation_layer7': 'relu', 'optimizer': 'adam', 'learning_rate': 0.001, 'weight_initializer': 'glorot_uniform', 'batch_size': 32, 'regularization_type': 'l1', 'regularization_strength': 0.0, 'use_lr_scheduler': 0, 'use_dropout': 0, 'dropout_rate': 0.0}

# %%
history = best_model.fit(X_train, y_train, epochs=350, validation_split=0.2)

# Record additional metrics
memory_usage = psutil.virtual_memory().used
cpu_usage = psutil.cpu_percent()

# Evaluate the best model on the test set
test_metrics = best_model.evaluate(X_test, y_test)

# Additional classification metrics
y_pred = best_model.predict(X_test)
y_pred_classes = np.round(y_pred)

precision = precision_score(y_test, np.round(y_pred))
recall = recall_score(y_test, np.round(y_pred))
f1 = f1_score(y_test, np.round(y_pred))
roc_auc = roc_auc_score(y_test, y_pred)
avg_precision = average_precision_score(y_test, y_pred)

confusion_matrix = tf.math.confusion_matrix(y_test, y_pred_classes).numpy()

# Display metrics
print("Test Metrics:")
print(" - Loss:", test_metrics[0])
print(" - Accuracy:", test_metrics[1])
print(" - Other Metrics:")
print("   - Precision:", precision)
print("   - Recall:", recall)
print("   - F1 Score:", f1)
print("   - ROC-AUC:", roc_auc)
print("   - Precision Score", avg_precision)
print("   - Confusion Matrix:")
print(confusion_matrix)



# Save experiment details in hp_array
experiment_details = {
    'model': modelname,
    'hpt_method':hpt_method,
    'best_hyperparameters': best_hps.values,
    'elapsed_time': elapsed_time,
    'memory_usage': memory_usage,
    'cpu_usage': cpu_usage,
    'precision': precision,
    'recall': recall,
    'f1_score': f1,
    'roc_auc': roc_auc,
    'confusion_matrix': confusion_matrix.tolist(),
}
print(experiment_details)
hp_array.append(experiment_details)
# Out:
# Epoch 1/350
# 4185/4185 [==============================] - 19s 4ms/step - loss: 0.2560 - accuracy: 0.8984 - val_loss: 0.1771 - val_accuracy: 0.9183
# Epoch 2/350
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1673 - accuracy: 0.9194 - val_loss: 0.1619 - val_accuracy: 0.9220
# Epoch 3/350
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1611 - accuracy: 0.9223 - val_loss: 0.1630 - val_accuracy: 0.9235
# Epoch 4/350
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1567 - accuracy: 0.9255 - val_loss: 0.1536 - val_accuracy: 0.9263
# Epoch 5/350
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1543 - accuracy: 0.9262 - val_loss: 0.1561 - val_accuracy: 0.9250
# Epoch 6/350
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1511 - accuracy: 0.9284 - val_loss: 0.1492 - val_accuracy: 0.9301
# Epoch 7/350
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1496 - accuracy: 0.9294 - val_loss: 0.1491 - val_accuracy: 0.9304
# Epoch 8/350
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1481 - accuracy: 0.9304 - val_loss: 0.1485 - val_accuracy: 0.9307
# Epoch 9/350
# 4185/4185 [==============================] - 11s 3ms/step - loss: 0.1470 - accuracy: 0.9304 - val_loss: 0.1471 - val_accuracy: 0.9309
# Epoch 10/350
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1463 - accuracy: 0.9309 - val_loss: 0.1486 - val_accuracy: 0.9280
# Epoch 11/350
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1452 - accuracy: 0.9311 - val_loss: 0.1494 - val_accuracy: 0.9295
# Epoch 12/350
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1445 - accuracy: 0.9320 - val_loss: 0.1445 - val_accuracy: 0.9320
# Epoch 13/350
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1439 - accuracy: 0.9326 - val_loss: 0.1451 - val_accuracy: 0.9318
# Epoch 14/350
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1434 - accuracy: 0.9326 - val_loss: 0.1442 - val_accuracy: 0.9339
# Epoch 15/350
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1429 - accuracy: 0.9333 - val_loss: 0.1485 - val_accuracy: 0.9296
# Epoch 16/350
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1423 - accuracy: 0.9331 - val_loss: 0.1453 - val_accuracy: 0.9334
# Epoch 17/350
# 4185/4185 [==============================] - 11s 3ms/step - loss: 0.1415 - accuracy: 0.9334 - val_loss: 0.1496 - val_accuracy: 0.9292
# Epoch 18/350
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1412 - accuracy: 0.9338 - val_loss: 0.1440 - val_accuracy: 0.9344
# Epoch 19/350
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1404 - accuracy: 0.9336 - val_loss: 0.1496 - val_accuracy: 0.9280
# Epoch 20/350
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1403 - accuracy: 0.9341 - val_loss: 0.1427 - val_accuracy: 0.9331
# Epoch 21/350
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.
350
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1265 - accuracy: 0.9414 - val_loss: 0.1451 - val_accuracy: 0.9347
# Epoch 328/350
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1274 - accuracy: 0.9411 - val_loss: 0.1380 - val_accuracy: 0.9365
# Epoch 329/350
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1256 - accuracy: 0.9422 - val_loss: 0.1400 - val_accuracy: 0.9358
# Epoch 330/350
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1283 - accuracy: 0.9408 - val_loss: 0.1384 - val_accuracy: 0.9358
# Epoch 331/350
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1284 - accuracy: 0.9409 - val_loss: 0.1428 - val_accuracy: 0.9351
# Epoch 332/350
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1303 - accuracy: 0.9406 - val_loss: 0.1437 - val_accuracy: 0.9353
# Epoch 333/350
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1288 - accuracy: 0.9406 - val_loss: 0.1406 - val_accuracy: 0.9347
# Epoch 334/350
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1297 - accuracy: 0.9398 - val_loss: 0.1421 - val_accuracy: 0.9349
# Epoch 335/350
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1274 - accuracy: 0.9409 - val_loss: 0.1374 - val_accuracy: 0.9370
# Epoch 336/350
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1277 - accuracy: 0.9405 - val_loss: 0.1389 - val_accuracy: 0.9363
# Epoch 337/350
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1276 - accuracy: 0.9406 - val_loss: 0.1391 - val_accuracy: 0.9367
# Epoch 338/350
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1275 - accuracy: 0.9403 - val_loss: 0.1429 - val_accuracy: 0.9353
# Epoch 339/350
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1277 - accuracy: 0.9402 - val_loss: 0.1382 - val_accuracy: 0.9366
# Epoch 340/350
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1262 - accuracy: 0.9418 - val_loss: 0.1428 - val_accuracy: 0.9352
# Epoch 341/350
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1269 - accuracy: 0.9410 - val_loss: 0.1417 - val_accuracy: 0.9352
# Epoch 342/350
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1260 - accuracy: 0.9412 - val_loss: 0.1460 - val_accuracy: 0.9355
# Epoch 343/350
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1283 - accuracy: 0.9403 - val_loss: 0.1390 - val_accuracy: 0.9356
# Epoch 344/350
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1281 - accuracy: 0.9413 - val_loss: 0.1453 - val_accuracy: 0.9336
# Epoch 345/350
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1299 - accuracy: 0.9396 - val_loss: 0.1375 - val_accuracy: 0.9361
# Epoch 346/350
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1273 - accuracy: 0.9406 - val_loss: 0.1468 - val_accuracy: 0.9320
# Epoch 347/350
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1270 - accuracy: 0.9412 - val_loss: 0.1382 - val_accuracy: 0.9360
# Epoch 348/350
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1282 - accuracy: 0.9408 - val_loss: 0.1406 - val_accuracy: 0.9366
# Epoch 349/350
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1271 - accuracy: 0.9412 - val_loss: 0.1383 - val_accuracy: 0.9366
# Epoch 350/350
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1285 - accuracy: 0.9408 - val_loss: 0.1417 - val_accuracy: 0.9346
# 291/291 [==============================] - 0s 2ms/step - loss: 0.1290 - accuracy: 0.9434
# 291/291 [==============================] - 1s 2ms/step
# Test Metrics:
#  - Loss: 0.1290043294429779
#  - Accuracy: 0.943440854549408
#  - Other Metrics:
#    - Precision: 0.9582222222222222
#    - Recall: 0.9273118279569893
#    - F1 Score: 0.9425136612021858
#    - ROC-AUC: 0.9890556596138282
#    - Precision Score 0.9896804994704472
#    - Confusion Matrix:
# [[4462  188]
#  [ 338 4312]]
# {'model': 'deep_ann_model', 'hpt_method': 'random search', 'best_hyperparameters': {'units': 256, 'activation_layer1': 'relu', 'activation_layer2': 'leaky_relu', 'activation_layer3': 'tanh', 'activation_layer4': 'relu', 'activation_layer5': 'leaky_relu', 'activation_layer6': 'leaky_relu', 'activation_layer7': 'relu', 'optimizer': 'adam', 'learning_rate': 0.001, 'weight_initializer': 'glorot_uniform', 'batch_size': 32, 'regularization_type': 'l1', 'regularization_strength': 0.0, 'use_lr_scheduler': 0, 'use_dropout': 0, 'dropout_rate': 0.0}, 'elapsed_time': 8110.586231946945, 'memory_usage': 2353246208, 'cpu_usage': 72.8, 'precision': 0.9582222222222222, 'recall': 0.9273118279569893, 'f1_score': 0.9425136612021858, 'roc_auc': 0.9890556596138282, 'confusion_matrix': [[4462, 188], [338, 4312]]}

# %%
max_val_acc_epoch = np.argmax(history.history['val_accuracy'])
max_val_acc = history.history['val_accuracy'][max_val_acc_epoch]
min_val_loss_epoch = np.argmin(history.history['val_loss'])
min_val_loss = history.history['val_loss'][min_val_loss_epoch]

print("Epoch with maximum validation accuracy:", max_val_acc_epoch)
print("Maximum validation accuracy:", max_val_acc)
print("Epoch with minimum validation loss:", min_val_loss_epoch)
print("Minimum validation loss:", min_val_loss)
# Out:
# Epoch with maximum validation accuracy: 217
# Maximum validation accuracy: 0.938739538192749
# Epoch with minimum validation loss: 265
# Minimum validation loss: 0.1348196566104889

# %%
import matplotlib.pyplot as plt

# Create a figure with subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plot accuracy
axes[0].plot(history.history['accuracy'], label='Training Accuracy')
axes[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
axes[0].axvline(x=217, color='g', linestyle='--', label='Epoch 217')  # Vertical line at epoch 60
axes[0].set_title('Model Accuracy')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Plot loss
axes[1].plot(history.history['loss'], label='Training Loss')
axes[1].plot(history.history['val_loss'], label='Validation Loss')
axes[1].axvline(x=265, color='g', linestyle='--', label='Epoch 265')  # Vertical line at epoch 60
axes[1].set_title('Model Loss')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

# Calculate ROC curve
fpr, tpr, thresholds_roc = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Calculate Precision-Recall curve
precision, recall, thresholds_pr = precision_recall_curve(y_test, y_pred)
average_precision = average_precision_score(y_test, y_pred)

# Plot ROC curve and Precision-Recall curve as subplots
plt.figure(figsize=(15, 6))

# Plot ROC curve
plt.subplot(1, 2, 1)
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) - Shallow Model')
plt.legend(loc="lower right")

# Plot Precision-Recall curve
plt.subplot(1, 2, 2)
plt.plot(recall, precision, color='blue', lw=2, label='Precision-Recall curve (AP = %0.2f)' % average_precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

plt.tight_layout()
plt.show()

# %%
# Build the model with the best hyperparameters and train it
best_model = tuner.hypermodel.build(best_hps)
history = best_model.fit(X_train, y_train, epochs=217, validation_split=0.2)

# Record additional metrics
memory_usage = psutil.virtual_memory().used
cpu_usage = psutil.cpu_percent()

# Evaluate the best model on the test set
print("Best Hyperparameters:")
print(best_hps.values)


# Evaluate the best model on the test set
test_metrics = best_model.evaluate(X_test, y_test)

# Additional classification metrics
y_pred = best_model.predict(X_test)
y_pred_classes = np.round(y_pred)

precision = precision_score(y_test, np.round(y_pred))
recall = recall_score(y_test, np.round(y_pred))
f1 = f1_score(y_test, np.round(y_pred))
roc_auc = roc_auc_score(y_test, y_pred)
avg_precision = average_precision_score(y_test, y_pred)

confusion_matrix = tf.math.confusion_matrix(y_test, y_pred_classes).numpy()


# Display metrics
print("Test Metrics:")
print(" - Loss:", test_metrics[0])
print(" - Accuracy:", test_metrics[1])
print(" - Other Metrics:")
print("   - Precision:", precision)
print("   - Recall:", recall)
print("   - F1 Score:", f1)
print("   - ROC-AUC:", roc_auc)
print("   - Precision Score", avg_precision)
print("   - Confusion Matrix:")
print(confusion_matrix)



# Save experiment details in hp_array
experiment_details = {
    'model': modelname,
    'hpt_method':hpt_method,
    'best_hyperparameters': best_hps.values,
    'elapsed_time': elapsed_time,
    'memory_usage': memory_usage,
    'cpu_usage': cpu_usage,
    'precision': precision,
    'recall': recall,
    'f1_score': f1,
    'roc_auc': roc_auc,
    'confusion_matrix': confusion_matrix.tolist(),
}
print(experiment_details)
hp_array.append(experiment_details)
# Out:
# Epoch 1/217
# 4185/4185 [==============================] - 27s 5ms/step - loss: 0.1973 - accuracy: 0.9018 - val_loss: 0.1714 - val_accuracy: 0.9174
# Epoch 2/217
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1700 - accuracy: 0.9162 - val_loss: 0.1644 - val_accuracy: 0.9202
# Epoch 3/217
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1618 - accuracy: 0.9220 - val_loss: 0.1710 - val_accuracy: 0.9143
# Epoch 4/217
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1563 - accuracy: 0.9255 - val_loss: 0.1548 - val_accuracy: 0.9269
# Epoch 5/217
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1535 - accuracy: 0.9274 - val_loss: 0.1518 - val_accuracy: 0.9297
# Epoch 6/217
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1515 - accuracy: 0.9291 - val_loss: 0.1531 - val_accuracy: 0.9263
# Epoch 7/217
# 4185/4185 [==============================] - 11s 3ms/step - loss: 0.1501 - accuracy: 0.9293 - val_loss: 0.1484 - val_accuracy: 0.9314
# Epoch 8/217
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1487 - accuracy: 0.9304 - val_loss: 0.1472 - val_accuracy: 0.9303
# Epoch 9/217
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1470 - accuracy: 0.9306 - val_loss: 0.1484 - val_accuracy: 0.9317
# Epoch 10/217
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1458 - accuracy: 0.9320 - val_loss: 0.1460 - val_accuracy: 0.9323
# Epoch 11/217
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.
217
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1297 - accuracy: 0.9396 - val_loss: 0.1399 - val_accuracy: 0.9361
# Epoch 132/217
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1294 - accuracy: 0.9395 - val_loss: 0.1418 - val_accuracy: 0.9342
# Epoch 133/217
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1300 - accuracy: 0.9393 - val_loss: 0.1396 - val_accuracy: 0.9369
# Epoch 134/217
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1293 - accuracy: 0.9400 - val_loss: 0.1389 - val_accuracy: 0.9363
# Epoch 135/217
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1299 - accuracy: 0.9392 - val_loss: 0.1393 - val_accuracy: 0.9379
# Epoch 136/217
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1305 - accuracy: 0.9390 - val_loss: 0.1369 - val_accuracy: 0.9368
# Epoch 137/217
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1297 - accuracy: 0.9402 - val_loss: 0.1379 - val_accuracy: 0.9360
# Epoch 138/217
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1295 - accuracy: 0.9394 - val_loss: 0.1396 - val_accuracy: 0.9354
# Epoch 139/217
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1295 - accuracy: 0.9393 - val_loss: 0.1402 - val_accuracy: 0.9348
# Epoch 140/217
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1293 - accuracy: 0.9387 - val_loss: 0.1407 - val_accuracy: 0.9357
# Epoch 141/217
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1301 - accuracy: 0.9388 - val_loss: 0.1442 - val_accuracy: 0.9350
# Epoch 142/217
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1294 - accuracy: 0.9393 - val_loss: 0.1394 - val_accuracy: 0.9360
# Epoch 143/217
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1299 - accuracy: 0.9387 - val_loss: 0.1373 - val_accuracy: 0.9372
# Epoch 144/217
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1289 - accuracy: 0.9396 - val_loss: 0.1371 - val_accuracy: 0.9364
# Epoch 145/217
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1287 - accuracy: 0.9398 - val_loss: 0.1372 - val_accuracy: 0.9372
# Epoch 146/217
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1289 - accuracy: 0.9392 - val_loss: 0.1376 - val_accuracy: 0.9361
# Epoch 147/217
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1291 - accuracy: 0.9398 - val_loss: 0.1398 - val_accuracy: 0.9346
# Epoch 148/217
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1290 - accuracy: 0.9396 - val_loss: 0.1372 - val_accuracy: 0.9360
# Epoch 149/217
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1282 - accuracy: 0.9398 - val_loss: 0.1351 - val_accuracy: 0.9384
# Epoch 150/217
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1269 - accuracy: 0.9402 - val_loss: 0.1383 - val_accuracy: 0.9371
# Epoch 151/217
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1280 - accuracy: 0.9400 - val_loss: 0.1395 - val_accuracy: 0.9361
# Epoch 152/217
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1278 - accuracy: 0.9401 - val_loss: 0.1391 - val_accuracy: 0.9368
# Epoch 153/217
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1288 - accuracy: 0.9400 - val_loss: 0.1380 - val_accuracy: 0.9370
# Epoch 154/217
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1300 - accuracy: 0.9392 - val_loss: 0.1397 - val_accuracy: 0.9344
# Epoch 155/217
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1308 - accuracy: 0.9388 - val_loss: 0.1405 - val_accuracy: 0.9365
# Epoch 156/217
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1312 - accuracy: 0.9387 - val_loss: 0.1387 - val_accuracy: 0.9371
# Epoch 157/217
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1293 - accuracy: 0.9394 - val_loss: 0.1417 - val_accuracy: 0.9353
# Epoch 158/217
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1280 - accuracy: 0.9402 - val_loss: 0.1376 - val_accuracy: 0.9374
# Epoch 159/217
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1281 - accuracy: 0.9399 - val_loss: 0.1375 - val_accuracy: 0.9365
# Epoch 160/217
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1293 - accuracy: 0.9395 - val_loss: 0.1401 - val_accuracy: 0.9361
# Epoch 161/217
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1292 - accuracy: 0.9401 - val_loss: 0.1370 - val_accuracy: 0.9363
# Epoch 162/217
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1289 - accuracy: 0.9398 - val_loss: 0.1417 - val_accuracy: 0.9324
# Epoch 163/217
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.
217
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1293 - accuracy: 0.9395 - val_loss: 0.1394 - val_accuracy: 0.9355
# Epoch 196/217
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1293 - accuracy: 0.9394 - val_loss: 0.1461 - val_accuracy: 0.9326
# Epoch 197/217
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1297 - accuracy: 0.9390 - val_loss: 0.1396 - val_accuracy: 0.9361
# Epoch 198/217
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1289 - accuracy: 0.9396 - val_loss: 0.1411 - val_accuracy: 0.9354
# Epoch 199/217
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1299 - accuracy: 0.9383 - val_loss: 0.1409 - val_accuracy: 0.9358
# Epoch 200/217
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1303 - accuracy: 0.9383 - val_loss: 0.1410 - val_accuracy: 0.9345
# Epoch 201/217
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1312 - accuracy: 0.9389 - val_loss: 0.1376 - val_accuracy: 0.9377
# Epoch 202/217
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1294 - accuracy: 0.9397 - val_loss: 0.1380 - val_accuracy: 0.9363
# Epoch 203/217
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1298 - accuracy: 0.9393 - val_loss: 0.1418 - val_accuracy: 0.9338
# Epoch 204/217
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1291 - accuracy: 0.9393 - val_loss: 0.1357 - val_accuracy: 0.9373
# Epoch 205/217
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1300 - accuracy: 0.9399 - val_loss: 0.1433 - val_accuracy: 0.9335
# Epoch 206/217
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1323 - accuracy: 0.9389 - val_loss: 0.1392 - val_accuracy: 0.9364
# Epoch 207/217
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1330 - accuracy: 0.9385 - val_loss: 0.1433 - val_accuracy: 0.9349
# Epoch 208/217
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1307 - accuracy: 0.9387 - val_loss: 0.1391 - val_accuracy: 0.9356
# Epoch 209/217
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1295 - accuracy: 0.9394 - val_loss: 0.1394 - val_accuracy: 0.9359
# Epoch 210/217
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1294 - accuracy: 0.9392 - val_loss: 0.1366 - val_accuracy: 0.9372
# Epoch 211/217
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1311 - accuracy: 0.9385 - val_loss: 0.1428 - val_accuracy: 0.9333
# Epoch 212/217
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1313 - accuracy: 0.9384 - val_loss: 0.1395 - val_accuracy: 0.9362
# Epoch 213/217
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1302 - accuracy: 0.9387 - val_loss: 0.1515 - val_accuracy: 0.9306
# Epoch 214/217
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1332 - accuracy: 0.9379 - val_loss: 0.1412 - val_accuracy: 0.9352
# Epoch 215/217
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1312 - accuracy: 0.9390 - val_loss: 0.1395 - val_accuracy: 0.9353
# Epoch 216/217
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1309 - accuracy: 0.9392 - val_loss: 0.1444 - val_accuracy: 0.9333
# Epoch 217/217
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1295 - accuracy: 0.9399 - val_loss: 0.1387 - val_accuracy: 0.9357
# Best Hyperparameters:
# {'units': 256, 'activation_layer1': 'relu', 'activation_layer2': 'leaky_relu', 'activation_layer3': 'tanh', 'activation_layer4': 'relu', 'activation_layer5': 'leaky_relu', 'activation_layer6': 'leaky_relu', 'activation_layer7': 'relu', 'optimizer': 'adam', 'learning_rate': 0.001, 'weight_initializer': 'glorot_uniform', 'batch_size': 32, 'regularization_type': 'l1', 'regularization_strength': 0.0, 'use_lr_scheduler': 0, 'use_dropout': 0, 'dropout_rate': 0.0}
# 291/291 [==============================] - 1s 2ms/step - loss: 0.1323 - accuracy: 0.9399
# 291/291 [==============================] - 1s 2ms/step
# Test Metrics:
#  - Loss: 0.13226871192455292
#  - Accuracy: 0.9398924708366394
#  - Other Metrics:
#    - Precision: 0.9639374007711499
#    - Recall: 0.9139784946236559
#    - F1 Score: 0.938293409868639
#    - ROC-AUC: 0.9886449762978379
#    - Precision Score 0.9893994670942098
#    - Confusion Matrix:
# [[4491  159]
#  [ 400 4250]]
# {'model': 'deep_ann_model', 'hpt_method': 'random search', 'best_hyperparameters': {'units': 256, 'activation_layer1': 'relu', 'activation_layer2': 'leaky_relu', 'activation_layer3': 'tanh', 'activation_layer4': 'relu', 'activation_layer5': 'leaky_relu', 'activation_layer6': 'leaky_relu', 'activation_layer7': 'relu', 'optimizer': 'adam', 'learning_rate': 0.001, 'weight_initializer': 'glorot_uniform', 'batch_size': 32, 'regularization_type': 'l1', 'regularization_strength': 0.0, 'use_lr_scheduler': 0, 'use_dropout': 0, 'dropout_rate': 0.0}, 'elapsed_time': 8110.586231946945, 'memory_usage': 2635980800, 'cpu_usage': 61.8, 'precision': 0.9639374007711499, 'recall': 0.9139784946236559, 'f1_score': 0.938293409868639, 'roc_auc': 0.9886449762978379, 'confusion_matrix': [[4491, 159], [400, 4250]]}

# %%
max_val_acc_epoch = np.argmax(history.history['val_accuracy'])
max_val_acc = history.history['val_accuracy'][max_val_acc_epoch]
min_val_loss_epoch = np.argmin(history.history['val_loss'])
min_val_loss = history.history['val_loss'][min_val_loss_epoch]

print("Epoch with maximum validation accuracy:", max_val_acc_epoch)
print("Maximum validation accuracy:", max_val_acc)
print("Epoch with minimum validation loss:", min_val_loss_epoch)
print("Minimum validation loss:", min_val_loss)
# Out:
# Epoch with maximum validation accuracy: 76
# Maximum validation accuracy: 0.938470721244812
# Epoch with minimum validation loss: 148
# Minimum validation loss: 0.13510599732398987

# %%
import matplotlib.pyplot as plt

# Create a figure with subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plot accuracy
axes[0].plot(history.history['accuracy'], label='Training Accuracy')
axes[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
axes[0].axvline(x=max_val_acc_epoch, color='g', linestyle='--', label=f'Epoch {max_val_acc_epoch}')  # Vertical line at epoch 60
axes[0].set_title('Model Accuracy')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Plot loss
axes[1].plot(history.history['loss'], label='Training Loss')
axes[1].plot(history.history['val_loss'], label='Validation Loss')
axes[1].axvline(x=min_val_loss_epoch, color='g', linestyle='--', label=f'Epoch {min_val_loss_epoch}')  # Vertical line at epoch 60
axes[1].set_title('Model Loss')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

# Calculate ROC curve
fpr, tpr, thresholds_roc = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Calculate Precision-Recall curve
precision, recall, thresholds_pr = precision_recall_curve(y_test, y_pred)
average_precision = average_precision_score(y_test, y_pred)

# Plot ROC curve and Precision-Recall curve as subplots
plt.figure(figsize=(15, 6))

# Plot ROC curve
plt.subplot(1, 2, 1)
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) - Shallow Model')
plt.legend(loc="lower right")

# Plot Precision-Recall curve
plt.subplot(1, 2, 2)
plt.plot(recall, precision, color='blue', lw=2, label='Precision-Recall curve (AP = %0.2f)' % average_precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

plt.tight_layout()
plt.show()

# %%
from keras.callbacks import ModelCheckpoint

# Define the filepath to save the model
checkpoint_filepath = deep_model_path_best_hp

# Define a ModelCheckpoint callback to save the model with the highest validation accuracy
checkpoint = ModelCheckpoint(checkpoint_filepath,
                             monitor='val_accuracy',
                             save_best_only=True,
                             mode='max',
                             verbose=1)

# Build the model with the best hyperparameters
best_model = tuner.hypermodel.build(best_hps)

# Train the model with early stopping and ModelCheckpoint callback
history = best_model.fit(X_train, y_train,
                          epochs=max_val_acc_epoch,
                          validation_split=0.2,
                          callbacks=[checkpoint])
# Out:
# Epoch 1/76
# 4182/4185 [============================>.] - ETA: 0s - loss: 0.6932 - accuracy: 0.5001
# Epoch 1: val_accuracy improved from -inf to 0.49713, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models14003/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 15s 3ms/step - loss: 0.6932 - accuracy: 0.5001 - val_loss: 0.6932 - val_accuracy: 0.4971
# Epoch 2/76
# 4184/4185 [============================>.] - ETA: 0s - loss: 0.6932 - accuracy: 0.4981
# Epoch 2: val_accuracy did not improve from 0.49713
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.6932 - accuracy: 0.4980 - val_loss: 0.6932 - val_accuracy: 0.4971
# Epoch 3/76
# 4174/4185 [============================>.] - ETA: 0s - loss: 0.6932 - accuracy: 0.5007
# Epoch 3: val_accuracy did not improve from 0.49713
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.6932 - accuracy: 0.5007 - val_loss: 0.6934 - val_accuracy: 0.4971
# Epoch 4/76
# 4163/4185 [============================>.] - ETA: 0s - loss: 0.6932 - accuracy: 0.5018
# Epoch 4: val_accuracy improved from 0.49713 to 0.50287, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models14003/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.6932 - accuracy: 0.5016 - val_loss: 0.6931 - val_accuracy: 0.5029
# Epoch 5/76
# 4170/4185 [============================>.] - ETA: 0s - loss: 0.6932 - accuracy: 0.4997
# Epoch 5: val_accuracy did not improve from 0.50287
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.6932 - accuracy: 0.4996 - val_loss: 0.6931 - val_accuracy: 0.5029
# Epoch 6/76
# 4177/4185 [============================>.] - ETA: 0s - loss: 0.6932 - accuracy: 0.5017
# Epoch 6: val_accuracy did not improve from 0.50287
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.6932 - accuracy: 0.5017 - val_loss: 0.6931 - val_accuracy: 0
ms/step - loss: 0.6932 - accuracy: 0.4991 - val_loss: 0.6931 - val_accuracy: 0.5029
# Epoch 76/76
# 4171/4185 [============================>.] - ETA: 0s - loss: 0.6932 - accuracy: 0.4999
# Epoch 76: val_accuracy did not improve from 0.50287
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.4971

# %%
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import load_model, Model

best_model =load_model(checkpoint_filepath)

# Display the summary of the loaded model
best_model.summary()

# Plot the architecture of the loaded model
plot_model(best_model, to_file='deep_model_best_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 256)               5376
#
#  dense_25 (Dense)            (None, 128)               32896
#
#  dense_26 (Dense)            (None, 64)                8256
#
#  dense_27 (Dense)            (None, 32)                2080
#
#  dense_28 (Dense)            (None, 16)                528
#
#  dense_29 (Dense)            (None, 8)                 136
#
#  dense_30 (Dense)            (None, 4)                 36
#
#  dense_31 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 49313 (192.63 KB)
# Trainable params: 49313 (192.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Testing Deep Model

# %%
import psutil
import time
from keras.models import load_model
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, average_precision_score
import tensorflow as tf

# Load the saved model
saved_model = load_model(checkpoint_filepath)

# Measure CPU and memory usage before prediction
cpu_usage_before = psutil.cpu_percent()
memory_usage_before = psutil.virtual_memory().used

# Record start time for prediction
start_time = time.time()

# Assuming X_test and y_test are your test data
# Predict on the test data
y_pred = saved_model.predict(X_test)

# Convert predicted probabilities to binary predictions (0 or 1)
y_pred_classes = (y_pred > 0.5).astype(int)

# Record end time for prediction
end_time = time.time()

# Measure CPU and memory usage after prediction
cpu_usage_after = psutil.cpu_percent()
memory_usage_after = psutil.virtual_memory().used

# Calculate prediction time
prediction_time = end_time - start_time

# Calculate performance metrics
accuracy = accuracy_score(y_test, y_pred_classes)
precision = precision_score(y_test, y_pred_classes)
recall = recall_score(y_test, y_pred_classes)
f1 = f1_score(y_test, y_pred_classes)
roc_auc = roc_auc_score(y_test, y_pred)
avg_precision = average_precision_score(y_test, y_pred)

# Compute confusion matrix
confusion_matrix = tf.math.confusion_matrix(y_test, y_pred_classes).numpy()

# Print performance metrics
print("Test Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("ROC AUC Score:", roc_auc)
print("Average Precision:", avg_precision)
print("Confusion Matrix:\n", confusion_matrix)

# Print CPU and memory usage, and prediction time
print("CPU usage before prediction:", cpu_usage_before)
print("Memory usage before prediction:", memory_usage_before)
print("CPU usage after prediction:", cpu_usage_after)
print("Memory usage after prediction:", memory_usage_after)
print("Prediction time:", prediction_time)
# Out:
# 291/291 [==============================] - 0s 1ms/step
# Test Accuracy: 0.5
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
# ROC AUC Score: 0.5
# Average Precision: 0.5
# Confusion Matrix:
#  [[4650    0]
#  [4650    0]]
# CPU usage before prediction: 61.8
# Memory usage before prediction: 2535616512
# CPU usage after prediction: 63.2
# Memory usage after prediction: 2535481344
# Prediction time: 0.6231198310852051
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

# Calculate ROC curve
fpr, tpr, thresholds_roc = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Calculate Precision-Recall curve
precision, recall, thresholds_pr = precision_recall_curve(y_test, y_pred)
average_precision = average_precision_score(y_test, y_pred)

# Plot ROC curve and Precision-Recall curve as subplots
plt.figure(figsize=(15, 6))

# Plot ROC curve
plt.subplot(1, 2, 1)
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) - Shallow Model')
plt.legend(loc="lower right")

# Plot Precision-Recall curve
plt.subplot(1, 2, 2)
plt.plot(recall, precision, color='blue', lw=2, label='Precision-Recall curve (AP = %0.2f)' % average_precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Deep Model Validation

# %%
import psutil
import time
import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, average_precision_score
import tensorflow as tf
from keras.models import load_model

# Load the best model saved by ModelCheckpoint
best_model = load_model(checkpoint_filepath)

# Measure CPU and memory usage before validation
cpu_usage_before = psutil.cpu_percent()
memory_usage_before = psutil.virtual_memory().used

# Record start time for validation
start_time = time.time()

# Validate the loaded best model using validation data
evaluation = best_model.evaluate(X_val, y_val)

# Record end time for validation
end_time = time.time()

# Measure CPU and memory usage after validation
cpu_usage_after = psutil.cpu_percent()
memory_usage_after = psutil.virtual_memory().used

# Calculate validation time
validation_time = end_time - start_time

# Print the evaluation metrics
print("Validation Loss:", evaluation[0])
print("Validation Accuracy:", evaluation[1])

# Assuming y_pred is the predicted probabilities and y_pred_classes are the predicted classes
y_pred = best_model.predict(X_val)
y_pred_classes = np.round(y_pred)

# Compute additional performance metrics
precision = precision_score(y_val, y_pred_classes)
recall = recall_score(y_val, y_pred_classes)
f1 = f1_score(y_val, y_pred_classes)
roc_auc = roc_auc_score(y_val, y_pred)
avg_precision = average_precision_score(y_val, y_pred)

# Compute confusion matrix
confusion_matrix = tf.math.confusion_matrix(y_val, y_pred_classes).numpy()

# Print additional performance metrics
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("ROC AUC Score:", roc_auc)
print("Average Precision:", avg_precision)
print("Confusion Matrix:\n", confusion_matrix)

# Print CPU and memory usage, and validation time
print("CPU usage before validation:", cpu_usage_before)
print("Memory usage before validation:", memory_usage_before)
print("CPU usage after validation:", cpu_usage_after)
print("Memory usage after validation:", memory_usage_after)
print("Validation time:", validation_time)
# Out:
# 291/291 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.5000
# Validation Loss: 0.693146288394928
# Validation Accuracy: 0.5
# 291/291 [==============================] - 1s 2ms/step
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
# ROC AUC Score: 0.5
# Average Precision: 0.5
# Confusion Matrix:
#  [[4650    0]
#  [4650    0]]
# CPU usage before validation: 46.3
# Memory usage before validation: 2946502656
# CPU usage after validation: 62.4
# Memory usage after validation: 2946371584
# Validation time: 0.8911702632904053
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

# Calculate ROC curve
fpr, tpr, thresholds_roc = roc_curve(y_val, y_pred)
roc_auc = auc(fpr, tpr)

# Calculate Precision-Recall curve
precision, recall, thresholds_pr = precision_recall_curve(y_val, y_pred)
average_precision = average_precision_score(y_val, y_pred)

# Plot ROC curve and Precision-Recall curve as subplots
plt.figure(figsize=(15, 6))

# Plot ROC curve
plt.subplot(1, 2, 1)
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) - Shallow Model')
plt.legend(loc="lower right")

# Plot Precision-Recall curve
plt.subplot(1, 2, 2)
plt.plot(recall, precision, color='blue', lw=2, label='Precision-Recall curve (AP = %0.2f)' % average_precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

plt.tight_layout()
plt.show()

# %%
import datetime

# Get the current datetime
current_datetime = datetime.datetime.now()

# Add a time delta (5 hours and 30 minutes)
time_delta = datetime.timedelta(hours=5, minutes=30)
updated_datetime = current_datetime + time_delta

# Format the updated datetime
formatted_datetime = updated_datetime.strftime("%Y-%m-%d %H:%M:%S")
print("Updated Datetime:", formatted_datetime)
# Out:
# Updated Datetime: 2024-04-05 02:38:46

# %% [markdown]
# ## Save Hyperparameters 25

# %%
# Convert hp_array to DataFrame
df = pd.DataFrame(hp_array)
print(df)
# Save DataFrame to CSV
df.to_csv(f_hp_path, index=False)
print (f_hp_path, "saved")
# Out:
#             model     hpt_method  \
# 0  deep_ann_model  random search
# 1  deep_ann_model  random search
# 2  deep_ann_model  random search
# 3  deep_ann_model  random search
#
#                                 best_hyperparameters  elapsed_time  \
# 0  {'units': 256, 'activation_layer1': 'leaky_rel...  13707.120153
# 1  {'units': 256, 'activation_layer1': 'leaky_rel...  13707.120153
# 2  {'units': 256, 'activation_layer1': 'leaky_rel...  13707.120153
# 3  {'units': 256, 'activation_layer1': 'leaky_rel...  13707.120153
#
#    memory_usage  cpu_usage  precision    recall  f1_score   roc_auc  \
# 0    2685784064       72.3   0.758356  0.975914  0.853489  0.840210
# 1    2677829632       64.8   0.952508  0.918710  0.935304  0.986455
# 2    2838548480       74.0   0.925075  0.857634  0.890079  0.947314
# 3    2899894272       55.7   0.942371  0.917849  0.929949  0.985792
#
#               confusion_matrix
# 0  [[3204, 1446], [112, 4538]]
# 1   [[4437, 213], [378, 4272]]
# 2   [[4327, 323], [662, 3988]]
# 3   [[4389, 261], [382, 4268]]
# /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/cp2_hp.csv saved
