# %%
import os
import time
#mysys="jupyter" #
mysys="colab"
split="_90_5_5b_"
sn='sn_'
test_ratio=0.05

training_samples=167400
testing_samples=9300
validation_samples=9300

if mysys=="colab":
    from google.colab import drive
    drive.mount('/content/drive')
    in_path='/content/drive/MyDrive/UNSW_Data/'
    datapath='/content/drive/MyDrive/ANN_Edge/unsw_data/final4/'
    modelpath='/content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/'
    slash="/"
    ML_path=datapath+'ml2/'
    STDN_path=ML_path+ '/ml/stdn/'
else:
    current_folder = os.getcwd() + kkk
    print(current_folder)
    slash="\\"
    path=current_folder.replace('Model_05', "") + 'ANN_Edge\\final\\'
    print(path)
    ML_path=current_folder.replace('Model_05', "") + 'ANN_Edge\\final\ml\\'
    STDN_path=current_folder.replace('Model_05', "") + 'ANN_Edge\\final\ml\stdn\\'

print(in_path)
print(datapath)
performance_data=[]

in_f_train= in_path + 'UNSW_NB15_training-set.csv'
in_f_test=in_path+'UNSW_NB15_testing-set.csv'
f_features=in_path+ 'UNSW_NB15_f.csv'
out_f_train=datapath+'unsw-nb15_training' + split +'.csv'
out_f_test=datapath+'unsw-nb15_testing' + split+ '.csv'
out_f_validation=datapath+'unsw-nb15_validation' + split+ '.csv'

shallow_model_path=modelpath+ 'shallow_model_ANN5.keras'
deep_model_path=modelpath+ 'deep_model_ANN5.keras'

shallow_model_path_best_hp=modelpath+ 'shallow_model_ANN5_hp.keras'
deep_model_path_best_hp=modelpath+ 'deep_model_ANN5_hp.keras'

in_f_features=in_path + 'UNSW_NB15_f.csv'

f_performance_data=modelpath+ 'cp2_small_data_performance.csv'
f_hp_data=modelpath+ 'cp2_small_data_hp.csv'


print(in_f_train)
print(in_f_test)
print(in_f_features)
print(out_f_train)
print(out_f_test)
print(out_f_validation)
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/UNSW_Data/
# /content/drive/MyDrive/ANN_Edge/unsw_data/final4/
# /content/drive/MyDrive/UNSW_Data/UNSW_NB15_training-set.csv
# /content/drive/MyDrive/UNSW_Data/UNSW_NB15_testing-set.csv
# /content/drive/MyDrive/UNSW_Data/UNSW_NB15_f.csv
# /content/drive/MyDrive/ANN_Edge/unsw_data/final4/unsw-nb15_training_90_5_5b_.csv
# /content/drive/MyDrive/ANN_Edge/unsw_data/final4/unsw-nb15_testing_90_5_5b_.csv
# /content/drive/MyDrive/ANN_Edge/unsw_data/final4/unsw-nb15_validation_90_5_5b_.csv

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Define the features
features = ['ct_state_ttl', 'sload', 'rate', 'sttl', 'smean', 'dload', 'sbytes', 'ct_srv_dst', 'ct_dst_src_ltm', 'dbytes', 'ackdat', 'dttl', 'ct_dst_sport_ltm', 'dmean','ct_srv_src', 'dinpkt', 'tcprtt', 'dur', 'synack', 'sinpkt']
#features2= ['ct_state_ttl', 'sload', 'rate', 'sttl', 'smean', 'dload', 'sbytes', 'ct_srv_dst', 'ct_dst_src_ltm', 'dbytes', 'ackdat', 'dttl', 'ct_dst_sport_ltm', 'dmean', 'ct_srv_src', 'dinpkt', 'tcprtt', 'dur', 'synack', 'sinpkt'], 'proto', 'dport', 'stime']

# Load preprocessed data for training and testing
df_train = pd.read_csv(out_f_train)
df_test = pd.read_csv(out_f_test)
df_val = pd.read_csv(out_f_validation)
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167400 entries, 0 to 167399
# Data columns (total 45 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 167400 non-null  int64
#  1   dur                167400 non-null  float64
#  2   proto              167400 non-null  object
#  3   service            167400 non-null  object
#  4   state              167400 non-null  object
#  5   spkts              167400 non-null  int64
#  6   dpkts              167400 non-null  int64
#  7   sbytes             167400 non-null  int64
#  8   dbytes             167400 non-null  int64
#  9   rate               167400 non-null  float64
#  10  sttl               167400 non-null  int64
#  11  dttl               167400 non-null  int64
#  12  sload              167400 non-null  float64
#  13  dload              167400 non-null  float64
#  14  sloss              167400 non-null  int64
#  15  dloss              167400 non-null  int64
#  16  sinpkt             167400 non-null  float64
#  17  dinpkt             167400 non-null  float64
#  18  sjit               167400 non-null  float64
#  19  djit               167400 non-null  float64
#  20  swin               167400 non-null  int64
#  21  stcpb              167400 non-null  int64
#  22  dtcpb              167400 non-null  int64
#  23  dwin               167400 non-null  int64
#  24  tcprtt             167400 non-null  float64
#  25  synack             167400 non-null  float64
#  26  ackdat             167400 non-null  float64
#  27  smean              167400 non-null  int64
#  28  dmean              167400 non-null  int64
#  29  trans_depth        167400 non-null  int64
#  30  response_body_len  167400 non-null  int64
#  31  ct_srv_src         167400 non-null  int64
#  32  ct_state_ttl       167400 non-null  int64
#  33  ct_dst_ltm         167400 non-null  int64
#  34  ct_src_dport_ltm   167400 non-null  int64
#  35  ct_dst_sport_ltm   167400 non-null  int64
#  36  ct_dst_src_ltm     167400 non-null  int64
#  37  is_ftp_login       167400 non-null  int64
#  38  ct_ftp_cmd         167400 non-null  int64
#  39  ct_flw_http_mthd   167400 non-null  int64
#  40  ct_src_ltm         167400 non-null  int64
#  41  ct_srv_dst         167400 non-null  int64
#  42  is_sm_ips_ports    167400 non-null  int64
#  43  attack_cat         167400 non-null  object
#  44  label              167400 non-null  int64
# dtypes: float64(11), int64(30), object(4)
# memory usage: 57.5+ MB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9300 entries, 0 to 9299
# Data columns (total 45 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 9300 non-null   int64
#  1   dur                9300 non-null   float64
#  2   proto              9300 non-null   object
#  3   service            9300 non-null   object
#  4   state              9300 non-null   object
#  5   spkts              9300 non-null   int64
#  6   dpkts              9300 non-null   int64
#  7   sbytes             9300 non-null   int64
#  8   dbytes             9300 non-null   int64
#  9   rate               9300 non-null   float64
#  10  sttl               9300 non-null   int64
#  11  dttl               9300 non-null   int64
#  12  sload              9300 non-null   float64
#  13  dload              9300 non-null   float64
#  14  sloss              9300 non-null   int64
#  15  dloss              9300 non-null   int64
#  16  sinpkt             9300 non-null   float64
#  17  dinpkt             9300 non-null   float64
#  18  sjit               9300 non-null   float64
#  19  djit               9300 non-null   float64
#  20  swin               9300 non-null   int64
#  21  stcpb              9300 non-null   int64
#  22  dtcpb              9300 non-null   int64
#  23  dwin               9300 non-null   int64
#  24  tcprtt             9300 non-null   float64
#  25  synack             9300 non-null   float64
#  26  ackdat             9300 non-null   float64
#  27  smean              9300 non-null   int64
#  28  dmean              9300 non-null   int64
#  29  trans_depth        9300 non-null   int64
#  30  response_body_len  9300 non-null   int64
#  31  ct_srv_src         9300 non-null   int64
#  32  ct_state_ttl       9300 non-null   int64
#  33  ct_dst_ltm         9300 non-null   int64
#  34  ct_src_dport_ltm   9300 non-null   int64
#  35  ct_dst_sport_ltm   9300 non-null   int64
#  36  ct_dst_src_ltm     9300 non-null   int64
#  37  is_ftp_login       9300 non-null   int64
#  38  ct_ftp_cmd         9300 non-null   int64
#  39  ct_flw_http_mthd   9300 non-null   int64
#  40  ct_src_ltm         9300 non-null   int64
#  41  ct_srv_dst         9300 non-null   int64
#  42  is_sm_ips_ports    9300 non-null   int64
#  43  attack_cat         9300 non-null   object
#  44  label              9300 non-null   int64
# dtypes: float64(11), int64(30), object(4)
# memory usage: 3.2+ MB

# %%
df_val.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9300 entries, 0 to 9299
# Data columns (total 45 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 9300 non-null   int64
#  1   dur                9300 non-null   float64
#  2   proto              9300 non-null   object
#  3   service            9300 non-null   object
#  4   state              9300 non-null   object
#  5   spkts              9300 non-null   int64
#  6   dpkts              9300 non-null   int64
#  7   sbytes             9300 non-null   int64
#  8   dbytes             9300 non-null   int64
#  9   rate               9300 non-null   float64
#  10  sttl               9300 non-null   int64
#  11  dttl               9300 non-null   int64
#  12  sload              9300 non-null   float64
#  13  dload              9300 non-null   float64
#  14  sloss              9300 non-null   int64
#  15  dloss              9300 non-null   int64
#  16  sinpkt             9300 non-null   float64
#  17  dinpkt             9300 non-null   float64
#  18  sjit               9300 non-null   float64
#  19  djit               9300 non-null   float64
#  20  swin               9300 non-null   int64
#  21  stcpb              9300 non-null   int64
#  22  dtcpb              9300 non-null   int64
#  23  dwin               9300 non-null   int64
#  24  tcprtt             9300 non-null   float64
#  25  synack             9300 non-null   float64
#  26  ackdat             9300 non-null   float64
#  27  smean              9300 non-null   int64
#  28  dmean              9300 non-null   int64
#  29  trans_depth        9300 non-null   int64
#  30  response_body_len  9300 non-null   int64
#  31  ct_srv_src         9300 non-null   int64
#  32  ct_state_ttl       9300 non-null   int64
#  33  ct_dst_ltm         9300 non-null   int64
#  34  ct_src_dport_ltm   9300 non-null   int64
#  35  ct_dst_sport_ltm   9300 non-null   int64
#  36  ct_dst_src_ltm     9300 non-null   int64
#  37  is_ftp_login       9300 non-null   int64
#  38  ct_ftp_cmd         9300 non-null   int64
#  39  ct_flw_http_mthd   9300 non-null   int64
#  40  ct_src_ltm         9300 non-null   int64
#  41  ct_srv_dst         9300 non-null   int64
#  42  is_sm_ips_ports    9300 non-null   int64
#  43  attack_cat         9300 non-null   object
#  44  label              9300 non-null   int64
# dtypes: float64(11), int64(30), object(4)
# memory usage: 3.2+ MB

# %%
# Separate features and labels for training set
X_train = df_train[features].values # assuming 'label' is the column containing labels
y_train = df_train['label'].values

# Separate features and labels for testing set
X_test = df_test[features].values  # assuming 'label' is the column containing labels
y_test = df_test['label'].values

# Separate features and labels for testing set
X_val =df_val[features].values  # assuming 'label' is the column containing labels
y_val =df_val['label'].values

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape,y_val.shape)
print(X_train.shape[0]/(X_train.shape[0]+ X_test.shape[0]))
print(X_test.shape[0]/(X_test.shape[0]+ X_test.shape[0]))
print(X_val.shape[0]/(X_val.shape[0]+ X_val.shape[0]))
# Out:
# (167400, 20) (167400,) (9300, 20) (9300,) (9300, 20) (9300,)
# 0.9473684210526315
# 0.5
# 0.5

# %%
# Standardize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_val = scaler.transform(X_val)

# %%
import time
import psutil
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, average_precision_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.metrics import confusion_matrix

#performance_metrics = []

def get_system_info():
    # Get CPU and memory usage
    cpu_usage = psutil.cpu_percent()
    memory_usage = psutil.virtual_memory().percent
    return cpu_usage, memory_usage

# Define function to calculate training and testing time
def calculate_time(start_time):
    end_time = time.time()
    elapsed_time = end_time - start_time
    return elapsed_time

def evaluate_performance(title, test_loss, test_accuracy, y_test, y_preds, cpu_use, mem_use, training_time, test_time,  prt):
    #accuracy = accuracy_score(y_test, y_preds)
    precision = precision_score(y_test, y_preds)
    recall = recall_score(y_test, y_preds)
    f1 = f1_score(y_test, y_preds)
    roc_auc = roc_auc_score(y_test, y_preds)
    avg_precision = average_precision_score(y_test, y_preds)
    conf_matrix = confusion_matrix(y_test, y_preds)

    metrics ={
        'data': title,
        'time': time.time(),
        'Training time':  training_time,
        'test time':test_time,
        'memory usage':mem_use,
        'cpu usage': cpu_use,
        'accuracy': test_accuracy,
        'loss' :test_loss,
        'precision':  precision,
        'recall' : recall,
        'f1_score':   f1,
        'roc_auc' :roc_auc,
        'avg_precision':avg_precision,
        'conf_matrix':  conf_matrix,
    }

    if prt == 1:
        print(title, "Model Performance: ")
        print ('Training time',  training_time)
        print ('Testing time',  test_time)
        print ('Memory Usage', mem_use)
        print ('CPU usage', cpu_use)
        print("Test Accuracy:", test_accuracy)
        print("Test Loss:", test_loss)
        print("Precision:", precision)
        print("Recall:", recall)
        print("F1-score:", f1)
        print("roc_auc", roc_auc)
        print("avg_precision",avg_precision)
        print("Confusion Matrix:")
        print(conf_matrix)

    return metrics

# Define function to display performance metrics
def display_metrics(test_loss, test_accuracy, val_accuracy, precision, recall, f1, roc_auc, avg_precision):
    print("Test Loss:", test_loss)
    print("Test Accuracy:", test_accuracy)
    print("Validation Accuracy:", val_accuracy)
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1 Score:", f1)
    print("ROC-AUC Score:", roc_auc)
    print("Average Precision Score:", avg_precision)

# %% [markdown]
# ## Shallow *ANN* Model

# %%
# Define Shallow model hyperparameters
shallow_hyperparameters = {
    'input_dim': len(features),
    'neurons_layer1': 512,
    'activation_layer1': 'relu',
    'learning_rate': 0.0001
}

# Define paths and model name
modelpath = shallow_model_path
model_name = 'shallow_model_ANN'

# %%
from sklearn.metrics import confusion_matrix
# Define shallow ANN model function
def create_shallow_ann_model(input_dim, neurons_layer1, activation_layer1, learning_rate):
    model = Sequential()

    # hidden layer 1
    model.add(Dense(neurons_layer1, input_dim=input_dim, activation=activation_layer1))

    # Output layer
    model.add(Dense(1, activation='sigmoid'))

    # Compile model
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    return model


# Create the shallow ANN model with the best hyperparameters
start_time = time.time()
shallow_model = create_shallow_ann_model(**shallow_hyperparameters)
train_time = calculate_time(start_time)

# Train the model on the training data
start_time = time.time()
history = shallow_model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2)
cpu_usage, memory_usage=get_system_info()
train_time += calculate_time(start_time)

# Evaluate the model on the test set
start_time = time.time()
test_loss, test_accuracy = shallow_model.evaluate(X_test, y_test)
test_time = calculate_time(start_time)

# Calculate additional performance metrics on the validation set
y_pred_val = shallow_model.predict(X_test)

val_accuracy = accuracy_score(y_test, np.round(y_pred_val))
precision = precision_score(y_test, np.round(y_pred_val))
recall = recall_score(y_test, np.round(y_pred_val))
f1 = f1_score(y_test, np.round(y_pred_val))
roc_auc = roc_auc_score(y_test, y_pred_val)
avg_precision = average_precision_score(y_test, y_pred_val)
# Calculate the confusion matrix
conf_matrix = confusion_matrix(y_test, np.round(y_pred_val))

# Display performance metrics
display_metrics(test_loss, test_accuracy, val_accuracy, precision, recall, f1, roc_auc, avg_precision)
summary=shallow_model.summary()
print(summary)

# Save the trained model for inference
#joblib.dump(shallow_model, modelpath)
tf.keras.models.save_model(shallow_model, modelpath)
# Collect memory usage, CPU usage, and append to an array
metrics = {
    'Time':time.time(),
    'Model': model_name,
    'Training Time': train_time,
    'Testing Time': test_time,
    'Memory Usage': memory_usage,
    'CPU Usage': cpu_usage,
    'Test Loss': test_loss,
    'Test Accuracy': test_accuracy,
    'Validation Accuracy': val_accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1 Score': f1,
    'ROC-AUC Score': roc_auc,
    'Average Precision Score': avg_precision,
    "Confusion Matrix" : conf_matrix
}
# Out:
# Epoch 1/20
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.2688 - accuracy: 0.8716 - val_loss: 0.2242 - val_accuracy: 0.8896
# Epoch 2/20
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.2119 - accuracy: 0.8948 - val_loss: 0.2056 - val_accuracy: 0.8971
# Epoch 3/20
# 4185/4185 [==============================] - 8s 2ms/step - loss: 0.1990 - accuracy: 0.8997 - val_loss: 0.1966 - val_accuracy: 0.9012
# Epoch 4/20
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1913 - accuracy: 0.9056 - val_loss: 0.1908 - val_accuracy: 0.9038
# Epoch 5/20
# 4185/4185 [==============================] - 8s 2ms/step - loss: 0.1860 - accuracy: 0.9093 - val_loss: 0.1851 - val_accuracy: 0.9114
# Epoch 6/20
# 4185/4185 [==============================] - 8s 2ms/step - loss: 0.1820 - accuracy: 0.9124 - val_loss: 0.1821 - val_accuracy: 0.9117
# Epoch 7/20
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1789 - accuracy: 0.9140 - val_loss: 0.1791 - val_accuracy: 0.9150
# Epoch 8/20
# 4185/4185 [==============================] - 8s 2ms/step - loss: 0.1763 - accuracy: 0.9156 - val_loss: 0.1770 - val_accuracy: 0.9172
# Epoch 9/20
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1744 - accuracy: 0.9171 - val_loss: 0.1756 - val_accuracy: 0.9163
# Epoch 10/20
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1726 - accuracy: 0.9181 - val_loss: 0.1732 - val_accuracy: 0.9188
# Epoch 11/20
# 4185/4185 [==============================] - 8s 2ms/step - loss: 0.1709 - accuracy: 0.9189 - val_loss: 0.1717 - val_accuracy: 0.9203
# Epoch 12/20
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1699 - accuracy: 0.9202 - val_loss: 0.1699 - val_accuracy: 0.9217
# Epoch 13/20
# 4185/4185 [==============================] - 8s 2ms/step - loss: 0.1687 - accuracy: 0.9207 - val_loss: 0.1692 - val_accuracy: 0.9202
# Epoch 14/20
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1675 - accuracy: 0.9210 - val_loss: 0.1689 - val_accuracy: 0.9210
# Epoch 15/20
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1666 - accuracy: 0.9217 - val_loss: 0.1675 - val_accuracy: 0.9195
# Epoch 16/20
# 4185/4185 [==============================] - 8s 2ms/step - loss: 0.1657 - accuracy: 0.9221 - val_loss: 0.1664 - val_accuracy: 0.9217
# Epoch 17/20
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1650 - accuracy: 0.9224 - val_loss: 0.1668 - val_accuracy: 0.9212
# Epoch 18/20
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1643 - accuracy: 0.9228 - val_loss: 0.1651 - val_accuracy: 0.9226
# Epoch 19/20
# 4185/4185 [==============================] - 8s 2ms/step - loss: 0.1636 - accuracy: 0.9234 - val_loss: 0.1641 - val_accuracy: 0.9227
# Epoch 20/20
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1630 - accuracy: 0.9238 - val_loss: 0.1647 - val_accuracy: 0.9219
# 291/291 [==============================] - 1s 2ms/step - loss: 0.1577 - accuracy: 0.9280
# 291/291 [==============================] - 1s 2ms/step
# Test Loss: 0.15767952799797058
# Test Accuracy: 0.9279569983482361
# Validation Accuracy: 0.9279569892473118
# Precision: 0.945389435989257
# Recall: 0.9083870967741936
# F1 Score: 0.926518973459092
# ROC-AUC Score: 0.9841405017921148
# Average Precision Score: 0.9849527651001276
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               10752
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 11265 (44.00 KB)
# Trainable params: 11265 (44.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
import matplotlib.pyplot as plt

# Create a figure with subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plot accuracy
axes[0].plot(history.history['accuracy'], label='Training Accuracy')
axes[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
axes[0].set_title('Model Accuracy')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Plot loss
axes[1].plot(history.history['loss'], label='Training Loss')
axes[1].plot(history.history['val_loss'], label='Validation Loss')
axes[1].set_title('Model Loss')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

# Calculate ROC curve
fpr, tpr, thresholds_roc = roc_curve(y_test, y_pred_val)
roc_auc = auc(fpr, tpr)

# Calculate Precision-Recall curve
precision, recall, thresholds_pr = precision_recall_curve(y_test, y_pred_val)
average_precision = average_precision_score(y_test, y_pred_val)

# Plot ROC curve and Precision-Recall curve as subplots
plt.figure(figsize=(15, 6))

# Plot ROC curve
plt.subplot(1, 2, 1)
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) - Shallow Model')
plt.legend(loc="lower right")

# Plot Precision-Recall curve
plt.subplot(1, 2, 2)
plt.plot(recall, precision, color='blue', lw=2, label='Precision-Recall curve (AP = %0.2f)' % average_precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

plt.tight_layout()
plt.show()

# %%
#Append the metrics to an array
performance_data.append(metrics)

# Convert performance_metrics array to DataFrame
df_performance_data = pd.DataFrame(performance_data)
# Display the DataFrame
print(df_performance_data)
# Out:
#            Time              Model  Training Time  Testing Time  Memory Usage  \
# 0  1.712164e+09  shallow_model_ANN     202.791085      0.688525          12.8
#
#    CPU Usage  Test Loss  Test Accuracy  Validation Accuracy  Precision  \
# 0       40.7    0.15768       0.927957             0.927957   0.945389
#
#      Recall  F1 Score  ROC-AUC Score  Average Precision Score  \
# 0  0.908387  0.926519       0.984141                 0.984953
#
#              Confusion Matrix
# 0  [[4406, 244], [426, 4224]]

# %% [markdown]
# ## Deep Model ANN

# %%
# Define deep model hyperparameters
deep_hyperparameters = {
    'input_dim': len(features),
    'neurons_layer1': 256,
    'activation_layer1': 'relu',
    'neurons_layer2': 128,
    'activation_layer2': 'relu',
    'neurons_layer3': 64,
    'activation_layer3': 'relu',
    'neurons_layer4': 32,
    'activation_layer4': 'relu',
    'neurons_layer5': 16,
    'activation_layer5': 'relu',
    'neurons_layer6': 8,
    'activation_layer6': 'relu',
    'neurons_layer7': 4,
    'activation_layer7': 'relu',
    'learning_rate': 0.0001
}

# Define paths and model name
modelpath = deep_model_path
model_name = 'deep_model_ANN'

# %%
def create_deep_ann_model(input_dim, neurons_layer1, activation_layer1, neurons_layer2, activation_layer2, neurons_layer3, activation_layer3,
                          neurons_layer4, activation_layer4, neurons_layer5, activation_layer5, neurons_layer6, activation_layer6,
                          neurons_layer7, activation_layer7, learning_rate):
    model = Sequential()

    # Hidden layer 1
    model.add(Dense(neurons_layer1, input_dim=input_dim, activation=activation_layer1))

    # Hidden layer 2
    model.add(Dense(neurons_layer2, activation=activation_layer2))

    # Hidden layer 3
    model.add(Dense(neurons_layer3, activation=activation_layer3))

    # Hidden layer 4
    model.add(Dense(neurons_layer4, activation=activation_layer4))

    # Hidden layer 5
    model.add(Dense(neurons_layer5, activation=activation_layer5))

    # Hidden layer 6
    model.add(Dense(neurons_layer6, activation=activation_layer6))

    # Hidden layer 7
    model.add(Dense(neurons_layer7, activation=activation_layer7))

    # Output layer
    model.add(Dense(1, activation='sigmoid'))

    # Compile model
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    return model

# Create the deep ANN model with the best hyperparameters
start_time = time.time()
deep_model = create_deep_ann_model(**deep_hyperparameters)
train_time = calculate_time(start_time)

# Train the model on the training data
start_time = time.time()
history = deep_model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2)
train_time += calculate_time(start_time)
cpu_usage, memory_usage=get_system_info()

# Evaluate the model on the test set
start_time = time.time()
test_loss, test_accuracy = deep_model.evaluate(X_test, y_test)
test_time = calculate_time(start_time)

# Calculate additional performance metrics on the validation set
y_pred_val = deep_model.predict(X_test)
val_accuracy = accuracy_score(y_test, np.round(y_pred_val))
precision = precision_score(y_test, np.round(y_pred_val))
recall = recall_score(y_test, np.round(y_pred_val))
f1 = f1_score(y_test, np.round(y_pred_val))
roc_auc = roc_auc_score(y_test, y_pred_val)
avg_precision = average_precision_score(y_test, y_pred_val)

# Calculate the confusion matrix
conf_matrix = confusion_matrix(y_test, np.round(y_pred_val))

# Display performance metrics
display_metrics(test_loss, test_accuracy, val_accuracy, precision, recall, f1, roc_auc, avg_precision)

summary=deep_model.summary()
print(summary)

# Save the trained model for inference
#tf.keras.models.save_model(deep_model, modelpath)


# Collect memory usage, CPU usage, and append to an array
metrics = {
    'Time':time.time(),
    'Model': model_name,
    'Training Time': train_time,
    'Testing Time': test_time,
    'Memory Usage': memory_usage,
    'CPU Usage': cpu_usage,
    'Test Loss': test_loss,
    'Test Accuracy': test_accuracy,
    'Validation Accuracy': val_accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1 Score': f1,
    'ROC-AUC Score': roc_auc,
    'Average Precision Score': avg_precision,
    'Confusion Matrix' : conf_matrix
}
# Out:
# Epoch 1/20
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.2412 - accuracy: 0.8911 - val_loss: 0.1831 - val_accuracy: 0.9095
# Epoch 2/20
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1771 - accuracy: 0.9125 - val_loss: 0.1716 - val_accuracy: 0.9159
# Epoch 3/20
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1680 - accuracy: 0.9182 - val_loss: 0.1652 - val_accuracy: 0.9203
# Epoch 4/20
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1619 - accuracy: 0.9224 - val_loss: 0.1606 - val_accuracy: 0.9234
# Epoch 5/20
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1584 - accuracy: 0.9240 - val_loss: 0.1625 - val_accuracy: 0.9237
# Epoch 6/20
# 4185/4185 [==============================] - 11s 3ms/step - loss: 0.1555 - accuracy: 0.9258 - val_loss: 0.1664 - val_accuracy: 0.9226
# Epoch 7/20
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1530 - accuracy: 0.9275 - val_loss: 0.1514 - val_accuracy: 0.9288
# Epoch 8/20
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1512 - accuracy: 0.9281 - val_loss: 0.1549 - val_accuracy: 0.9251
# Epoch 9/20
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1495 - accuracy: 0.9292 - val_loss: 0.1495 - val_accuracy: 0.9299
# Epoch 10/20
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1483 - accuracy: 0.9297 - val_loss: 0.1484 - val_accuracy: 0.9296
# Epoch 11/20
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1469 - accuracy: 0.9307 - val_loss: 0.1477 - val_accuracy: 0.9324
# Epoch 12/20
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1460 - accuracy: 0.9310 - val_loss: 0.1451 - val_accuracy: 0.9322
# Epoch 13/20
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1451 - accuracy: 0.9318 - val_loss: 0.1453 - val_accuracy: 0.9319
# Epoch 14/20
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1442 - accuracy: 0.9327 - val_loss: 0.1453 - val_accuracy: 0.9326
# Epoch 15/20
# 4185/4185 [==============================] - 11s 3ms/step - loss: 0.1431 - accuracy: 0.9327 - val_loss: 0.1472 - val_accuracy: 0.9311
# Epoch 16/20
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1429 - accuracy: 0.9326 - val_loss: 0.1453 - val_accuracy: 0.9332
# Epoch 17/20
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1421 - accuracy: 0.9333 - val_loss: 0.1445 - val_accuracy: 0.9331
# Epoch 18/20
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1411 - accuracy: 0.9342 - val_loss: 0.1434 - val_accuracy: 0.9332
# Epoch 19/20
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1407 - accuracy: 0.9344 - val_loss: 0.1430 - val_accuracy: 0.9346
# Epoch 20/20
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1400 - accuracy: 0.9348 - val_loss: 0.1438 - val_accuracy: 0.9335
# 291/291 [==============================] - 1s 2ms/step - loss: 0.1343 - accuracy: 0.9372
# 291/291 [==============================] - 1s 2ms/step
# Test Loss: 0.13430242240428925
# Test Accuracy: 0.9372043013572693
# Validation Accuracy: 0.9372043010752689
# Precision: 0.9587093862815884
# Recall: 0.9137634408602151
# F1 Score: 0.9356969830433824
# ROC-AUC Score: 0.9882975604116083
# Average Precision Score: 0.9890139871936507
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 256)               5376
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 32)                2080
#
#  dense_6 (Dense)             (None, 16)                528
#
#  dense_7 (Dense)             (None, 8)                 136
#
#  dense_8 (Dense)             (None, 4)                 36
#
#  dense_9 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 49313 (192.63 KB)
# Trainable params: 49313 (192.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
import matplotlib.pyplot as plt

# Create a figure with subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plot accuracy
axes[0].plot(history.history['accuracy'], label='Training Accuracy')
axes[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
axes[0].set_title('Model Accuracy')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Plot loss
axes[1].plot(history.history['loss'], label='Training Loss')
axes[1].plot(history.history['val_loss'], label='Validation Loss')
axes[1].set_title('Model Loss')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

# Calculate ROC curve
fpr, tpr, thresholds_roc = roc_curve(y_test, y_pred_val)
roc_auc = auc(fpr, tpr)

# Calculate Precision-Recall curve
precision, recall, thresholds_pr = precision_recall_curve(y_test, y_pred_val)
average_precision = average_precision_score(y_test, y_pred_val)

# Plot ROC curve and Precision-Recall curve as subplots
plt.figure(figsize=(15, 6))

# Plot ROC curve
plt.subplot(1, 2, 1)
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) - Shallow Model')
plt.legend(loc="lower right")

# Plot Precision-Recall curve
plt.subplot(1, 2, 2)
plt.plot(recall, precision, color='blue', lw=2, label='Precision-Recall curve (AP = %0.2f)' % average_precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

plt.tight_layout()
plt.show()

# %%
#Append the metrics to an array
performance_data.append(metrics)

# Convert performance_metrics array to DataFrame
df_performance_data = pd.DataFrame(performance_data)

# Display the DataFrame
print(df_performance_data)
df_performance_data.to_csv(f_performance_data, index=False)
print(f_performance_data, "Saved")
# Out:
#            Time              Model  Training Time  Testing Time  Memory Usage  \
# 0  1.712164e+09  shallow_model_ANN     202.791085      0.688525          12.8
# 1  1.712164e+09     deep_model_ANN     263.399727      0.729605          13.1
#
#    CPU Usage  Test Loss  Test Accuracy  Validation Accuracy  Precision  \
# 0       40.7   0.157680       0.927957             0.927957   0.945389
# 1       57.2   0.134302       0.937204             0.937204   0.958709
#
#      Recall  F1 Score  ROC-AUC Score  Average Precision Score  \
# 0  0.908387  0.926519       0.984141                 0.984953
# 1  0.913763  0.935697       0.988298                 0.989014
#
#              Confusion Matrix
# 0  [[4406, 244], [426, 4224]]
# 1  [[4467, 183], [401, 4249]]
# /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/cp2_small_data_performance.csv Saved

# %% [markdown]
# ## Hyperparameter Tuning

# %%
# !pip install keras-tuner
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (24.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2024.2.2)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.7 kt-legacy-1.0.5

# %%
from kerastuner.tuners import RandomSearch, Hyperband
# Out:
# <ipython-input-10-e64760501d7e>:1: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner.tuners import RandomSearch, Hyperband

# %% [markdown]
# ## Hyperparameter tuning - shallow model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.regularizers import l1, l2  # Import l1 and l2 functions

from kerastuner import RandomSearch
from kerastuner import HyperParameters

modelname="shallow_model"
hpt_method="random search"
hp_array=[]

# Define a learning rate scheduler function
def lr_scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

def build_shallow_ann_model(hp):
    model = Sequential()

    # Input layer
    model.add(Dense(units=512,
                    input_dim=len(features),
                    activation=hp['activation_layer1'],
                    kernel_initializer=hp['weight_initializer'],
                    kernel_regularizer=l1(hp['regularization_strength']) if hp['regularization_type'] == 'l1' else
                                     l2(hp['regularization_strength']) if hp['regularization_type'] == 'l2' else None))

    # Dropout layer (optional)
    if hp['use_dropout']:
        model.add(Dropout(rate=hp['dropout_rate']))

    # Output layer
    model.add(Dense(1, activation='sigmoid'))

    # Define the learning rate scheduler
    lr_schedule = LearningRateScheduler(lr_scheduler)

    # Choose the optimizer based on the hyperparameter value
    optimizer = None
    if hp['optimizer'] == 'adam':
        optimizer = tf.keras.optimizers.Adam(learning_rate=hp['learning_rate'])
    elif hp['optimizer'] == 'rmsprop':
        optimizer = tf.keras.optimizers.RMSprop(learning_rate=hp['learning_rate'])
    elif hp['optimizer'] == 'sgd':
        optimizer = tf.keras.optimizers.SGD(learning_rate=hp['learning_rate'], momentum=0.9)

    model.compile(optimizer=optimizer,
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    return model



# Create a HyperParameters object
hp = HyperParameters()

# Add hyperparameters to the object
hp.Choice('activation_layer1', ['relu', 'tanh', 'leaky_relu'])
hp.Choice('optimizer', ['adam', 'rmsprop', 'sgd'])  # Hyperparameter for choosing the optimizer
hp.Choice('learning_rate', [0.01, 0.001, 0.0001])
hp.Choice('weight_initializer', ['random_normal', 'glorot_uniform', 'he_normal'])
hp.Choice('batch_size', [8, 16, 32, 64, 128, 256])
hp.Choice('regularization_type', ['','l1', 'l2'])
hp.Choice('regularization_strength', [0.0, 0.001, 0.01, 0.1])
hp.Choice('use_lr_scheduler', [True, False])  # Hyperparameter for choosing whether to use the learning rate scheduler
hp.Choice('use_dropout', [True, False])  # Hyperparameter for choosing whether to use dropout
hp.Float('dropout_rate', 0.0, 0.5, step=0.1)  # Dropout rate hyperparameter
# Out:
# 0.0

# %%
# Instantiate the RandomSearch tuner with the HyperParameters object
tuner = RandomSearch(
    build_shallow_ann_model,
    objective='val_accuracy',
    max_trials=50,
    executions_per_trial=1,
    directory='my_dir',
    project_name='shallow_ann_hp_tuning_RS',
    hyperparameters=hp  # Use the HyperParameters object
)

# Record start time
start_time = time.time()

# Perform hyperparameter tuning
tuner.search(X_train, y_train,
             epochs=10,
             validation_split=0.2)

# Record end time
end_time = time.time()
elapsed_time = end_time - start_time

# Get the best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# Build the model with the best hyperparameters and train it
best_model = tuner.hypermodel.build(best_hps)
history = best_model.fit(X_train, y_train, epochs=100, validation_split=0.2)

cpu_usage, memory_usage=get_system_info()


# Evaluate the best model on the test set
print("Best Hyperparameters:")
print(best_hps.values)


# Evaluate the best model on the test set
test_metrics = best_model.evaluate(X_test, y_test)

# Additional classification metrics
y_pred = best_model.predict(X_test)
y_pred_classes = np.round(y_pred)

precision = precision_score(y_test, np.round(y_pred))
recall = recall_score(y_test, np.round(y_pred))
f1 = f1_score(y_test, np.round(y_pred))
roc_auc = roc_auc_score(y_test, y_pred)
avg_precision = average_precision_score(y_test, y_pred)

confusion_matrix = tf.math.confusion_matrix(y_test, y_pred_classes).numpy()

# Additional regression metrics
regression_metrics = {
    'mse': test_metrics[0],  # Mean Squared Error
    'mae': test_metrics[1],  # Mean Absolute Error
    'r_squared': 1 - (np.sum((y_test - y_pred.flatten())**2) / np.sum((y_test - np.mean(y_test))**2)),
    'explained_variance': 1 - (np.var(y_test - y_pred.flatten()) / np.var(y_test))
}

# Display metrics
print("Test Metrics:")
print(" - Loss:", test_metrics[0])
print(" - Accuracy:", test_metrics[1])
print(" - elapsed_time", elapsed_time)
print("- memory_usage", memory_usage)
print(" - Other Metrics:")
print("   - Precision:", precision)
print("   - Recall:", recall)
print("   - F1 Score:", f1)
print("   - ROC-AUC:", roc_auc)
print("   - Precision Score", avg_precision)
print("   - Confusion Matrix:")
print(confusion_matrix)

print("Regression Metrics:")
for metric_name, metric_value in regression_metrics.items():
    print(f" - {metric_name}: {metric_value}")

# Save experiment details in hp_array
experiment_details = {
    'model': modelname,
    'hpt_method':hpt_method,
    'best_hyperparameters': best_hps.values,
    'elapsed_time': elapsed_time,
    'memory_usage': memory_usage,
    'cpu_usage': cpu_usage,
    'precision': precision,
    'recall': recall,
    'f1_score': f1,
    'roc_auc': roc_auc,
    'confusion_matrix': confusion_matrix.tolist(),
    'regression_metrics': regression_metrics
}
print(experiment_details)
hp_array.append(experiment_details)
# Out:
# Trial 50 Complete [00h 02m 23s]
# val_accuracy: 0.9006571173667908
#
# Best val_accuracy So Far: 0.9279271364212036
# Total elapsed time: 01h 52m 06s
# Epoch 1/100
# 4185/4185 [==============================] - 11s 2ms/step - loss: 0.2081 - accuracy: 0.8989 - val_loss: 0.1922 - val_accuracy: 0.9037
# Epoch 2/100
# 4185/4185 [==============================] - 11s 3ms/step - loss: 0.1838 - accuracy: 0.9124 - val_loss: 0.1929 - val_accuracy: 0.9099
# Epoch 3/100
# 4185/4185 [==============================] - 11s 3ms/step - loss: 0.1775 - accuracy: 0.9156 - val_loss: 0.1714 - val_accuracy: 0.9197
# Epoch 4/100
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1736 - accuracy: 0.9187 - val_loss: 0.1712 - val_accuracy: 0.9220
# Epoch 5/100
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1702 - accuracy: 0.9215 - val_loss: 0.1713 - val_accuracy: 0.9207
# Epoch 6/100
# 4185/4185 [==============================] - 11s 3ms/step - loss: 0.1679 - accuracy: 0.9229 - val_loss: 0.1655 - val_accuracy: 0.9250
# Epoch 7/100
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1659 - accuracy: 0.9239 - val_loss: 0.1670 - val_accuracy: 0.9243
# Epoch 8/100
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1644 - accuracy: 0.9247 - val_loss: 0.1701 - val_accuracy: 0.9208
# Epoch 9/100
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1635 - accuracy: 0.9256 - val_loss: 0.1628 - val_accuracy: 0.9265
# Epoch 10/100
# 4185/4185 [==============================] - 11s 3ms/step - loss: 0.1624 - accuracy: 0.9268 - val_loss: 0.1660 - val_accuracy: 0.9220
# Epoch 11/100
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1618 - accuracy: 0.9271 - val_loss: 0.1648 - val_accuracy: 0.9259
# Epoch 12/100
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1607 - accuracy: 0.9278 - val_loss: 0.1561 - val_accuracy: 0.9283
# Epoch 13/100
# 4185/4185 [==============================] - 11s 3ms/step - loss: 0.1593 - accuracy: 0.9281 - val_loss: 0.1613 - val_accuracy: 0.9287
# Epoch 14/100
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1593 - accuracy: 0.9281 - val_loss: 0.1649 - val_accuracy: 0.9257
# Epoch 15/100
# 4185/4185 [==============================] - 11s 3ms/step - loss: 0.1597 - accuracy: 0.9286 - val_loss: 0.1591 - val_accuracy: 0.9296
# Epoch 16/100
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1587 - accuracy: 0.9287 - val_loss: 0.1582 - val_accuracy: 0.9287
# Epoch 17/100
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1587 - accuracy: 0.9288 - val_loss: 0.1640 - val_accuracy: 0.9297
# Epoch 18/100
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1577 - accuracy: 0.9298 - val_loss: 0.1617 - val_accuracy: 0.9299
# Epoch 19/100
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1577 - accuracy: 0.9298 - val_loss: 0.1631 - val_accuracy: 0.9270
# Epoch 20/100
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1578 - accuracy: 0.9299 - val_loss: 0.1762 - val_accuracy: 0.9195
# Epoch 21/100
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1568 - accuracy: 0.9303 - val_loss: 0.1576 - val_accuracy: 0.9306
# Epoch 22/100
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1573 - accuracy: 0.9297 - val_loss: 0.1633 - val_accuracy: 0.9281
# Epoch 23/100
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1567 - accuracy: 0.9308 - val_loss: 0.1587 - val_accuracy: 0.9288
# Epoch 24/100
# 4185/4185 [==============================] - 8s 2ms/step - loss: 0.1570 - accuracy: 0.9304 - val_loss: 0.1622 - val_accuracy: 0.9273
# Epoch 25/100
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1565 - accuracy: 0.9309 - val_loss: 0.1586 - val_accuracy: 0.9292
# Epoch 26/100
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1572 - accuracy: 0.9309 - val_loss: 0.1561 - val_accuracy: 0.9325
# Epoch 27/100
# 4185/4185 [==============================] - 8s 2ms/step - loss: 0.1568 - accuracy: 0.9307 - val_loss: 0.1586 - val_accuracy: 0.9313
# Epoch 28/100
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1563 - accuracy: 0.9310 - val_loss: 0.1608 - val_accuracy: 0.9315
# Epoch 29/100
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1564 - accuracy: 0.9314 - val_loss: 0.1616 - val_accuracy: 0.9277
# Epoch 30/100
# 4185/4185 [==============================] - 8s 2ms/step - loss: 0.
100
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1635 - accuracy: 0.9335 - val_loss: 0.1803 - val_accuracy: 0.9274
# Epoch 93/100
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1617 - accuracy: 0.9335 - val_loss: 0.1722 - val_accuracy: 0.9332
# Epoch 94/100
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1630 - accuracy: 0.9340 - val_loss: 0.1714 - val_accuracy: 0.9342
# Epoch 95/100
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1625 - accuracy: 0.9340 - val_loss: 0.1773 - val_accuracy: 0.9284
# Epoch 96/100
# 4185/4185 [==============================] - 8s 2ms/step - loss: 0.1620 - accuracy: 0.9342 - val_loss: 0.1755 - val_accuracy: 0.9332
# Epoch 97/100
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1635 - accuracy: 0.9335 - val_loss: 0.1735 - val_accuracy: 0.9316
# Epoch 98/100
# 4185/4185 [==============================] - 11s 3ms/step - loss: 0.1626 - accuracy: 0.9337 - val_loss: 0.1843 - val_accuracy: 0.9294
# Epoch 99/100
# 4185/4185 [==============================] - 8s 2ms/step - loss: 0.1622 - accuracy: 0.9338 - val_loss: 0.1864 - val_accuracy: 0.9299
# Epoch 100/100
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1622 - accuracy: 0.9341 - val_loss: 0.1830 - val_accuracy: 0.9339
# Best Hyperparameters:
# {'activation_layer1': 'relu', 'optimizer': 'rmsprop', 'learning_rate': 0.001, 'weight_initializer': 'he_normal', 'batch_size': 256, 'regularization_type': '', 'regularization_strength': 0.01, 'use_lr_scheduler': 0, 'use_dropout': 0, 'dropout_rate': 0.30000000000000004}
# 291/291 [==============================] - 0s 1ms/step - loss: 0.1560 - accuracy: 0.9408
# 291/291 [==============================] - 0s 1ms/step
# Test Metrics:
#  - Loss: 0.15595591068267822
#  - Accuracy: 0.9407526850700378
#  - elapsed_time 4766.720930337906
# - memory_usage 12.7
#  - Other Metrics:
#    - Precision: 0.9541325060935076
#    - Recall: 0.9260215053763441
#    - F1 Score: 0.9398668558332424
#    - ROC-AUC: 0.9870411377037808
#    - Precision Score 0.9877705737551234
#    - Confusion Matrix:
# [[4443  207]
#  [ 344 4306]]
# Regression Metrics:
#  - mse: 0.15595591068267822
#  - mae: 0.9407526850700378
#  - r_squared: 0.8216517353652775
#  - explained_variance: 0.8217806794889131
# {'model': 'shallow_model', 'hpt_method': 'random search', 'best_hyperparameters': {'activation_layer1': 'relu', 'optimizer': 'rmsprop', 'learning_rate': 0.001, 'weight_initializer': 'he_normal', 'batch_size': 256, 'regularization_type': '', 'regularization_strength': 0.01, 'use_lr_scheduler': 0, 'use_dropout': 0, 'dropout_rate': 0.30000000000000004}, 'elapsed_time': 4766.720930337906, 'memory_usage': 12.7, 'cpu_usage': 68.2, 'precision': 0.9541325060935076, 'recall': 0.9260215053763441, 'f1_score': 0.9398668558332424, 'roc_auc': 0.9870411377037808, 'confusion_matrix': [[4443, 207], [344, 4306]], 'regression_metrics': {'mse': 0.15595591068267822, 'mae': 0.9407526850700378, 'r_squared': 0.8216517353652775, 'explained_variance': 0.8217806794889131}}

# %%
max_val_acc_epoch = np.argmax(history.history['val_accuracy'])
max_val_acc = history.history['val_accuracy'][max_val_acc_epoch]
min_val_loss_epoch = np.argmin(history.history['val_loss'])
min_val_loss = history.history['val_loss'][min_val_loss_epoch]

print("Epoch with maximum validation accuracy:", max_val_acc_epoch)
print("Maximum validation accuracy:", max_val_acc)
print("Epoch with minimum validation loss:", min_val_loss_epoch)
print("Minimum validation loss:", min_val_loss)
# Out:
# Epoch with maximum validation accuracy: 37
# Maximum validation accuracy: 0.9349163770675659
# Epoch with minimum validation loss: 37
# Minimum validation loss: 0.150529146194458

# %%
import matplotlib.pyplot as plt

# Create a figure with subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plot accuracy
axes[0].plot(history.history['accuracy'], label='Training Accuracy')
axes[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
axes[0].axvline(x=37, color='g', linestyle='--', label='Epoch 37')  # Vertical line at epoch 60
axes[0].set_title('Model Accuracy')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Plot loss
axes[1].plot(history.history['loss'], label='Training Loss')
axes[1].plot(history.history['val_loss'], label='Validation Loss')
axes[1].axvline(x=37, color='g', linestyle='--', label='Epoch 37')  # Vertical line at epoch 60
axes[1].set_title('Model Loss')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt


# Calculate ROC curve
fpr, tpr, thresholds_roc = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Calculate Precision-Recall curve
precision, recall, thresholds_pr = precision_recall_curve(y_test, y_pred)
average_precision = average_precision_score(y_test, y_pred)

# Plot ROC curve and Precision-Recall curve as subplots
plt.figure(figsize=(15, 6))

# Plot ROC curve
plt.subplot(1, 2, 1)
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) - Shallow Model')
plt.legend(loc="lower right")

# Plot Precision-Recall curve
plt.subplot(1, 2, 2)
plt.plot(recall, precision, color='blue', lw=2, label='Precision-Recall curve (AP = %0.2f)' % average_precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

plt.tight_layout()
plt.show()

# %% [markdown]
# #Creating the final shallow model

# %%
from keras.callbacks import ModelCheckpoint

# Define the filepath to save the model
checkpoint_filepath = shallow_model_path_best_hp

# Define a ModelCheckpoint callback to save the model with the highest validation accuracy
checkpoint = ModelCheckpoint(checkpoint_filepath,
                             monitor='val_accuracy',
                             save_best_only=True,
                             mode='max',
                             verbose=1)

# Build the model with the best hyperparameters
best_model = tuner.hypermodel.build(best_hps)

# Train the model with early stopping and ModelCheckpoint callback
history = best_model.fit(X_train, y_train,
                          epochs=max_val_acc_epoch,
                          validation_split=0.2,
                          callbacks=[checkpoint])
# Out:
# Epoch 1/37
# 4181/4185 [============================>.] - ETA: 0s - loss: 0.2083 - accuracy: 0.8979
# Epoch 1: val_accuracy improved from -inf to 0.90678, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.2082 - accuracy: 0.8979 - val_loss: 0.1916 - val_accuracy: 0.9068
# Epoch 2/37
# 4172/4185 [============================>.] - ETA: 0s - loss: 0.1830 - accuracy: 0.9123
# Epoch 2: val_accuracy improved from 0.90678 to 0.91514, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1830 - accuracy: 0.9123 - val_loss: 0.1765 - val_accuracy: 0.9151
# Epoch 3/37
# 4156/4185 [============================>.] - ETA: 0s - loss: 0.1764 - accuracy: 0.9164
# Epoch 3: val_accuracy improved from 0.91514 to 0.92040, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1767 - accuracy: 0.9163 - val_loss: 0.1688 - val_accuracy: 0.9204
# Epoch 4/37
# 4162/4185 [============================>.] - ETA: 0s - loss: 0.1727 - accuracy: 0.9190
# Epoch 4: val_accuracy improved from 0.92040 to 0.92064, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 8s 2ms/step - loss: 0.1726 - accuracy: 0.9191 - val_loss: 0.1697 - val_accuracy: 0.9206
# Epoch 5/37
# 4167/4185 [============================>.] - ETA: 0s - loss: 0.1692 - accuracy: 0.9218
# Epoch 5: val_accuracy did not improve from 0.92064
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1692 - accuracy: 0.9218 - val_loss: 0.1697 - val_accuracy: 0.9203
# Epoch 6/37
# 4166/4185 [============================>.] - ETA: 0s - loss: 0.1676 - accuracy: 0.9225
# Epoch 6: val_accuracy improved from 0.92064 to 0.92145, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1676 - accuracy: 0.9225 - val_loss: 0.1699 - val_accuracy: 0.9214
# Epoch 7/37
# 4159/4185 [============================>.] - ETA: 0s - loss: 0.1660 - accuracy: 0.9243
# Epoch 7: val_accuracy improved from 0.92145 to 0.92342, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 8s 2ms/step - loss: 0.1661 - accuracy: 0.9243 - val_loss: 0.1643 - val_accuracy: 0.9234
# Epoch 8/37
# 4180/4185 [============================>.] - ETA: 0s - loss: 0.1642 - accuracy: 0.9250
# Epoch 8: val_accuracy did not improve from 0.92342
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1641 - accuracy: 0.9250 - val_loss: 0.1658 - val_accuracy: 0.9234
# Epoch 9/37
# 4169/4185 [============================>.] - ETA: 0s - loss: 0.1637 - accuracy: 0.9257
# Epoch 9: val_accuracy improved from 0.92342 to 0.92419, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1637 - accuracy: 0.9256 - val_loss: 0.1715 - val_accuracy: 0.9242
# Epoch 10/37
# 4183/4185 [============================>.] - ETA: 0s - loss: 0.1624 - accuracy: 0.9265
# Epoch 10: val_accuracy improved from 0.92419 to 0.92691, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 8s 2ms/step - loss: 0.1625 - accuracy: 0.9265 - val_loss: 0.1580 - val_accuracy: 0.9269
# Epoch 11/37
# 4172/4185 [============================>.] - ETA: 0s - loss: 0.1609 - accuracy: 0.9268
# Epoch 11: val_accuracy improved from 0.92691 to 0.92823, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 11s 3ms/step - loss: 0.1609 - accuracy: 0.9268 - val_loss: 0.1611 - val_accuracy: 0.9282
# Epoch 12/37
# 4174/4185 [============================>.] - ETA: 0s - loss: 0.1612 - accuracy: 0.9272
# Epoch 12: val_accuracy did not improve from 0.92823
# 4185/4185 [==============================] - 11s 3ms/step - loss: 0.1612 - accuracy: 0.9273 - val_loss: 0.1589 - val_accuracy: 0.9280
# Epoch 13/37
# 4162/4185 [============================>.] - ETA: 0s - loss: 0.1604 - accuracy: 0.9282
# Epoch 13: val_accuracy did not improve from 0.92823
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1605 - accuracy: 0.9281 - val_loss: 0.1695 - val_accuracy: 0.9240
# Epoch 14/37
# 4174/4185 [============================>.] - ETA: 0s - loss: 0.1604 - accuracy: 0.9278
# Epoch 14: val_accuracy did not improve from 0.92823
# 4185/4185 [==============================] - 9s 2ms/step - loss: 0.1604 - accuracy: 0.9278 - val_loss: 0.1701 - val_accuracy: 0.9227
# Epoch 15/37
# 4174/4185 [============================>.] - ETA: 0s - loss: 0.1594 - accuracy: 0.9289
# Epoch 15: val_accuracy improved from 0.92823 to 0.92852, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1595 - accuracy: 0.9288 - val_loss: 0.1606 - val_accuracy: 0.9285
# Epoch 16/37
# 4184/4185 [============================>.] - ETA: 0s - loss: 0.1590 - accuracy: 0.9286
# Epoch 16: val_accuracy did not improve from 0.92852
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1589 - accuracy: 0.9286 - val_loss: 0.1655 - val_accuracy: 0.9261
# Epoch 17/37
# 4183/4185 [============================>.] - ETA: 0s - loss: 0.1596 - accuracy: 0.9292
# Epoch 17: val_accuracy improved from 0.92852 to 0.93065, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.1597 - accuracy: 0.9291 - val_loss: 0.1605 - val_accuracy: 0.9306
# Epoch 18/37
# 4158/4185 [============================>.] - ETA: 0s - loss: 0.1591 - accuracy: 0.9293
# Epoch 18: val_accuracy did not improve from 0.93065
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1590 - accuracy: 0.9293 - val_loss: 0.1685 - val_accuracy: 0.9276
# Epoch 19/37
# 4173/4185 [============================>.] - ETA: 0s - loss: 0.1596 - accuracy: 0.9296
# Epoch 19: val_accuracy did not improve from 0.93065
# 4185/4185 [==============================] - 12s 3ms/step - loss: 0.1595 - accuracy: 0.9297 - val_loss: 0.1624 - val_accuracy: 0.9284
# Epoch 20/37
# 4167/4185 [============================>.] - ETA: 0s - loss: 0.1583 - accuracy: 0.9301
# Epoch 20: val_accuracy did not improve from 0.93065
# 4185/4185 [==============================] - 11s 3ms/step - loss: 0.1583 - accuracy: 0.9300 - val_loss: 0.1644 - val_accuracy: 0.9283
# Epoch 21/37
# 4164/4185 [============================>.] - ETA: 0s - loss: 0.1585 - accuracy: 0.9292
# Epoch 21: val_accuracy did not improve from 0.93065
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1586 - accuracy: 0.9292 - val_loss: 0.1624 - val_accuracy: 0.9283
# Epoch 22/37
# 4157/4185 [============================>.] - ETA: 0s - loss: 0.1589 - accuracy: 0.9298
# Epoch 22: val_accuracy did not improve from 0.93065
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1588 - accuracy: 0.9298 - val_loss: 0.1579 - val_accuracy: 0.9306
# Epoch 23/37
# 4176/4185 [============================>.] - ETA: 0s - loss: 0.1583 - accuracy: 0.9296
# Epoch 23: val_accuracy improved from 0.93065 to 0.93070, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1584 - accuracy: 0.9296 - val_loss: 0.1583 - val_accuracy: 0.9307
# Epoch 24/37
# 4169/4185 [============================>.] - ETA: 0s - loss: 0.1580 - accuracy: 0.9303
# Epoch 24: val_accuracy did not improve from 0.93070
# 4185/4185 [==============================] - 8s 2ms/step - loss: 0.1581 - accuracy: 0.9303 - val_loss: 0.1603 - val_accuracy: 0.9285
# Epoch 25/37
# 4181/4185 [============================>.] - ETA: 0s - loss: 0.1573 - accuracy: 0.9304
# Epoch 25: val_accuracy improved from 0.93070 to 0.93085, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1573 - accuracy: 0.9304 - val_loss: 0.1600 - val_accuracy: 0.9309
# Epoch 26/37
# 4181/4185 [============================>.] - ETA: 0s - loss: 0.1576 - accuracy: 0.9306
# Epoch 26: val_accuracy did not improve from 0.93085
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1576 - accuracy: 0.9306 - val_loss: 0.1607 - val_accuracy: 0.9296
# Epoch 27/37
# 4184/4185 [============================>.] - ETA: 0s - loss: 0.1580 - accuracy: 0.9299
# Epoch 27: val_accuracy did not improve from 0.93085
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1580 - accuracy: 0.9299 - val_loss: 0.1657 - val_accuracy: 0.9302
# Epoch 28/37
# 4174/4185 [============================>.] - ETA: 0s - loss: 0.1578 - accuracy: 0.9304
# Epoch 28: val_accuracy did not improve from 0.93085
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1578 - accuracy: 0.9304 - val_loss: 0.1603 - val_accuracy: 0.9301
# Epoch 29/37
# 4179/4185 [============================>.] - ETA: 0s - loss: 0.1576 - accuracy: 0.9302
# Epoch 29: val_accuracy did not improve from 0.93085
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1575 - accuracy: 0.9302 - val_loss: 0.1663 - val_accuracy: 0.9230
# Epoch 30/37
# 4185/4185 [==============================] - ETA: 0s - loss: 0.1573 - accuracy: 0.9311
# Epoch 30: val_accuracy improved from 0.93085 to 0.93184, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 21s 5ms/step - loss: 0.1573 - accuracy: 0.9311 - val_loss: 0.1585 - val_accuracy: 0.9318
# Epoch 31/37
# 4180/4185 [============================>.] - ETA: 0s - loss: 0.1571 - accuracy: 0.9311
# Epoch 31: val_accuracy did not improve from 0.93184
# 4185/4185 [==============================] - 19s 4ms/step - loss: 0.1572 - accuracy: 0.9310 - val_loss: 0.1622 - val_accuracy: 0.9288
# Epoch 32/37
# 4166/4185 [============================>.] - ETA: 0s - loss: 0.1571 - accuracy: 0.9311
# Epoch 32: val_accuracy improved from 0.93184 to 0.93232, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1571 - accuracy: 0.9311 - val_loss: 0.1570 - val_accuracy: 0.9323
# Epoch 33/37
# 4158/4185 [============================>.] - ETA: 0s - loss: 0.1569 - accuracy: 0.9320
# Epoch 33: val_accuracy did not improve from 0.93232
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1568 - accuracy: 0.9320 - val_loss: 0.1609 - val_accuracy: 0.9292
# Epoch 34/37
# 4179/4185 [============================>.] - ETA: 0s - loss: 0.1573 - accuracy: 0.9312
# Epoch 34: val_accuracy improved from 0.93232 to 0.93405, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/shallow_model_ANN5_hp.keras
# 4185/4185 [==============================] - 8s 2ms/step - loss: 0.1573 - accuracy: 0.9313 - val_loss: 0.1581 - val_accuracy: 0.9341
# Epoch 35/37
# 4171/4185 [============================>.] - ETA: 0s - loss: 0.1568 - accuracy: 0.9318
# Epoch 35: val_accuracy did not improve from 0.93405
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1568 - accuracy: 0.9318 - val_loss: 0.1580 - val_accuracy: 0.9318
# Epoch 36/37
# 4178/4185 [============================>.] - ETA: 0s - loss: 0.1569 - accuracy: 0.9320
# Epoch 36: val_accuracy did not improve from 0.93405
# 4185/4185 [==============================] - 11s 3ms/step - loss: 0.1569 - accuracy: 0.9320 - val_loss: 0.1585 - val_accuracy: 0.9329
# Epoch 37/37
# 4169/4185 [============================>.] - ETA: 0s - loss: 0.1565 - accuracy: 0.9317
# Epoch 37: val_accuracy did not improve from 0.93405
# 4185/4185 [==============================] - 10s 2ms/step - loss: 0.1566 - accuracy: 0.9317 - val_loss: 0.1603 - val_accuracy: 0.9326

# %%
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import load_model, Model

best_model =load_model(checkpoint_filepath)

# Display the summary of the loaded model
best_model.summary()

# Plot the architecture of the loaded model
plot_model(best_model, to_file='shallow_model_best_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 512)               10752
#
#  dense_5 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 11265 (44.00 KB)
# Trainable params: 11265 (44.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## ANN Shallow Model Testing

# %%
import psutil
import time
from keras.models import load_model
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, average_precision_score
import tensorflow as tf

# Load the saved model
saved_model = load_model(checkpoint_filepath)

# Measure CPU and memory usage before prediction
cpu_usage_before = psutil.cpu_percent()
memory_usage_before = psutil.virtual_memory().used

# Record start time for prediction
start_time = time.time()

# Assuming X_test and y_test are your test data
# Predict on the test data
y_pred = saved_model.predict(X_test)

# Convert predicted probabilities to binary predictions (0 or 1)
y_pred_classes = (y_pred > 0.5).astype(int)

# Record end time for prediction
end_time = time.time()

# Measure CPU and memory usage after prediction
cpu_usage_after = psutil.cpu_percent()
memory_usage_after = psutil.virtual_memory().used

# Calculate prediction time
prediction_time = end_time - start_time

# Calculate performance metrics
accuracy = accuracy_score(y_test, y_pred_classes)
precision = precision_score(y_test, y_pred_classes)
recall = recall_score(y_test, y_pred_classes)
f1 = f1_score(y_test, y_pred_classes)
roc_auc = roc_auc_score(y_test, y_pred)
avg_precision = average_precision_score(y_test, y_pred)

# Compute confusion matrix
confusion_matrix = tf.math.confusion_matrix(y_test, y_pred_classes).numpy()

# Print performance metrics
print("Test Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("ROC AUC Score:", roc_auc)
print("Average Precision:", avg_precision)
print("Confusion Matrix:\n", confusion_matrix)

# Print CPU and memory usage, and prediction time
print("CPU usage before prediction:", cpu_usage_before)
print("Memory usage before prediction:", memory_usage_before)
print("CPU usage after prediction:", cpu_usage_after)
print("Memory usage after prediction:", memory_usage_after)
print("Prediction time:", prediction_time)
# Out:
# 291/291 [==============================] - 1s 2ms/step
# Test Accuracy: 0.9365591397849462
# Precision: 0.9440069991251093
# Recall: 0.9281720430107527
# F1 Score: 0.9360225547603558
# ROC AUC Score: 0.9865294947392763
# Average Precision: 0.9873881826323334
# Confusion Matrix:
#  [[4394  256]
#  [ 334 4316]]
# CPU usage before prediction: 64.2
# Memory usage before prediction: 2189008896
# CPU usage after prediction: 72.5
# Memory usage after prediction: 2199179264
# Prediction time: 1.3517534732818604

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

# Calculate ROC curve
fpr, tpr, thresholds_roc = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Calculate Precision-Recall curve
precision, recall, thresholds_pr = precision_recall_curve(y_test, y_pred)
average_precision = average_precision_score(y_test, y_pred)

# Plot ROC curve and Precision-Recall curve as subplots
plt.figure(figsize=(15, 6))

# Plot ROC curve
plt.subplot(1, 2, 1)
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) - Shallow Model')
plt.legend(loc="lower right")

# Plot Precision-Recall curve
plt.subplot(1, 2, 2)
plt.plot(recall, precision, color='blue', lw=2, label='Precision-Recall curve (AP = %0.2f)' % average_precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## ANN Shallow Model Validation

# %%
import psutil
import time
import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, average_precision_score
import tensorflow as tf
from keras.models import load_model

# Load the best model saved by ModelCheckpoint
best_model = load_model(checkpoint_filepath)

# Measure CPU and memory usage before validation
cpu_usage_before = psutil.cpu_percent()
memory_usage_before = psutil.virtual_memory().used

# Record start time for validation
start_time = time.time()

# Validate the loaded best model using validation data
evaluation = best_model.evaluate(X_val, y_val)

# Record end time for validation
end_time = time.time()

# Measure CPU and memory usage after validation
cpu_usage_after = psutil.cpu_percent()
memory_usage_after = psutil.virtual_memory().used

# Calculate validation time
validation_time = end_time - start_time

# Print the evaluation metrics
print("Validation Loss:", evaluation[0])
print("Validation Accuracy:", evaluation[1])

# Assuming y_pred is the predicted probabilities and y_pred_classes are the predicted classes
y_pred = best_model.predict(X_val)
y_pred_classes = np.round(y_pred)

# Compute additional performance metrics
precision = precision_score(y_val, y_pred_classes)
recall = recall_score(y_val, y_pred_classes)
f1 = f1_score(y_val, y_pred_classes)
roc_auc = roc_auc_score(y_val, y_pred)
avg_precision = average_precision_score(y_val, y_pred)

# Compute confusion matrix
confusion_matrix = tf.math.confusion_matrix(y_val, y_pred_classes).numpy()

# Print additional performance metrics
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("ROC AUC Score:", roc_auc)
print("Average Precision:", avg_precision)
print("Confusion Matrix:\n", confusion_matrix)

# Print CPU and memory usage, and validation time
print("CPU usage before validation:", cpu_usage_before)
print("Memory usage before validation:", memory_usage_before)
print("CPU usage after validation:", cpu_usage_after)
print("Memory usage after validation:", memory_usage_after)
print("Validation time:", validation_time)
# Out:
# 291/291 [==============================] - 1s 2ms/step - loss: 0.1695 - accuracy: 0.9319
# Validation Loss: 0.1695464700460434
# Validation Accuracy: 0.9319354891777039
# 291/291 [==============================] - 0s 1ms/step
# Precision: 0.9405571397236236
# Recall: 0.9221505376344086
# F1 Score: 0.9312628949940276
# ROC AUC Score: 0.9845745172852353
# Average Precision: 0.9851714266803618
# Confusion Matrix:
#  [[4379  271]
#  [ 362 4288]]
# CPU usage before validation: 45.1
# Memory usage before validation: 2190671872
# CPU usage after validation: 50.3
# Memory usage after validation: 2190794752
# Validation time: 0.8543503284454346

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

# Calculate ROC curve
fpr, tpr, thresholds_roc = roc_curve(y_val, y_pred)
roc_auc = auc(fpr, tpr)

# Calculate Precision-Recall curve
precision, recall, thresholds_pr = precision_recall_curve(y_val, y_pred)
average_precision = average_precision_score(y_val, y_pred)

# Plot ROC curve and Precision-Recall curve as subplots
plt.figure(figsize=(15, 6))

# Plot ROC curve
plt.subplot(1, 2, 1)
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) - Shallow Model')
plt.legend(loc="lower right")

# Plot Precision-Recall curve
plt.subplot(1, 2, 2)
plt.plot(recall, precision, color='blue', lw=2, label='Precision-Recall curve (AP = %0.2f)' % average_precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Deep model Hyperparameter tuning

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.regularizers import l1, l2  # Import l1 and l2 functions
from kerastuner import RandomSearch
from kerastuner import HyperParameters
import numpy as np
import time
import psutil
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, average_precision_score

modelname = "deep_ann_model"
hpt_method = "random search"

# Define a learning rate scheduler function
def lr_scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

# Update the model building function to include the new hyperparameters and configurations
def build_deep_ann_model(hp):
    model = Sequential()
    lu = hp['units']  # layer units
    # Input layer
    model.add(Dense(units=lu,
                    input_dim=len(features),
                    activation=hp['activation_layer1'],
                    kernel_initializer=hp['weight_initializer'],
                    kernel_regularizer=l1(hp['regularization_strength']) if hp['regularization_type'] == 'l1' else
                    l2(hp['regularization_strength']) if hp['regularization_type'] == 'l2' else None))

    # Hidden layers
    for i in range(1, 7):
        lu = lu / 2
        model.add(Dense(units=lu,
                        activation=hp[f'activation_layer{i + 1}'],
                        kernel_initializer=hp['weight_initializer'],
                        kernel_regularizer=l1(hp['regularization_strength']) if hp['regularization_type'] == 'l1' else
                        l2(hp['regularization_strength']) if hp['regularization_type'] == 'l2' else None))

        # Dropout layer (optional)
        if hp['use_dropout']:
            model.add(Dropout(rate=hp['dropout_rate']))

    # Output layer
    model.add(Dense(1, activation='sigmoid'))

    # Define the learning rate scheduler
    lr_schedule = LearningRateScheduler(lr_scheduler)

    # Choose the optimizer based on the hyperparameter value
    optimizer = None
    if hp['optimizer'] == 'adam':
        optimizer = tf.keras.optimizers.Adam(learning_rate=hp['learning_rate'])
    elif hp['optimizer'] == 'rmsprop':
        optimizer = tf.keras.optimizers.RMSprop(learning_rate=hp['learning_rate'])
    elif hp['optimizer'] == 'sgd':
        optimizer = tf.keras.optimizers.SGD(learning_rate=hp['learning_rate'], momentum=0.9)

    model.compile(optimizer=optimizer,
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    return model

# Create a HyperParameters object
hp = HyperParameters()
hp.Choice('units', [256])
# Add hyperparameters to the object
hp.Choice('activation_layer1', ['relu', 'tanh', 'leaky_relu'])
hp.Choice('activation_layer2', ['relu', 'tanh', 'leaky_relu'])
hp.Choice('activation_layer3', ['relu', 'tanh', 'leaky_relu'])
hp.Choice('activation_layer4', ['relu', 'tanh', 'leaky_relu'])
hp.Choice('activation_layer5', ['relu', 'tanh', 'leaky_relu'])
hp.Choice('activation_layer6', ['relu', 'tanh', 'leaky_relu'])
hp.Choice('activation_layer7', ['relu', 'tanh', 'leaky_relu'])
hp.Choice('optimizer', ['adam', 'rmsprop', 'sgd'])  # Hyperparameter for choosing the optimizer
hp.Choice('learning_rate', [0.01, 0.001, 0.0001])
hp.Choice('weight_initializer', ['random_normal', 'glorot_uniform', 'he_normal'])
hp.Choice('batch_size', [8, 16, 32, 64, 128, 256])
hp.Choice('regularization_type', ['','l1', 'l2'])
hp.Choice('regularization_strength', [0.0, 0.001, 0.01, 0.1])
hp.Choice('use_lr_scheduler', [True, False])  # Hyperparameter for choosing whether to use the learning rate scheduler
hp.Choice('use_dropout', [True, False])  # Hyperparameter for choosing whether to use dropout
hp.Float('dropout_rate', 0.0, 0.5, step=0.1)  # Dropout rate hyperparameter
# Out:
# 0.0

# %%
# Instantiate the RandomSearch tuner with the HyperParameters object
tuner = RandomSearch(
    build_deep_ann_model,
    objective='val_accuracy',
    max_trials=50,
    executions_per_trial=1,
    directory='my_dir',
    project_name='deep_ann_hy_tuning_RS',
    hyperparameters=hp  # Use the HyperParameters object
)

# Record start time
start_time = time.time()

# Perform hyperparameter tuning
tuner.search(X_train, y_train,
             epochs=10,
             validation_split=0.2)

# Record end time
end_time = time.time()
elapsed_time = end_time - start_time

# Get the best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# Build the model with the best hyperparameters and train it
best_model = tuner.hypermodel.build(best_hps)
history = best_model.fit(X_train, y_train, epochs=200, validation_split=0.2)

# Record additional metrics
memory_usage = psutil.virtual_memory().used
cpu_usage = psutil.cpu_percent()

# Evaluate the best model on the test set
print("Best Hyperparameters:")
print(best_hps.values)


# Evaluate the best model on the test set
test_metrics = best_model.evaluate(X_test, y_test)

# Additional classification metrics
y_pred = best_model.predict(X_test)
y_pred_classes = np.round(y_pred)

precision = precision_score(y_test, np.round(y_pred))
recall = recall_score(y_test, np.round(y_pred))
f1 = f1_score(y_test, np.round(y_pred))
roc_auc = roc_auc_score(y_test, y_pred)
avg_precision = average_precision_score(y_test, y_pred)

confusion_matrix = tf.math.confusion_matrix(y_test, y_pred_classes).numpy()



# Display metrics
print("Test Metrics:")
print(" - Loss:", test_metrics[0])
print(" - Accuracy:", test_metrics[1])
print(" - Other Metrics:")
print("   - Precision:", precision)
print("   - Recall:", recall)
print("   - F1 Score:", f1)
print("   - ROC-AUC:", roc_auc)
print("   - Precision Score", avg_precision)
print("   - Confusion Matrix:")
print(confusion_matrix)



# Save experiment details in hp_array
experiment_details = {
    'model': modelname,
    'hpt_method':hpt_method,
    'best_hyperparameters': best_hps.values,
    'elapsed_time': elapsed_time,
    'memory_usage': memory_usage,
    'cpu_usage': cpu_usage,
    'precision': precision,
    'recall': recall,
    'f1_score': f1,
    'roc_auc': roc_auc,
    'confusion_matrix': confusion_matrix.tolist(),
    'regression_metrics': regression_metrics
}
print(experiment_details)
hp_array.append(experiment_details)
# Out:
# Trial 50 Complete [00h 03m 24s]
# val_accuracy: 0.9223417043685913
#
# Best val_accuracy So Far: 0.9328255653381348
# Total elapsed time: 02h 16m 16s
# Epoch 1/200
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.1916 - accuracy: 0.9026 - val_loss: 0.1690 - val_accuracy: 0.9191
# Epoch 2/200
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1652 - accuracy: 0.9195 - val_loss: 0.1597 - val_accuracy: 0.9225
# Epoch 3/200
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1573 - accuracy: 0.9244 - val_loss: 0.1542 - val_accuracy: 0.9276
# Epoch 4/200
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1531 - accuracy: 0.9275 - val_loss: 0.1509 - val_accuracy: 0.9289
# Epoch 5/200
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1499 - accuracy: 0.9293 - val_loss: 0.1469 - val_accuracy: 0.9326
# Epoch 6/200
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1478 - accuracy: 0.9302 - val_loss: 0.1472 - val_accuracy: 0.9317
# Epoch 7/200
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1459 - accuracy: 0.9314 - val_loss: 0.1454 - val_accuracy: 0.9329
# Epoch 8/200
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1451 - accuracy: 0.9313 - val_loss: 0.1488 - val_accuracy: 0.9309
# Epoch 9/200
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1438 - accuracy: 0.9322 - val_loss: 0.1465 - val_accuracy: 0.9312
# Epoch 10/200
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1422 - accuracy: 0.9337 - val_loss: 0.1423 - val_accuracy: 0.9336
# Epoch 11/200
# 4185/4185 [==============================] - 15s 3ms/step - loss: 0.1414 - accuracy: 0.9335 - val_loss: 0.1448 - val_accuracy: 0.9313
# Epoch 12/200
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1404 - accuracy: 0.9339 - val_loss: 0.1430 - val_accuracy: 0.9346
# Epoch 13/200
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1393 - accuracy: 0.9350 - val_loss: 0.1409 - val_accuracy: 0.9344
# Epoch 14/200
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1386 - accuracy: 0.9355 - val_loss: 0.1412 - val_accuracy: 0.9337
# Epoch 15/200
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1379 - accuracy: 0.9362 - val_loss: 0.1412 - val_accuracy: 0.9339
# Epoch 16/200
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1378 - accuracy: 0.9355 - val_loss: 0.1492 - val_accuracy: 0.9283
# Epoch 17/200
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1366 - accuracy: 0.9365 - val_loss: 0.1427 - val_accuracy: 0.9354
# Epoch 18/200
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1363 - accuracy: 0.9364 - val_loss: 0.1392 - val_accuracy: 0.9352
# Epoch 19/200
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1359 - accuracy: 0.9367 - val_loss: 0.1394 - val_accuracy: 0.9368
# Epoch 20/200
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1351 - accuracy: 0.9372 - val_loss: 0.1403 - val_accuracy: 0.9337
# Epoch 21/200
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1343 - accuracy: 0.9375 - val_loss: 0.1376 - val_accuracy: 0.9366
# Epoch 22/200
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1342 - accuracy: 0.9380 - val_loss: 0.1389 - val_accuracy: 0.9347
# Epoch 23/200
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1328 - accuracy: 0.9384 - val_loss: 0.1416 - val_accuracy: 0.9343
# Epoch 24/200
# 4185/4185 [==============================] - 13s 3ms/step - loss: 0.1325 - accuracy: 0.9383 - val_loss: 0.1399 - val_accuracy: 0.9358
# Epoch 25/200
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1323 - accuracy: 0.9385 - val_loss: 0.1433 - val_accuracy: 0.9353
# Epoch 26/200
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1321 - accuracy: 0.9387 - val_loss: 0.1436 - val_accuracy: 0.9345
# Epoch 27/200
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1314 - accuracy: 0.9387 - val_loss: 0.1369 - val_accuracy: 0.9372
# Epoch 28/200
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.
200
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.0943 - accuracy: 0.9570 - val_loss: 0.1365 - val_accuracy: 0.9436
# Epoch 183/200
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.0927 - accuracy: 0.9576 - val_loss: 0.1392 - val_accuracy: 0.9447
# Epoch 184/200
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.0918 - accuracy: 0.9581 - val_loss: 0.1429 - val_accuracy: 0.9438
# Epoch 185/200
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.0929 - accuracy: 0.9576 - val_loss: 0.1385 - val_accuracy: 0.9438
# Epoch 186/200
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.0927 - accuracy: 0.9583 - val_loss: 0.1423 - val_accuracy: 0.9412
# Epoch 187/200
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.0918 - accuracy: 0.9577 - val_loss: 0.1492 - val_accuracy: 0.9425
# Epoch 188/200
# 4185/4185 [==============================] - 15s 3ms/step - loss: 0.0930 - accuracy: 0.9573 - val_loss: 0.1367 - val_accuracy: 0.9430
# Epoch 189/200
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.0927 - accuracy: 0.9578 - val_loss: 0.1381 - val_accuracy: 0.9426
# Epoch 190/200
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.0928 - accuracy: 0.9580 - val_loss: 0.1394 - val_accuracy: 0.9434
# Epoch 191/200
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.0943 - accuracy: 0.9568 - val_loss: 0.1370 - val_accuracy: 0.9444
# Epoch 192/200
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.0927 - accuracy: 0.9579 - val_loss: 0.1386 - val_accuracy: 0.9436
# Epoch 193/200
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.0925 - accuracy: 0.9577 - val_loss: 0.1380 - val_accuracy: 0.9431
# Epoch 194/200
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.0928 - accuracy: 0.9578 - val_loss: 0.1454 - val_accuracy: 0.9419
# Epoch 195/200
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.0917 - accuracy: 0.9587 - val_loss: 0.1406 - val_accuracy: 0.9439
# Epoch 196/200
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.0915 - accuracy: 0.9585 - val_loss: 0.1504 - val_accuracy: 0.9420
# Epoch 197/200
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.0916 - accuracy: 0.9585 - val_loss: 0.1416 - val_accuracy: 0.9433
# Epoch 198/200
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.0914 - accuracy: 0.9586 - val_loss: 0.1430 - val_accuracy: 0.9432
# Epoch 199/200
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.0911 - accuracy: 0.9583 - val_loss: 0.1421 - val_accuracy: 0.9455
# Epoch 200/200
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.0913 - accuracy: 0.9586 - val_loss: 0.1434 - val_accuracy: 0.9432
# Best Hyperparameters:
# {'units': 256, 'activation_layer1': 'tanh', 'activation_layer2': 'tanh', 'activation_layer3': 'relu', 'activation_layer4': 'relu', 'activation_layer5': 'relu', 'activation_layer6': 'relu', 'activation_layer7': 'leaky_relu', 'optimizer': 'adam', 'learning_rate': 0.001, 'weight_initializer': 'he_normal', 'batch_size': 8, 'regularization_type': 'l1', 'regularization_strength': 0.0, 'use_lr_scheduler': 1, 'use_dropout': 1, 'dropout_rate': 0.0}
# 291/291 [==============================] - 1s 2ms/step - loss: 0.1425 - accuracy: 0.9444
# 291/291 [==============================] - 1s 2ms/step
# Test Metrics:
#  - Loss: 0.14254610240459442
#  - Accuracy: 0.9444085955619812
#  - Other Metrics:
#    - Precision: 0.9542756649813146
#    - Recall: 0.9335483870967742
#    - F1 Score: 0.9437982389390152
#    - ROC-AUC: 0.9896814198173199
#    - Precision Score 0.9901784286908343
#    - Confusion Matrix:
# [[4442  208]
#  [ 309 4341]]
# Regression Metrics:
#  - mse: 0.14254610240459442
#  - mae: 0.9444085955619812
#  - r_squared: 0.8386856494456709
#  - explained_variance: 0.8387245239740857
# {'model': 'deep_ann_model', 'hpt_method': 'random search', 'best_hyperparameters': {'units': 256, 'activation_layer1': 'tanh', 'activation_layer2': 'tanh', 'activation_layer3': 'relu', 'activation_layer4': 'relu', 'activation_layer5': 'relu', 'activation_layer6': 'relu', 'activation_layer7': 'leaky_relu', 'optimizer': 'adam', 'learning_rate': 0.001, 'weight_initializer': 'he_normal', 'batch_size': 8, 'regularization_type': 'l1', 'regularization_strength': 0.0, 'use_lr_scheduler': 1, 'use_dropout': 1, 'dropout_rate': 0.0}, 'elapsed_time': 8175.974803209305, 'memory_usage': 1469399040, 'cpu_usage': 71.9, 'precision': 0.9542756649813146, 'recall': 0.9335483870967742, 'f1_score': 0.9437982389390152, 'roc_auc': 0.9896814198173199, 'confusion_matrix': [[4442, 208], [309, 4341]], 'regression_metrics': {'mse': 0.14254610240459442, 'mae': 0.9444085955619812, 'r_squared': 0.8386856494456709, 'explained_variance': 0.8387245239740857}}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-1e9fb492bd35> in <cell line: 96>()
#      94 }
#      95 print(experiment_details)
# ---> 96 hp_array.append(experiment_details)
#
# NameError: name 'hp_array' is not defined

# %%
max_val_acc_epoch = np.argmax(history.history['val_accuracy'])
max_val_acc = history.history['val_accuracy'][max_val_acc_epoch]
min_val_loss_epoch = np.argmin(history.history['val_loss'])
min_val_loss = history.history['val_loss'][min_val_loss_epoch]

print("Epoch with maximum validation accuracy:", max_val_acc_epoch)
print("Maximum validation accuracy:", max_val_acc)
print("Epoch with minimum validation loss:", min_val_loss_epoch)
print("Minimum validation loss:", min_val_loss)
# Out:
# Epoch with maximum validation accuracy: 198
# Maximum validation accuracy: 0.9454599618911743
# Epoch with minimum validation loss: 111
# Minimum validation loss: 0.13109037280082703

# %%
import matplotlib.pyplot as plt

# Create a figure with subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plot accuracy
axes[0].plot(history.history['accuracy'], label='Training Accuracy')
axes[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
axes[0].axvline(x=198, color='g', linestyle='--', label='Epoch 198')  # Vertical line at epoch 60
axes[0].set_title('Model Accuracy')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Plot loss
axes[1].plot(history.history['loss'], label='Training Loss')
axes[1].plot(history.history['val_loss'], label='Validation Loss')
axes[1].axvline(x=111, color='g', linestyle='--', label='Epoch 111')  # Vertical line at epoch 60
axes[1].set_title('Model Loss')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

# Calculate ROC curve
fpr, tpr, thresholds_roc = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Calculate Precision-Recall curve
precision, recall, thresholds_pr = precision_recall_curve(y_test, y_pred)
average_precision = average_precision_score(y_test, y_pred)

# Plot ROC curve and Precision-Recall curve as subplots
plt.figure(figsize=(15, 6))

# Plot ROC curve
plt.subplot(1, 2, 1)
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) - Shallow Model')
plt.legend(loc="lower right")

# Plot Precision-Recall curve
plt.subplot(1, 2, 2)
plt.plot(recall, precision, color='blue', lw=2, label='Precision-Recall curve (AP = %0.2f)' % average_precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

plt.tight_layout()
plt.show()

# %%
# Build the model with the best hyperparameters and train it
best_model = tuner.hypermodel.build(best_hps)
history = best_model.fit(X_train, y_train, epochs=300, validation_split=0.2)

# Record additional metrics
memory_usage = psutil.virtual_memory().used
cpu_usage = psutil.cpu_percent()

# Evaluate the best model on the test set
print("Best Hyperparameters:")
print(best_hps.values)


# Evaluate the best model on the test set
test_metrics = best_model.evaluate(X_test, y_test)

# Additional classification metrics
y_pred = best_model.predict(X_test)
y_pred_classes = np.round(y_pred)

precision = precision_score(y_test, np.round(y_pred))
recall = recall_score(y_test, np.round(y_pred))
f1 = f1_score(y_test, np.round(y_pred))
roc_auc = roc_auc_score(y_test, y_pred)
avg_precision = average_precision_score(y_test, y_pred)

confusion_matrix = tf.math.confusion_matrix(y_test, y_pred_classes).numpy()


# Display metrics
print("Test Metrics:")
print(" - Loss:", test_metrics[0])
print(" - Accuracy:", test_metrics[1])
print(" - Other Metrics:")
print("   - Precision:", precision)
print("   - Recall:", recall)
print("   - F1 Score:", f1)
print("   - ROC-AUC:", roc_auc)
print("   - Precision Score", avg_precision)
print("   - Confusion Matrix:")
print(confusion_matrix)



# Save experiment details in hp_array
experiment_details = {
    'model': modelname,
    'hpt_method':hpt_method,
    'best_hyperparameters': best_hps.values,
    'elapsed_time': elapsed_time,
    'memory_usage': memory_usage,
    'cpu_usage': cpu_usage,
    'precision': precision,
    'recall': recall,
    'f1_score': f1,
    'roc_auc': roc_auc,
    'confusion_matrix': confusion_matrix.tolist(),
    'regression_metrics': regression_metrics
}
print(experiment_details)
#hp_array.append(experiment_details)
# Out:
# Epoch 1/300
# 4185/4185 [==============================] - 21s 5ms/step - loss: 0.1949 - accuracy: 0.8995 - val_loss: 0.1720 - val_accuracy: 0.9124
# Epoch 2/300
# 4185/4185 [==============================] - 21s 5ms/step - loss: 0.1666 - accuracy: 0.9180 - val_loss: 0.1615 - val_accuracy: 0.9191
# Epoch 3/300
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1577 - accuracy: 0.9240 - val_loss: 0.1552 - val_accuracy: 0.9293
# Epoch 4/300
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1527 - accuracy: 0.9272 - val_loss: 0.1482 - val_accuracy: 0.9312
# Epoch 5/300
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1491 - accuracy: 0.9295 - val_loss: 0.1494 - val_accuracy: 0.9292
# Epoch 6/300
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1471 - accuracy: 0.9307 - val_loss: 0.1479 - val_accuracy: 0.9330
# Epoch 7/300
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1451 - accuracy: 0.9317 - val_loss: 0.1433 - val_accuracy: 0.9335
# Epoch 8/300
# 4185/4185 [==============================] - 15s 3ms/step - loss: 0.1440 - accuracy: 0.9325 - val_loss: 0.1435 - val_accuracy: 0.9347
# Epoch 9/300
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1427 - accuracy: 0.9329 - val_loss: 0.1460 - val_accuracy: 0.9341
# Epoch 10/300
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1422 - accuracy: 0.9337 - val_loss: 0.1431 - val_accuracy: 0.9347
# Epoch 11/300
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.1410 - accuracy: 0.9339 - val_loss: 0.1417 - val_accuracy: 0.9338
# Epoch 12/300
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1404 - accuracy: 0.9342 - val_loss: 0.1434 - val_accuracy: 0.9324
# Epoch 13/300
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1392 - accuracy: 0.9351 - val_loss: 0.1414 - val_accuracy: 0.9350
# Epoch 14/300
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1384 - accuracy: 0.9355 - val_loss: 0.1454 - val_accuracy: 0.9333
# Epoch 15/300
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1373 - accuracy: 0.9362 - val_loss: 0.1393 - val_accuracy: 0.9355
# Epoch 16/300
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1364 - accuracy: 0.9366 - val_loss: 0.1409 - val_accuracy: 0.9335
# Epoch 17/300
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.1362 - accuracy: 0.9368 - val_loss: 0.1408 - val_accuracy: 0.9348
# Epoch 18/300
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1358 - accuracy: 0.9373 - val_loss: 0.1388 - val_accuracy: 0.9358
# Epoch 19/300
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1354 - accuracy: 0.9375 - val_loss: 0.1381 - val_accuracy: 0.9376
# Epoch 20/300
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.
300
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.0791 - accuracy: 0.9646 - val_loss: 0.1517 - val_accuracy: 0.9470
# Epoch 300/300
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.0798 - accuracy: 0.9643 - val_loss: 0.1428 - val_accuracy: 0.9460
# Best Hyperparameters:
# {'units': 256, 'activation_layer1': 'tanh', 'activation_layer2': 'tanh', 'activation_layer3': 'relu', 'activation_layer4': 'relu', 'activation_layer5': 'relu', 'activation_layer6': 'relu', 'activation_layer7': 'leaky_relu', 'optimizer': 'adam', 'learning_rate': 0.001, 'weight_initializer': 'he_normal', 'batch_size': 8, 'regularization_type': 'l1', 'regularization_strength': 0.0, 'use_lr_scheduler': 1, 'use_dropout': 1, 'dropout_rate': 0.0}
# 291/291 [==============================] - 1s 2ms/step - loss: 0.1361 - accuracy: 0.9495
# 291/291 [==============================] - 1s 2ms/step
# Test Metrics:
#  - Loss: 0.13611865043640137
#  - Accuracy: 0.949462354183197
#  - Other Metrics:
#    - Precision: 0.9613686534216336
#    - Recall: 0.9365591397849462
#    - F1 Score: 0.94880174291939
#    - ROC-AUC: 0.9910821597872586
#    - Precision Score 0.9916782688148145
#    - Confusion Matrix:
# [[4475  175]
#  [ 295 4355]]
# {'model': 'deep_ann_model', 'hpt_method': 'random search', 'best_hyperparameters': {'units': 256, 'activation_layer1': 'tanh', 'activation_layer2': 'tanh', 'activation_layer3': 'relu', 'activation_layer4': 'relu', 'activation_layer5': 'relu', 'activation_layer6': 'relu', 'activation_layer7': 'leaky_relu', 'optimizer': 'adam', 'learning_rate': 0.001, 'weight_initializer': 'he_normal', 'batch_size': 8, 'regularization_type': 'l1', 'regularization_strength': 0.0, 'use_lr_scheduler': 1, 'use_dropout': 1, 'dropout_rate': 0.0}, 'elapsed_time': 8175.974803209305, 'memory_usage': 2305716224, 'cpu_usage': 77.0, 'precision': 0.9613686534216336, 'recall': 0.9365591397849462, 'f1_score': 0.94880174291939, 'roc_auc': 0.9910821597872586, 'confusion_matrix': [[4475, 175], [295, 4355]], 'regression_metrics': {'mse': 0.14254610240459442, 'mae': 0.9444085955619812, 'r_squared': 0.8386856494456709, 'explained_variance': 0.8387245239740857}}

# %%
max_val_acc_epoch = np.argmax(history.history['val_accuracy'])
max_val_acc = history.history['val_accuracy'][max_val_acc_epoch]
min_val_loss_epoch = np.argmin(history.history['val_loss'])
min_val_loss = history.history['val_loss'][min_val_loss_epoch]

print("Epoch with maximum validation accuracy:", max_val_acc_epoch)
print("Maximum validation accuracy:", max_val_acc)
print("Epoch with minimum validation loss:", min_val_loss_epoch)
print("Minimum validation loss:", min_val_loss)
# Out:
# Epoch with maximum validation accuracy: 289
# Maximum validation accuracy: 0.9479390978813171
# Epoch with minimum validation loss: 185
# Minimum validation loss: 0.12733502686023712

# %%
import matplotlib.pyplot as plt

# Create a figure with subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plot accuracy
axes[0].plot(history.history['accuracy'], label='Training Accuracy')
axes[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
axes[0].axvline(x=289, color='g', linestyle='--', label='Epoch 289')  # Vertical line at epoch 60
axes[0].set_title('Model Accuracy')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Plot loss
axes[1].plot(history.history['loss'], label='Training Loss')
axes[1].plot(history.history['val_loss'], label='Validation Loss')
axes[1].axvline(x=185, color='g', linestyle='--', label='Epoch 185')  # Vertical line at epoch 60
axes[1].set_title('Model Loss')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

# Calculate ROC curve
fpr, tpr, thresholds_roc = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Calculate Precision-Recall curve
precision, recall, thresholds_pr = precision_recall_curve(y_test, y_pred)
average_precision = average_precision_score(y_test, y_pred)

# Plot ROC curve and Precision-Recall curve as subplots
plt.figure(figsize=(15, 6))

# Plot ROC curve
plt.subplot(1, 2, 1)
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) - Shallow Model')
plt.legend(loc="lower right")

# Plot Precision-Recall curve
plt.subplot(1, 2, 2)
plt.plot(recall, precision, color='blue', lw=2, label='Precision-Recall curve (AP = %0.2f)' % average_precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

plt.tight_layout()
plt.show()

# %%
from keras.callbacks import ModelCheckpoint

# Define the filepath to save the model
checkpoint_filepath = deep_model_path_best_hp

# Define a ModelCheckpoint callback to save the model with the highest validation accuracy
checkpoint = ModelCheckpoint(checkpoint_filepath,
                             monitor='val_accuracy',
                             save_best_only=True,
                             mode='max',
                             verbose=1)

# Build the model with the best hyperparameters
best_model = tuner.hypermodel.build(best_hps)

# Train the model with early stopping and ModelCheckpoint callback
history = best_model.fit(X_train, y_train,
                          epochs=max_val_acc_epoch,
                          validation_split=0.2,
                          callbacks=[checkpoint])
# Out:
# Epoch 1/289
# 4180/4185 [============================>.] - ETA: 0s - loss: 0.1910 - accuracy: 0.9023
# Epoch 1: val_accuracy improved from -inf to 0.91502, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 28s 6ms/step - loss: 0.1909 - accuracy: 0.9023 - val_loss: 0.1761 - val_accuracy: 0.9150
# Epoch 2/289
# 4185/4185 [==============================] - ETA: 0s - loss: 0.1655 - accuracy: 0.9194
# Epoch 2: val_accuracy improved from 0.91502 to 0.92279, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.1655 - accuracy: 0.9194 - val_loss: 0.1607 - val_accuracy: 0.9228
# Epoch 3/289
# 4182/4185 [============================>.] - ETA: 0s - loss: 0.1569 - accuracy: 0.9251
# Epoch 3: val_accuracy did not improve from 0.92279
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.1569 - accuracy: 0.9250 - val_loss: 0.1725 - val_accuracy: 0.9158
# Epoch 4/289
# 4178/4185 [============================>.] - ETA: 0s - loss: 0.1526 - accuracy: 0.9278
# Epoch 4: val_accuracy improved from 0.92279 to 0.92760, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1525 - accuracy: 0.9278 - val_loss: 0.1545 - val_accuracy: 0.9276
# Epoch 5/289
# 4185/4185 [==============================] - ETA: 0s - loss: 0.1497 - accuracy: 0.9286
# Epoch 5: val_accuracy improved from 0.92760 to 0.93103, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 29s 7ms/step - loss: 0.1497 - accuracy: 0.9286 - val_loss: 0.1476 - val_accuracy: 0.9310
# Epoch 6/289
# 4180/4185 [============================>.] - ETA: 0s - loss: 0.1478 - accuracy: 0.9306
# Epoch 6: val_accuracy improved from 0.93103 to 0.93366, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 32s 8ms/step - loss: 0.1478 - accuracy: 0.9307 - val_loss: 0.1453 - val_accuracy: 0.9337
# Epoch 7/289
# 4183/4185 [============================>.] - ETA: 0s - loss: 0.1453 - accuracy: 0.9323
# Epoch 7: val_accuracy did not improve from 0.93366
# 4185/4185 [==============================] - 22s 5ms/step - loss: 0.1453 - accuracy: 0.9323 - val_loss: 0.1484 - val_accuracy: 0.9305
# Epoch 8/289
# 4178/4185 [============================>.] - ETA: 0s - loss: 0.1442 - accuracy: 0.9326
# Epoch 8: val_accuracy did not improve from 0.93366
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1442 - accuracy: 0.9326 - val_loss: 0.1462 - val_accuracy: 0.9328
# Epoch 9/289
# 4183/4185 [============================>.] - ETA: 0s - loss: 0.1427 - accuracy: 0.9336
# Epoch 9: val_accuracy did not improve from 0.93366
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.1427 - accuracy: 0.9336 - val_loss: 0.1489 - val_accuracy: 0.9326
# Epoch 10/289
# 4181/4185 [============================>.] - ETA: 0s - loss: 0.1418 - accuracy: 0.9335
# Epoch 10: val_accuracy did not improve from 0.93366
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.1418 - accuracy: 0.9335 - val_loss: 0.1457 - val_accuracy: 0.9321
# Epoch 11/289
# 4185/4185 [==============================] - ETA: 0s - loss: 0.1408 - accuracy: 0.9345
# Epoch 11: val_accuracy did not improve from 0.93366
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1408 - accuracy: 0.9345 - val_loss: 0.1441 - val_accuracy: 0.9326
# Epoch 12/289
# 4185/4185 [==============================] - ETA: 0s - loss: 0.1403 - accuracy: 0.9347
# Epoch 12: val_accuracy improved from 0.93366 to 0.93369, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.1403 - accuracy: 0.9347 - val_loss: 0.1443 - val_accuracy: 0.9337
# Epoch 13/289
# 4181/4185 [============================>.] - ETA: 0s - loss: 0.1388 - accuracy: 0.9351
# Epoch 13: val_accuracy improved from 0.93369 to 0.93513, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1389 - accuracy: 0.9351 - val_loss: 0.1441 - val_accuracy: 0.9351
# Epoch 14/289
# 4183/4185 [============================>.] - ETA: 0s - loss: 0.1387 - accuracy: 0.9353
# Epoch 14: val_accuracy did not improve from 0.93513
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1387 - accuracy: 0.9353 - val_loss: 0.1433 - val_accuracy: 0.9348
# Epoch 15/289
# 4181/4185 [============================>.] - ETA: 0s - loss: 0.1380 - accuracy: 0.9358
# Epoch 15: val_accuracy did not improve from 0.93513
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1380 - accuracy: 0.9358 - val_loss: 0.1404 - val_accuracy: 0.9346
# Epoch 16/289
# 4174/4185 [============================>.] - ETA: 0s - loss: 0.1368 - accuracy: 0.9361
# Epoch 16: val_accuracy improved from 0.93513 to 0.93527, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1367 - accuracy: 0.9362 - val_loss: 0.1412 - val_accuracy: 0.9353
# Epoch 17/289
# 4182/4185 [============================>.] - ETA: 0s - loss: 0.1365 - accuracy: 0.9368
# Epoch 17: val_accuracy did not improve from 0.93527
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1365 - accuracy: 0.9369 - val_loss: 0.1434 - val_accuracy: 0.9333
# Epoch 18/289
# 4177/4185 [============================>.] - ETA: 0s - loss: 0.1362 - accuracy: 0.9364
# Epoch 18: val_accuracy did not improve from 0.93527
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1361 - accuracy: 0.9364 - val_loss: 0.1410 - val_accuracy: 0.9349
# Epoch 19/289
# 4180/4185 [============================>.] - ETA: 0s - loss: 0.1352 - accuracy: 0.9374
# Epoch 19: val_accuracy improved from 0.93527 to 0.93671, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.1352 - accuracy: 0.9374 - val_loss: 0.1414 - val_accuracy: 0.9367
# Epoch 20/289
# 4182/4185 [============================>.] - ETA: 0s - loss: 0.1345 - accuracy: 0.9375
# Epoch 20: val_accuracy improved from 0.93671 to 0.93740, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1345 - accuracy: 0.9375 - val_loss: 0.1404 - val_accuracy: 0.9374
# Epoch 21/289
# 4182/4185 [============================>.] - ETA: 0s - loss: 0.1342 - accuracy: 0.9382
# Epoch 21: val_accuracy improved from 0.93740 to 0.93784, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1342 - accuracy: 0.9382 - val_loss: 0.1368 - val_accuracy: 0.9378
# Epoch 22/289
# 4171/4185 [============================>.] - ETA: 0s - loss: 0.1331 - accuracy: 0.9384
# Epoch 22: val_accuracy did not improve from 0.93784
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1331 - accuracy: 0.9384 - val_loss: 0.1406 - val_accuracy: 0.9340
# Epoch 23/289
# 4183/4185 [============================>.] - ETA: 0s - loss: 0.1333 - accuracy: 0.9383
# Epoch 23: val_accuracy did not improve from 0.93784
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1333 - accuracy: 0.9383 - val_loss: 0.1388 - val_accuracy: 0.9366
# Epoch 24/289
# 4180/4185 [============================>.] - ETA: 0s - loss: 0.1328 - accuracy: 0.9381
# Epoch 24: val_accuracy did not improve from 0.93784
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1328 - accuracy: 0.9381 - val_loss: 0.1378 - val_accuracy: 0.9364
# Epoch 25/289
# 4166/4185 [============================>.] - ETA: 0s - loss: 0.1325 - accuracy: 0.9386
# Epoch 25: val_accuracy did not improve from 0.93784
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1325 - accuracy: 0.9387 - val_loss: 0.1369 - val_accuracy: 0.9363
# Epoch 26/289
# 4169/4185 [============================>.] - ETA: 0s - loss: 0.1312 - accuracy: 0.9393
# Epoch 26: val_accuracy improved from 0.93784 to 0.93916, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1311 - accuracy: 0.9393 - val_loss: 0.1342 - val_accuracy: 0.9392
# Epoch 27/289
# 4179/4185 [============================>.] - ETA: 0s - loss: 0.1305 - accuracy: 0.9392
# Epoch 27: val_accuracy did not improve from 0.93916
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1304 - accuracy: 0.9392 - val_loss: 0.1371 - val_accuracy: 0.9382
# Epoch 28/289
# 4169/4185 [============================>.] - ETA: 0s - loss: 0.1303 - accuracy: 0.9396
# Epoch 28: val_accuracy did not improve from 0.93916
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.1303 - accuracy: 0.9396 - val_loss: 0.1373 - val_accuracy: 0.9369
# Epoch 29/289
# 4183/4185 [============================>.] - ETA: 0s - loss: 0.1297 - accuracy: 0.9400
# Epoch 29: val_accuracy improved from 0.93916 to 0.93937, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1297 - accuracy: 0.9401 - val_loss: 0.1369 - val_accuracy: 0.9394
# Epoch 30/289
# 4178/4185 [============================>.] - ETA: 0s - loss: 0.1286 - accuracy: 0.9403
# Epoch 30: val_accuracy did not improve from 0.93937
# 4185/4185 [==============================] - 15s 3ms/step - loss: 0.1286 - accuracy: 0.9403 - val_loss: 0.1449 - val_accuracy: 0.9354
# Epoch 31/289
# 4184/4185 [============================>.] - ETA: 0s - loss: 0.1294 - accuracy: 0.9403
# Epoch 31: val_accuracy did not improve from 0.93937
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1294 - accuracy: 0.9403 - val_loss: 0.1378 - val_accuracy: 0.9365
# Epoch 32/289
# 4169/4185 [============================>.] - ETA: 0s - loss: 0.1286 - accuracy: 0.9401
# Epoch 32: val_accuracy improved from 0.93937 to 0.93952, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1286 - accuracy: 0.9401 - val_loss: 0.1342 - val_accuracy: 0.9395
# Epoch 33/289
# 4176/4185 [============================>.] - ETA: 0s - loss: 0.1282 - accuracy: 0.9404
# Epoch 33: val_accuracy did not improve from 0.93952
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1283 - accuracy: 0.9404 - val_loss: 0.1375 - val_accuracy: 0.9363
# Epoch 34/289
# 4180/4185 [============================>.] - ETA: 0s - loss: 0.1277 - accuracy: 0.9407
# Epoch 34: val_accuracy did not improve from 0.93952
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1278 - accuracy: 0.9407 - val_loss: 0.1371 - val_accuracy: 0.9367
# Epoch 35/289
# 4177/4185 [============================>.] - ETA: 0s - loss: 0.1266 - accuracy: 0.9410
# Epoch 35: val_accuracy did not improve from 0.93952
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1266 - accuracy: 0.9410 - val_loss: 0.1379 - val_accuracy: 0.9391
# Epoch 36/289
# 4179/4185 [============================>.] - ETA: 0s - loss: 0.1264 - accuracy: 0.9419
# Epoch 36: val_accuracy did not improve from 0.93952
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1264 - accuracy: 0.9418 - val_loss: 0.1389 - val_accuracy: 0.9381
# Epoch 37/289
# 4174/4185 [============================>.] - ETA: 0s - loss: 0.1265 - accuracy: 0.9411
# Epoch 37: val_accuracy improved from 0.93952 to 0.94038, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1266 - accuracy: 0.9412 - val_loss: 0.1355 - val_accuracy: 0.9404
# Epoch 38/289
# 4180/4185 [============================>.] - ETA: 0s - loss: 0.1264 - accuracy: 0.9414
# Epoch 38: val_accuracy did not improve from 0.94038
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1264 - accuracy: 0.9415 - val_loss: 0.1375 - val_accuracy: 0.9393
# Epoch 39/289
# 4177/4185 [============================>.] - ETA: 0s - loss: 0.1260 - accuracy: 0.9416
# Epoch 39: val_accuracy did not improve from 0.94038
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1260 - accuracy: 0.9415 - val_loss: 0.1359 - val_accuracy: 0.9376
# Epoch 40/289
# 4178/4185 [============================>.] - ETA: 0s - loss: 0.1260 - accuracy: 0.9417
# Epoch 40: val_accuracy did not improve from 0.94038
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1260 - accuracy: 0.9417 - val_loss: 0.1348 - val_accuracy: 0.9393
# Epoch 41/289
# 4178/4185 [============================>.] - ETA: 0s - loss: 0.1249 - accuracy: 0.9421
# Epoch 41: val_accuracy did not improve from 0.94038
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1249 - accuracy: 0.9421 - val_loss: 0.1378 - val_accuracy: 0.9377
# Epoch 42/289
# 4180/4185 [============================>.] - ETA: 0s - loss: 0.1248 - accuracy: 0.9421
# Epoch 42: val_accuracy did not improve from 0.94038
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1248 - accuracy: 0.9421 - val_loss: 0.1346 - val_accuracy: 0.9388
# Epoch 43/289
# 4171/4185 [============================>.] - ETA: 0s - loss: 0.1242 - accuracy: 0.9430
# Epoch 43: val_accuracy did not improve from 0.94038
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1242 - accuracy: 0.9430 - val_loss: 0.1322 - val_accuracy: 0.9397
# Epoch 44/289
# 4174/4185 [============================>.] - ETA: 0s - loss: 0.1237 - accuracy: 0.9425
# Epoch 44: val_accuracy did not improve from 0.94038
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1237 - accuracy: 0.9424 - val_loss: 0.1348 - val_accuracy: 0.9393
# Epoch 45/289
# 4178/4185 [============================>.] - ETA: 0s - loss: 0.1237 - accuracy: 0.9427
# Epoch 45: val_accuracy improved from 0.94038 to 0.94098, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1237 - accuracy: 0.9427 - val_loss: 0.1319 - val_accuracy: 0.9410
# Epoch 46/289
# 4177/4185 [============================>.] - ETA: 0s - loss: 0.1237 - accuracy: 0.9426
# Epoch 46: val_accuracy did not improve from 0.94098
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1237 - accuracy: 0.9426 - val_loss: 0.1338 - val_accuracy: 0.9388
# Epoch 47/289
# 4175/4185 [============================>.] - ETA: 0s - loss: 0.1228 - accuracy: 0.9433
# Epoch 47: val_accuracy did not improve from 0.94098
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1228 - accuracy: 0.9433 - val_loss: 0.1363 - val_accuracy: 0.9387
# Epoch 48/289
# 4183/4185 [============================>.] - ETA: 0s - loss: 0.1224 - accuracy: 0.9432
# Epoch 48: val_accuracy did not improve from 0.94098
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1224 - accuracy: 0.9432 - val_loss: 0.1370 - val_accuracy: 0.9381
# Epoch 49/289
# 4177/4185 [============================>.] - ETA: 0s - loss: 0.1222 - accuracy: 0.9439
# Epoch 49: val_accuracy did not improve from 0.94098
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1222 - accuracy: 0.9439 - val_loss: 0.1393 - val_accuracy: 0.9364
# Epoch 50/289
# 4172/4185 [============================>.] - ETA: 0s - loss: 0.1219 - accuracy: 0.9440
# Epoch 50: val_accuracy did not improve from 0.94098
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1220 - accuracy: 0.9440 - val_loss: 0.1393 - val_accuracy: 0.9367
# Epoch 51/289
# 4170/4185 [============================>.] - ETA: 0s - loss: 0.1216 - accuracy: 0.9443
# Epoch 51: val_accuracy did not improve from 0.94098
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.1216 - accuracy: 0.9443 - val_loss: 0.1380 - val_accuracy: 0.9376
# Epoch 52/289
# 4175/4185 [============================>.] - ETA: 0s - loss: 0.1211 - accuracy: 0.9439
# Epoch 52: val_accuracy did not improve from 0.94098
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1212 - accuracy: 0.9439 - val_loss: 0.1343 - val_accuracy: 0.9404
# Epoch 53/289
# 4181/4185 [============================>.] - ETA: 0s - loss: 0.1210 - accuracy: 0.9445
# Epoch 53: val_accuracy did not improve from 0.94098
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1210 - accuracy: 0.9445 - val_loss: 0.1331 - val_accuracy: 0.9401
# Epoch 54/289
# 4184/4185 [============================>.] - ETA: 0s - loss: 0.1205 - accuracy: 0.9447
# Epoch 54: val_accuracy did not improve from 0.94098
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1205 - accuracy: 0.9447 - val_loss: 0.1351 - val_accuracy: 0.9391
# Epoch 55/289
# 4182/4185 [============================>.] - ETA: 0s - loss: 0.1195 - accuracy: 0.9446
# Epoch 55: val_accuracy improved from 0.94098 to 0.94113, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1195 - accuracy: 0.9446 - val_loss: 0.1335 - val_accuracy: 0.9411
# Epoch 56/289
# 4166/4185 [============================>.] - ETA: 0s - loss: 0.1194 - accuracy: 0.9449
# Epoch 56: val_accuracy did not improve from 0.94113
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1193 - accuracy: 0.9449 - val_loss: 0.1349 - val_accuracy: 0.9400
# Epoch 57/289
# 4183/4185 [============================>.] - ETA: 0s - loss: 0.1191 - accuracy: 0.9450
# Epoch 57: val_accuracy did not improve from 0.94113
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1191 - accuracy: 0.9450 - val_loss: 0.1345 - val_accuracy: 0.9402
# Epoch 58/289
# 4183/4185 [============================>.] - ETA: 0s - loss: 0.1189 - accuracy: 0.9450
# Epoch 58: val_accuracy did not improve from 0.94113
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1189 - accuracy: 0.9450 - val_loss: 0.1362 - val_accuracy: 0.9389
# Epoch 59/289
# 4182/4185 [============================>.] - ETA: 0s - loss: 0.1180 - accuracy: 0.9455
# Epoch 59: val_accuracy did not improve from 0.94113
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1180 - accuracy: 0.9455 - val_loss: 0.1325 - val_accuracy: 0.9409
# Epoch 60/289
# 4180/4185 [============================>.] - ETA: 0s - loss: 0.1185 - accuracy: 0.9455
# Epoch 60: val_accuracy did not improve from 0.94113
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1184 - accuracy: 0.9455 - val_loss: 0.1323 - val_accuracy: 0.9405
# Epoch 61/289
# 4171/4185 [============================>.] - ETA: 0s - loss: 0.1179 - accuracy: 0.9456
# Epoch 61: val_accuracy did not improve from 0.94113
# 4185/4185 [==============================] - 15s 3ms/step - loss: 0.1179 - accuracy: 0.9456 - val_loss: 0.1390 - val_accuracy: 0.9392
# Epoch 62/289
# 4181/4185 [============================>.] - ETA: 0s - loss: 0.1175 - accuracy: 0.9459
# Epoch 62: val_accuracy improved from 0.94113 to 0.94173, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1175 - accuracy: 0.9458 - val_loss: 0.1310 - val_accuracy: 0.9417
# Epoch 63/289
# 4174/4185 [============================>.] - ETA: 0s - loss: 0.1178 - accuracy: 0.9457
# Epoch 63: val_accuracy did not improve from 0.94173
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1177 - accuracy: 0.9457 - val_loss: 0.1371 - val_accuracy: 0.9395
# Epoch 64/289
# 4178/4185 [============================>.] - ETA: 0s - loss: 0.1173 - accuracy: 0.9459
# Epoch 64: val_accuracy did not improve from 0.94173
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1174 - accuracy: 0.9458 - val_loss: 0.1338 - val_accuracy: 0.9407
# Epoch 65/289
# 4179/4185 [============================>.] - ETA: 0s - loss: 0.1169 - accuracy: 0.9463
# Epoch 65: val_accuracy did not improve from 0.94173
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1169 - accuracy: 0.9463 - val_loss: 0.1329 - val_accuracy: 0.9413
# Epoch 66/289
# 4176/4185 [============================>.] - ETA: 0s - loss: 0.1168 - accuracy: 0.9462
# Epoch 66: val_accuracy did not improve from 0.94173
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1167 - accuracy: 0.9463 - val_loss: 0.1355 - val_accuracy: 0.9391
# Epoch 67/289
# 4182/4185 [============================>.] - ETA: 0s - loss: 0.1164 - accuracy: 0.9462
# Epoch 67: val_accuracy did not improve from 0.94173
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1164 - accuracy: 0.9462 - val_loss: 0.1427 - val_accuracy: 0.9360
# Epoch 68/289
# 4184/4185 [============================>.] - ETA: 0s - loss: 0.1159 - accuracy: 0.9462
# Epoch 68: val_accuracy did not improve from 0.94173
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1159 - accuracy: 0.9462 - val_loss: 0.1369 - val_accuracy: 0.9416
# Epoch 69/289
# 4170/4185 [============================>.] - ETA: 0s - loss: 0.1161 - accuracy: 0.9464
# Epoch 69: val_accuracy did not improve from 0.94173
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1161 - accuracy: 0.9463 - val_loss: 0.1313 - val_accuracy: 0.9407
# Epoch 70/289
# 4172/4185 [============================>.] - ETA: 0s - loss: 0.1150 - accuracy: 0.9473
# Epoch 70: val_accuracy did not improve from 0.94173
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1150 - accuracy: 0.9473 - val_loss: 0.1363 - val_accuracy: 0.9396
# Epoch 71/289
# 4171/4185 [============================>.] - ETA: 0s - loss: 0.1148 - accuracy: 0.9468
# Epoch 71: val_accuracy did not improve from 0.94173
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.1148 - accuracy: 0.9468 - val_loss: 0.1360 - val_accuracy: 0.9381
# Epoch 72/289
# 4184/4185 [============================>.] - ETA: 0s - loss: 0.1139 - accuracy: 0.9478
# Epoch 72: val_accuracy did not improve from 0.94173
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1140 - accuracy: 0.9478 - val_loss: 0.1354 - val_accuracy: 0.9412
# Epoch 73/289
# 4184/4185 [============================>.] - ETA: 0s - loss: 0.1141 - accuracy: 0.9478
# Epoch 73: val_accuracy did not improve from 0.94173
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1141 - accuracy: 0.9479 - val_loss: 0.1350 - val_accuracy: 0.9407
# Epoch 74/289
# 4180/4185 [============================>.] - ETA: 0s - loss: 0.1141 - accuracy: 0.9477
# Epoch 74: val_accuracy did not improve from 0.94173
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1141 - accuracy: 0.9477 - val_loss: 0.1326 - val_accuracy: 0.9415
# Epoch 75/289
# 4178/4185 [============================>.] - ETA: 0s - loss: 0.1145 - accuracy: 0.9474
# Epoch 75: val_accuracy did not improve from 0.94173
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.1145 - accuracy: 0.9474 - val_loss: 0.1343 - val_accuracy: 0.9399
# Epoch 76/289
# 4178/4185 [============================>.] - ETA: 0s - loss: 0.1131 - accuracy: 0.9478
# Epoch 76: val_accuracy improved from 0.94173 to 0.94176, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.1131 - accuracy: 0.9478 - val_loss: 0.1340 - val_accuracy: 0.9418
# Epoch 77/289
# 4178/4185 [============================>.] - ETA: 0s - loss: 0.1133 - accuracy: 0.9473
# Epoch 77: val_accuracy did not improve from 0.94176
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1133 - accuracy: 0.9473 - val_loss: 0.1384 - val_accuracy: 0.9384
# Epoch 78/289
# 4168/4185 [============================>.] - ETA: 0s - loss: 0.1135 - accuracy: 0.9480
# Epoch 78: val_accuracy did not improve from 0.94176
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1135 - accuracy: 0.9479 - val_loss: 0.1341 - val_accuracy: 0.9416
# Epoch 79/289
# 4175/4185 [============================>.] - ETA: 0s - loss: 0.1127 - accuracy: 0.9479
# Epoch 79: val_accuracy did not improve from 0.94176
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1127 - accuracy: 0.9479 - val_loss: 0.1356 - val_accuracy: 0.9416
# Epoch 80/289
# 4182/4185 [============================>.] - ETA: 0s - loss: 0.1129 - accuracy: 0.9476
# Epoch 80: val_accuracy improved from 0.94176 to 0.94241, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1129 - accuracy: 0.9477 - val_loss: 0.1330 - val_accuracy: 0.9424
# Epoch 81/289
# 4185/4185 [==============================] - ETA: 0s - loss: 0.1122 - accuracy: 0.9484
# Epoch 81: val_accuracy improved from 0.94241 to 0.94277, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.1122 - accuracy: 0.9484 - val_loss: 0.1324 - val_accuracy: 0.9428
# Epoch 82/289
# 4181/4185 [============================>.] - ETA: 0s - loss: 0.1119 - accuracy: 0.9484
# Epoch 82: val_accuracy did not improve from 0.94277
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1118 - accuracy: 0.9483 - val_loss: 0.1329 - val_accuracy: 0.9407
# Epoch 83/289
# 4183/4185 [============================>.] - ETA: 0s - loss: 0.1127 - accuracy: 0.9478
# Epoch 83: val_accuracy did not improve from 0.94277
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1127 - accuracy: 0.9478 - val_loss: 0.1359 - val_accuracy: 0.9410
# Epoch 84/289
# 4179/4185 [============================>.] - ETA: 0s - loss: 0.1117 - accuracy: 0.9486
# Epoch 84: val_accuracy did not improve from 0.94277
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.1118 - accuracy: 0.9485 - val_loss: 0.1336 - val_accuracy: 0.9418
# Epoch 85/289
# 4180/4185 [============================>.] - ETA: 0s - loss: 0.1113 - accuracy: 0.9489
# Epoch 85: val_accuracy did not improve from 0.94277
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1113 - accuracy: 0.9489 - val_loss: 0.1353 - val_accuracy: 0.9411
# Epoch 86/289
# 4185/4185 [==============================] - ETA: 0s - loss: 0.1112 - accuracy: 0.9488
# Epoch 86: val_accuracy did not improve from 0.94277
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1112 - accuracy: 0.9488 - val_loss: 0.1333 - val_accuracy: 0.9416
# Epoch 87/289
# 4179/4185 [============================>.] - ETA: 0s - loss: 0.1116 - accuracy: 0.9488
# Epoch 87: val_accuracy did not improve from 0.94277
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1115 - accuracy: 0.9488 - val_loss: 0.1360 - val_accuracy: 0.9427
# Epoch 88/289
# 4183/4185 [============================>.] - ETA: 0s - loss: 0.1110 - accuracy: 0.9488
# Epoch 88: val_accuracy did not improve from 0.94277
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1110 - accuracy: 0.9488 - val_loss: 0.1334 - val_accuracy: 0.9422
# Epoch 89/289
# 4181/4185 [============================>.] - ETA: 0s - loss: 0.1108 - accuracy: 0.9490
# Epoch 89: val_accuracy did not improve from 0.94277
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1108 - accuracy: 0.9490 - val_loss: 0.1354 - val_accuracy: 0.9415
# Epoch 90/289
# 4181/4185 [============================>.] - ETA: 0s - loss: 0.1104 - accuracy: 0.9493
# Epoch 90: val_accuracy did not improve from 0.94277
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1104 - accuracy: 0.9493 - val_loss: 0.1350 - val_accuracy: 0.9412
# Epoch 91/289
# 4175/4185 [============================>.] - ETA: 0s - loss: 0.1105 - accuracy: 0.9491
# Epoch 91: val_accuracy improved from 0.94277 to 0.94295, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1104 - accuracy: 0.9491 - val_loss: 0.1349 - val_accuracy: 0.9430
# Epoch 92/289
# 4179/4185 [============================>.] - ETA: 0s - loss: 0.1102 - accuracy: 0.9490
# Epoch 92: val_accuracy did not improve from 0.94295
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1101 - accuracy: 0.9490 - val_loss: 0.1339 - val_accuracy: 0.9415
# Epoch 93/289
# 4183/4185 [============================>.] - ETA: 0s - loss: 0.1098 - accuracy: 0.9497
# Epoch 93: val_accuracy did not improve from 0.94295
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1098 - accuracy: 0.9498 - val_loss: 0.1381 - val_accuracy: 0.9388
# Epoch 94/289
# 4173/4185 [============================>.] - ETA: 0s - loss: 0.1088 - accuracy: 0.9498
# Epoch 94: val_accuracy did not improve from 0.94295
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1088 - accuracy: 0.9497 - val_loss: 0.1397 - val_accuracy: 0.9380
# Epoch 95/289
# 4180/4185 [============================>.] - ETA: 0s - loss: 0.1086 - accuracy: 0.9499
# Epoch 95: val_accuracy did not improve from 0.94295
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1087 - accuracy: 0.9499 - val_loss: 0.1317 - val_accuracy: 0.9426
# Epoch 96/289
# 4184/4185 [============================>.] - ETA: 0s - loss: 0.1083 - accuracy: 0.9506
# Epoch 96: val_accuracy did not improve from 0.94295
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1083 - accuracy: 0.9506 - val_loss: 0.1362 - val_accuracy: 0.9419
# Epoch 97/289
# 4174/4185 [============================>.] - ETA: 0s - loss: 0.1092 - accuracy: 0.9500
# Epoch 97: val_accuracy did not improve from 0.94295
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1092 - accuracy: 0.9501 - val_loss: 0.1334 - val_accuracy: 0.9429
# Epoch 98/289
# 4174/4185 [============================>.] - ETA: 0s - loss: 0.1080 - accuracy: 0.9506
# Epoch 98: val_accuracy did not improve from 0.94295
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1079 - accuracy: 0.9507 - val_loss: 0.1379 - val_accuracy: 0.9415
# Epoch 99/289
# 4184/4185 [============================>.] - ETA: 0s - loss: 0.1083 - accuracy: 0.9502
# Epoch 99: val_accuracy did not improve from 0.94295
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.1082 - accuracy: 0.9503 - val_loss: 0.1356 - val_accuracy: 0.9420
# Epoch 100/289
# 4182/4185 [============================>.] - ETA: 0s - loss: 0.1083 - accuracy: 0.9501
# Epoch 100: val_accuracy did not improve from 0.94295
# 4185/4185 [==============================] - 14s 3ms/step - loss: 0.1083 - accuracy: 0.9501 - val_loss: 0.1400 - val_accuracy: 0.9384
# Epoch 101/289
# 4177/4185 [============================>.] - ETA: 0s - loss: 0.1074 - accuracy: 0.9509
# Epoch 101: val_accuracy did not improve from 0.94295
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1074 - accuracy: 0.9509 - val_loss: 0.1396 - val_accuracy: 0.9418
# Epoch 102/289
# 4182/4185 [============================>.] - ETA: 0s - loss: 0.1064 - accuracy: 0.9513
# Epoch 102: val_accuracy did not improve from 0.94295
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1064 - accuracy: 0.9513 - val_loss: 0.1327 - val_accuracy: 0.9426
# Epoch 103/289
# 4171/4185 [============================>.] - ETA: 0s - loss: 0.1073 - accuracy: 0.9503
# Epoch 103: val_accuracy did not improve from 0.94295
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1074 - accuracy: 0.9503 - val_loss: 0.1366 - val_accuracy: 0.9423
# Epoch 104/289
# 4170/4185 [============================>.] - ETA: 0s - loss: 0.1069 - accuracy: 0.9514
# Epoch 104: val_accuracy did not improve from 0.94295
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1070 - accuracy: 0.9514 - val_loss: 0.1365 - val_accuracy: 0.9407
# Epoch 105/289
# 4168/4185 [============================>.] - ETA: 0s - loss: 0.1067 - accuracy: 0.9506
# Epoch 105: val_accuracy did not improve from 0.94295
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1066 - accuracy: 0.9507 - val_loss: 0.1345 - val_accuracy: 0.9427
# Epoch 106/289
# 4178/4185 [============================>.] - ETA: 0s - loss: 0.1062 - accuracy: 0.9509
# Epoch 106: val_accuracy did not improve from 0.94295
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1062 - accuracy: 0.9509 - val_loss: 0.1400 - val_accuracy: 0.9424
# Epoch 107/289
# 4176/4185 [============================>.] - ETA: 0s - loss: 0.1061 - accuracy: 0.9513
# Epoch 107: val_accuracy did not improve from 0.94295
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1061 - accuracy: 0.9513 - val_loss: 0.1428 - val_accuracy: 0.9418
# Epoch 108/289
# 4185/4185 [==============================] - ETA: 0s - loss: 0.1059 - accuracy: 0.9511
# Epoch 108: val_accuracy did not improve from 0.94295
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1059 - accuracy: 0.9511 - val_loss: 0.1357 - val_accuracy: 0.9421
# Epoch 109/289
# 4177/4185 [============================>.] - ETA: 0s - loss: 0.1053 - accuracy: 0.9517
# Epoch 109: val_accuracy improved from 0.94295 to 0.94343, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1054 - accuracy: 0.9516 - val_loss: 0.1380 - val_accuracy: 0.9434
# Epoch 110/289
# 4180/4185 [============================>.] - ETA: 0s - loss: 0.1055 - accuracy: 0.9519
# Epoch 110: val_accuracy did not improve from 0.94343
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.1055 - accuracy: 0.9518 - val_loss: 0.1388 - val_accuracy: 0.9431
# Epoch 111/289
# 4177/4185 [============================>.] - ETA: 0s - loss: 0.1059 - accuracy: 0.9512
# Epoch 111: val_accuracy did not improve from 0.94343
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.1059 - accuracy: 0.9512 - val_loss: 0.1378 - val_accuracy: 0.9399
# Epoch 112/289
# 4178/4185 [============================>.] - ETA: 0s - loss: 0.1047 - accuracy: 0.9523
# Epoch 112: val_accuracy did not improve from 0.94343
# 4185/4185 [==============================] - 19s 5ms/step - loss: 0.1046 - accuracy: 0.9524 - val_loss: 0.1374 - val_accuracy: 0.9412
# Epoch 113/289
# 4171/4185 [============================>.] - ETA: 0s - loss: 0.1054 - accuracy: 0.9516
# Epoch 113: val_accuracy did not improve from 0.94343
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.1054 - accuracy: 0.9516 - val_loss: 0.1333 - val_accuracy: 0.9416
# Epoch 114/289
# 4177/4185 [============================>.] - ETA: 0s - loss: 0.1052 - accuracy: 0.9515
# Epoch 114: val_accuracy did not improve from 0.94343
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.1052 - accuracy: 0.9515 - val_loss: 0.1305 - val_accuracy: 0.9424
# Epoch 115/289
# 4183/4185 [============================>.] - ETA: 0s - loss: 0.1048 - accuracy: 0.9516
# Epoch 115: val_accuracy did not improve from 0.94343
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.1048 - accuracy: 0.9516 - val_loss: 0.1408 - val_accuracy: 0.9417
# Epoch 116/289
# 4185/4185 [==============================] - ETA: 0s - loss: 0.1045 - accuracy: 0.9524
# Epoch 116: val_accuracy did not improve from 0.94343
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1045 - accuracy: 0.9524 - val_loss: 0.1357 - val_accuracy: 0.9423
# Epoch 117/289
# 4184/4185 [============================>.] - ETA: 0s - loss: 0.1037 - accuracy: 0.9523
# Epoch 117: val_accuracy did not improve from 0.94343
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.1037 - accuracy: 0.9523 - val_loss: 0.1377 - val_accuracy: 0.9412
# Epoch 118/289
# 4180/4185 [============================>.] - ETA: 0s - loss: 0.1048 - accuracy: 0.9521
# Epoch 118: val_accuracy did not improve from 0.94343
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1048 - accuracy: 0.9521 - val_loss: 0.1383 - val_accuracy: 0.9398
# Epoch 119/289
# 4168/4185 [============================>.] - ETA: 0s - loss: 0.1054 - accuracy: 0.9517
# Epoch 119: val_accuracy did not improve from 0.94343
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.1054 - accuracy: 0.9517 - val_loss: 0.1337 - val_accuracy: 0.9421
# Epoch 120/289
# 4171/4185 [============================>.] - ETA: 0s - loss: 0.1033 - accuracy: 0.9521
# Epoch 120: val_accuracy did not improve from 0.94343
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.1032 - accuracy: 0.9522 - val_loss: 0.1353 - val_accuracy: 0.9428
# Epoch 121/289
# 4179/4185 [============================>.] - ETA: 0s - loss: 0.1032 - accuracy: 0.9525
# Epoch 121: val_accuracy improved from 0.94343 to 0.94427, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.1031 - accuracy: 0.9525 - val_loss: 0.1342 - val_accuracy: 0.9443
# Epoch 122/289
# 4168/4185 [============================>.] - ETA: 0s - loss: 0.1041 - accuracy: 0.9521
# Epoch 122: val_accuracy did not improve from 0.94427
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1041 - accuracy: 0.9521 - val_loss: 0.1418 - val_accuracy: 0.9400
# Epoch 123/289
# 4170/4185 [============================>.] - ETA: 0s - loss: 0.1038 - accuracy: 0.9517
# Epoch 123: val_accuracy did not improve from 0.94427
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1038 - accuracy: 0.9517 - val_loss: 0.1377 - val_accuracy: 0.9409
# Epoch 124/289
# 4176/4185 [============================>.] - ETA: 0s - loss: 0.1037 - accuracy: 0.9523
# Epoch 124: val_accuracy did not improve from 0.94427
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1037 - accuracy: 0.9523 - val_loss: 0.1380 - val_accuracy: 0.9431
# Epoch 125/289
# 4172/4185 [============================>.] - ETA: 0s - loss: 0.1038 - accuracy: 0.9521
# Epoch 125: val_accuracy did not improve from 0.94427
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1038 - accuracy: 0.9521 - val_loss: 0.1375 - val_accuracy: 0.9421
# Epoch 126/289
# 4176/4185 [============================>.] - ETA: 0s - loss: 0.1033 - accuracy: 0.9527
# Epoch 126: val_accuracy did not improve from 0.94427
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.1034 - accuracy: 0.9527 - val_loss: 0.1376 - val_accuracy: 0.9420
# Epoch 127/289
# 4180/4185 [============================>.] - ETA: 0s - loss: 0.1037 - accuracy: 0.9520
# Epoch 127: val_accuracy did not improve from 0.94427
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.1037 - accuracy: 0.9520 - val_loss: 0.1457 - val_accuracy: 0.9415
# Epoch 128/289
# 4177/4185 [============================>.] - ETA: 0s - loss: 0.1020 - accuracy: 0.9528
# Epoch 128: val_accuracy did not improve from 0.94427
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.1020 - accuracy: 0.9528 - val_loss: 0.1393 - val_accuracy: 0.9418
# Epoch 129/289
# 4178/4185 [============================>.] - ETA: 0s - loss: 0.1020 - accuracy: 0.9537
# Epoch 129: val_accuracy did not improve from 0.94427
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1020 - accuracy: 0.9537 - val_loss: 0.1416 - val_accuracy: 0.9407
# Epoch 130/289
# 4179/4185 [============================>.] - ETA: 0s - loss: 0.1016 - accuracy: 0.9534
# Epoch 130: val_accuracy did not improve from 0.94427
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.1016 - accuracy: 0.9534 - val_loss: 0.1399 - val_accuracy: 0.9431
# Epoch 131/289
# 4181/4185 [============================>.] - ETA: 0s - loss: 0.1015 - accuracy: 0.9539
# Epoch 131: val_accuracy did not improve from 0.94427
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1015 - accuracy: 0.9539 - val_loss: 0.1342 - val_accuracy: 0.9440
# Epoch 132/289
# 4179/4185 [============================>.] - ETA: 0s - loss: 0.1008 - accuracy: 0.9540
# Epoch 132: val_accuracy did not improve from 0.94427
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1008 - accuracy: 0.9540 - val_loss: 0.1369 - val_accuracy: 0.9429
# Epoch 133/289
# 4177/4185 [============================>.] - ETA: 0s - loss: 0.1013 - accuracy: 0.9535
# Epoch 133: val_accuracy did not improve from 0.94427
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1012 - accuracy: 0.9534 - val_loss: 0.1364 - val_accuracy: 0.9421
# Epoch 134/289
# 4181/4185 [============================>.] - ETA: 0s - loss: 0.1011 - accuracy: 0.9535
# Epoch 134: val_accuracy did not improve from 0.94427
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.1010 - accuracy: 0.9535 - val_loss: 0.1416 - val_accuracy: 0.9431
# Epoch 135/289
# 4174/4185 [============================>.] - ETA: 0s - loss: 0.1011 - accuracy: 0.9537
# Epoch 135: val_accuracy did not improve from 0.94427
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1011 - accuracy: 0.9537 - val_loss: 0.1375 - val_accuracy: 0.9415
# Epoch 136/289
# 4178/4185 [============================>.] - ETA: 0s - loss: 0.1005 - accuracy: 0.9534
# Epoch 136: val_accuracy did not improve from 0.94427
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1004 - accuracy: 0.9534 - val_loss: 0.1398 - val_accuracy: 0.9426
# Epoch 137/289
# 4176/4185 [============================>.] - ETA: 0s - loss: 0.1019 - accuracy: 0.9532
# Epoch 137: val_accuracy did not improve from 0.94427
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1019 - accuracy: 0.9532 - val_loss: 0.1366 - val_accuracy: 0.9429
# Epoch 138/289
# 4176/4185 [============================>.] - ETA: 0s - loss: 0.1004 - accuracy: 0.9543
# Epoch 138: val_accuracy did not improve from 0.94427
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.1003 - accuracy: 0.9543 - val_loss: 0.1435 - val_accuracy: 0.9441
# Epoch 139/289
# 4185/4185 [==============================] - ETA: 0s - loss: 0.0995 - accuracy: 0.9543
# Epoch 139: val_accuracy did not improve from 0.94427
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.0995 - accuracy: 0.9543 - val_loss: 0.1387 - val_accuracy: 0.9414
# Epoch 140/289
# 4170/4185 [============================>.] - ETA: 0s - loss: 0.1006 - accuracy: 0.9543
# Epoch 140: val_accuracy did not improve from 0.94427
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1005 - accuracy: 0.9543 - val_loss: 0.1429 - val_accuracy: 0.9428
# Epoch 141/289
# 4180/4185 [============================>.] - ETA: 0s - loss: 0.1000 - accuracy: 0.9546
# Epoch 141: val_accuracy improved from 0.94427 to 0.94430, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.1000 - accuracy: 0.9546 - val_loss: 0.1419 - val_accuracy: 0.9443
# Epoch 142/289
# 4173/4185 [============================>.] - ETA: 0s - loss: 0.0993 - accuracy: 0.9540
# Epoch 142: val_accuracy did not improve from 0.94430
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.0993 - accuracy: 0.9540 - val_loss: 0.1362 - val_accuracy: 0.9414
# Epoch 143/289
# 4181/4185 [============================>.] - ETA: 0s - loss: 0.0993 - accuracy: 0.9543
# Epoch 143: val_accuracy did not improve from 0.94430
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.0993 - accuracy: 0.9543 - val_loss: 0.1424 - val_accuracy: 0.9416
# Epoch 144/289
# 4177/4185 [============================>.] - ETA: 0s - loss: 0.0990 - accuracy: 0.9545
# Epoch 144: val_accuracy did not improve from 0.94430
# 4185/4185 [==============================] - 15s 4ms/step - loss: 0.0989 - accuracy: 0.9545 - val_loss: 0.1400 - val_accuracy: 0.9425
# Epoch 145/289
# 4173/4185 [============================>.] - ETA: 0s - loss: 0.0993 - accuracy: 0.9545
# Epoch 145: val_accuracy did not improve from 0.94430
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.0993 - accuracy: 0.9544 - val_loss: 0.1367 - val_accuracy: 0.9429
# Epoch 146/289
# 4180/4185 [============================>.] - ETA: 0s - loss: 0.0986 - accuracy: 0.9547
# Epoch 146: val_accuracy did not improve from 0.94430
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.0985 - accuracy: 0.9547 - val_loss: 0.1430 - val_accuracy: 0.9431
# Epoch 147/289
# 4172/4185 [============================>.] - ETA: 0s - loss: 0.0990 - accuracy: 0.9548
# Epoch 147: val_accuracy did not improve from 0.94430
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.0990 - accuracy: 0.9548 - val_loss: 0.1421 - val_accuracy: 0.9438
# Epoch 148/289
# 4180/4185 [============================>.] - ETA: 0s - loss: 0.0981 - accuracy: 0.9555
# Epoch 148: val_accuracy did not improve from 0.94430
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.0980 - accuracy: 0.9555 - val_loss: 0.1458 - val_accuracy: 0.9405
# Epoch 149/289
# 4173/4185 [============================>.] - ETA: 0s - loss: 0.0993 - accuracy: 0.9541
# Epoch 149: val_accuracy did not improve from 0.94430
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.0992 - accuracy: 0.9541 - val_loss: 0.1417 - val_accuracy: 0.9428
# Epoch 150/289
# 4179/4185 [============================>.] - ETA: 0s - loss: 0.0986 - accuracy: 0.9552
# Epoch 150: val_accuracy did not improve from 0.94430
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.0987 - accuracy: 0.9552 - val_loss: 0.1414 - val_accuracy: 0.9429
# Epoch 151/289
# 4185/4185 [==============================] - ETA: 0s - loss: 0.0979 - accuracy: 0.9559
# Epoch 151: val_accuracy improved from 0.94430 to 0.94465, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.0979 - accuracy: 0.9559 - val_loss: 0.1454 - val_accuracy: 0.9447
# Epoch 152/289
# 4177/4185 [============================>.] - ETA: 0s - loss: 0.0987 - accuracy: 0.9552
# Epoch 152: val_accuracy did not improve from 0.94465
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.0987 - accuracy: 0.9553 - val_loss: 0.1378 - val_accuracy: 0.9424
# Epoch 153/289
# 4177/4185 [============================>.] - ETA: 0s - loss: 0.0983 - accuracy: 0.9548
# Epoch 153: val_accuracy did not improve from 0.94465
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.0983 - accuracy: 0.9548 - val_loss: 0.1468 - val_accuracy: 0.9415
# Epoch 154/289
# 4178/4185 [============================>.] - ETA: 0s - loss: 0.0970 - accuracy: 0.9555
# Epoch 154: val_accuracy did not improve from 0.94465
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.0971 - accuracy: 0.9555 - val_loss: 0.1390 - val_accuracy: 0.9439
# Epoch 155/289
# 4183/4185 [============================>.] - ETA: 0s - loss: 0.0968 - accuracy: 0.9559
# Epoch 155: val_accuracy did not improve from 0.94465
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.0969 - accuracy: 0.9559 - val_loss: 0.1409 - val_accuracy: 0.9435
# Epoch 156/289
# 4184/4185 [============================>.] - ETA: 0s - loss: 0.0967 - accuracy: 0.9561
# Epoch 156: val_accuracy did not improve from 0.94465
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.0967 - accuracy: 0.9561 - val_loss: 0.1409 - val_accuracy: 0.9430
# Epoch 157/289
# 4176/4185 [============================>.] - ETA: 0s - loss: 0.0967 - accuracy: 0.9560
# Epoch 157: val_accuracy did not improve from 0.94465
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.0967 - accuracy: 0.9560 - val_loss: 0.1398 - val_accuracy: 0.9436
# Epoch 158/289
# 4177/4185 [============================>.] - ETA: 0s - loss: 0.0968 - accuracy: 0.9558
# Epoch 158: val_accuracy did not improve from 0.94465
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.0968 - accuracy: 0.9558 - val_loss: 0.1415 - val_accuracy: 0.9441
# Epoch 159/289
# ...
# Epoch 236/289
# 4179/4185 [============================>.] - ETA: 0s - loss: 0.0877 - accuracy: 0.9603
# Epoch 236: val_accuracy improved from 0.94657 to 0.94728, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.0877 - accuracy: 0.9603 - val_loss: 0.1439 - val_accuracy: 0.9473
# Epoch 237/289
# 4172/4185 [============================>.] - ETA: 0s - loss: 0.0876 - accuracy: 0.9604
# Epoch 237: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.0877 - accuracy: 0.9603 - val_loss: 0.1443 - val_accuracy: 0.9429
# Epoch 238/289
# 4182/4185 [============================>.] - ETA: 0s - loss: 0.0873 - accuracy: 0.9610
# Epoch 238: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.0873 - accuracy: 0.9610 - val_loss: 0.1592 - val_accuracy: 0.9436
# Epoch 239/289
# 4176/4185 [============================>.] - ETA: 0s - loss: 0.0862 - accuracy: 0.9608
# Epoch 239: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.0862 - accuracy: 0.9608 - val_loss: 0.1500 - val_accuracy: 0.9454
# Epoch 240/289
# 4174/4185 [============================>.] - ETA: 0s - loss: 0.0858 - accuracy: 0.9613
# Epoch 240: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.0859 - accuracy: 0.9613 - val_loss: 0.1434 - val_accuracy: 0.9457
# Epoch 241/289
# 4176/4185 [============================>.] - ETA: 0s - loss: 0.0855 - accuracy: 0.9615
# Epoch 241: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.0855 - accuracy: 0.9615 - val_loss: 0.1450 - val_accuracy: 0.9459
# Epoch 242/289
# 4184/4185 [============================>.] - ETA: 0s - loss: 0.0872 - accuracy: 0.9603
# Epoch 242: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.0872 - accuracy: 0.9603 - val_loss: 0.1466 - val_accuracy: 0.9472
# Epoch 243/289
# 4181/4185 [============================>.] - ETA: 0s - loss: 0.0862 - accuracy: 0.9609
# Epoch 243: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.0861 - accuracy: 0.9610 - val_loss: 0.1470 - val_accuracy: 0.9448
# Epoch 244/289
# 4182/4185 [============================>.] - ETA: 0s - loss: 0.0857 - accuracy: 0.9619
# Epoch 244: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.0857 - accuracy: 0.9620 - val_loss: 0.1484 - val_accuracy: 0.9438
# Epoch 245/289
# 4181/4185 [============================>.] - ETA: 0s - loss: 0.0863 - accuracy: 0.9616
# Epoch 245: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.0863 - accuracy: 0.9616 - val_loss: 0.1519 - val_accuracy: 0.9456
# Epoch 246/289
# 4177/4185 [============================>.] - ETA: 0s - loss: 0.0855 - accuracy: 0.9616
# Epoch 246: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.0855 - accuracy: 0.9616 - val_loss: 0.1426 - val_accuracy: 0.9466
# Epoch 247/289
# 4181/4185 [============================>.] - ETA: 0s - loss: 0.0848 - accuracy: 0.9618
# Epoch 247: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.0848 - accuracy: 0.9618 - val_loss: 0.1434 - val_accuracy: 0.9438
# Epoch 248/289
# 4184/4185 [============================>.] - ETA: 0s - loss: 0.0868 - accuracy: 0.9608
# Epoch 248: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 19s 5ms/step - loss: 0.0868 - accuracy: 0.9608 - val_loss: 0.1545 - val_accuracy: 0.9455
# Epoch 249/289
# 4178/4185 [============================>.] - ETA: 0s - loss: 0.0848 - accuracy: 0.9621
# Epoch 249: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.0848 - accuracy: 0.9620 - val_loss: 0.1494 - val_accuracy: 0.9455
# Epoch 250/289
# 4183/4185 [============================>.] - ETA: 0s - loss: 0.0857 - accuracy: 0.9610
# Epoch 250: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.0857 - accuracy: 0.9610 - val_loss: 0.1433 - val_accuracy: 0.9467
# Epoch 251/289
# 4176/4185 [============================>.] - ETA: 0s - loss: 0.0846 - accuracy: 0.9618
# Epoch 251: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.0847 - accuracy: 0.9618 - val_loss: 0.1412 - val_accuracy: 0.9457
# Epoch 252/289
# 4183/4185 [============================>.] - ETA: 0s - loss: 0.0843 - accuracy: 0.9619
# Epoch 252: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.0843 - accuracy: 0.9619 - val_loss: 0.1598 - val_accuracy: 0.9460
# Epoch 253/289
# 4180/4185 [============================>.] - ETA: 0s - loss: 0.0853 - accuracy: 0.9615
# Epoch 253: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.0853 - accuracy: 0.9616 - val_loss: 0.1535 - val_accuracy: 0.9453
# Epoch 254/289
# 4179/4185 [============================>.] - ETA: 0s - loss: 0.0834 - accuracy: 0.9623
# Epoch 254: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.0834 - accuracy: 0.9623 - val_loss: 0.1496 - val_accuracy: 0.9460
# Epoch 255/289
# 4174/4185 [============================>.] - ETA: 0s - loss: 0.0848 - accuracy: 0.9617
# Epoch 255: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.0848 - accuracy: 0.9617 - val_loss: 0.1432 - val_accuracy: 0.9455
# Epoch 256/289
# 4178/4185 [============================>.] - ETA: 0s - loss: 0.0841 - accuracy: 0.9621
# Epoch 256: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.0841 - accuracy: 0.9621 - val_loss: 0.1459 - val_accuracy: 0.9461
# Epoch 257/289
# 4185/4185 [==============================] - ETA: 0s - loss: 0.0832 - accuracy: 0.9626
# Epoch 257: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 19s 4ms/step - loss: 0.0832 - accuracy: 0.9626 - val_loss: 0.1407 - val_accuracy: 0.9459
# Epoch 258/289
# 4176/4185 [============================>.] - ETA: 0s - loss: 0.0847 - accuracy: 0.9620
# Epoch 258: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.0847 - accuracy: 0.9620 - val_loss: 0.1434 - val_accuracy: 0.9448
# Epoch 259/289
# 4179/4185 [============================>.] - ETA: 0s - loss: 0.0846 - accuracy: 0.9623
# Epoch 259: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.0846 - accuracy: 0.9623 - val_loss: 0.1487 - val_accuracy: 0.9464
# Epoch 260/289
# 4182/4185 [============================>.] - ETA: 0s - loss: 0.0842 - accuracy: 0.9619
# Epoch 260: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.0842 - accuracy: 0.9619 - val_loss: 0.1469 - val_accuracy: 0.9456
# Epoch 261/289
# 4184/4185 [============================>.] - ETA: 0s - loss: 0.0850 - accuracy: 0.9621
# Epoch 261: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.0850 - accuracy: 0.9621 - val_loss: 0.1460 - val_accuracy: 0.9451
# Epoch 262/289
# 4175/4185 [============================>.] - ETA: 0s - loss: 0.0859 - accuracy: 0.9618
# Epoch 262: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.0858 - accuracy: 0.9618 - val_loss: 0.1499 - val_accuracy: 0.9467
# Epoch 263/289
# 4180/4185 [============================>.] - ETA: 0s - loss: 0.0851 - accuracy: 0.9617
# Epoch 263: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.0851 - accuracy: 0.9617 - val_loss: 0.1488 - val_accuracy: 0.9456
# Epoch 264/289
# 4180/4185 [============================>.] - ETA: 0s - loss: 0.0841 - accuracy: 0.9620
# Epoch 264: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.0842 - accuracy: 0.9620 - val_loss: 0.1516 - val_accuracy: 0.9466
# Epoch 265/289
# 4182/4185 [============================>.] - ETA: 0s - loss: 0.0839 - accuracy: 0.9618
# Epoch 265: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.0839 - accuracy: 0.9618 - val_loss: 0.1513 - val_accuracy: 0.9438
# Epoch 266/289
# 4182/4185 [============================>.] - ETA: 0s - loss: 0.0850 - accuracy: 0.9614
# Epoch 266: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.0851 - accuracy: 0.9613 - val_loss: 0.1415 - val_accuracy: 0.9452
# Epoch 267/289
# 4177/4185 [============================>.] - ETA: 0s - loss: 0.0835 - accuracy: 0.9619
# Epoch 267: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.0835 - accuracy: 0.9619 - val_loss: 0.1470 - val_accuracy: 0.9447
# Epoch 268/289
# 4177/4185 [============================>.] - ETA: 0s - loss: 0.0838 - accuracy: 0.9624
# Epoch 268: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 19s 4ms/step - loss: 0.0838 - accuracy: 0.9624 - val_loss: 0.1471 - val_accuracy: 0.9468
# Epoch 269/289
# 4182/4185 [============================>.] - ETA: 0s - loss: 0.0845 - accuracy: 0.9624
# Epoch 269: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.0845 - accuracy: 0.9624 - val_loss: 0.1588 - val_accuracy: 0.9446
# Epoch 270/289
# 4183/4185 [============================>.] - ETA: 0s - loss: 0.0839 - accuracy: 0.9623
# Epoch 270: val_accuracy did not improve from 0.94728
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.0839 - accuracy: 0.9623 - val_loss: 0.1422 - val_accuracy: 0.9451
# Epoch 271/289
# 4183/4185 [============================>.] - ETA: 0s - loss: 0.0838 - accuracy: 0.9623
# Epoch 271: val_accuracy improved from 0.94728 to 0.94734, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.0838 - accuracy: 0.9624 - val_loss: 0.1485 - val_accuracy: 0.9473
# Epoch 272/289
# 4178/4185 [============================>.] - ETA: 0s - loss: 0.0833 - accuracy: 0.9629
# Epoch 272: val_accuracy improved from 0.94734 to 0.94746, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 19s 5ms/step - loss: 0.0833 - accuracy: 0.9629 - val_loss: 0.1486 - val_accuracy: 0.9475
# Epoch 273/289
# 4179/4185 [============================>.] - ETA: 0s - loss: 0.0841 - accuracy: 0.9624
# Epoch 273: val_accuracy improved from 0.94746 to 0.94776, saving model to /content/drive/MyDrive/ANN_Edge/unsw_data/final4/models/deep_model_ANN5_hp.keras
# 4185/4185 [==============================] - 19s 5ms/step - loss: 0.0841 - accuracy: 0.9624 - val_loss: 0.1495 - val_accuracy: 0.9478
# Epoch 274/289
# 4171/4185 [============================>.] - ETA: 0s - loss: 0.0828 - accuracy: 0.9630
# Epoch 274: val_accuracy did not improve from 0.94776
# 4185/4185 [==============================] - 19s 5ms/step - loss: 0.0828 - accuracy: 0.9630 - val_loss: 0.1482 - val_accuracy: 0.9445
# Epoch 275/289
# 4178/4185 [============================>.] - ETA: 0s - loss: 0.0821 - accuracy: 0.9633
# Epoch 275: val_accuracy did not improve from 0.94776
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.0821 - accuracy: 0.9632 - val_loss: 0.1485 - val_accuracy: 0.9449
# Epoch 276/289
# 4179/4185 [============================>.] - ETA: 0s - loss: 0.0826 - accuracy: 0.9626
# Epoch 276: val_accuracy did not improve from 0.94776
# 4185/4185 [==============================] - 19s 4ms/step - loss: 0.0827 - accuracy: 0.9626 - val_loss: 0.1407 - val_accuracy: 0.9469
# Epoch 277/289
# 4180/4185 [============================>.] - ETA: 0s - loss: 0.0822 - accuracy: 0.9634
# Epoch 277: val_accuracy did not improve from 0.94776
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.0822 - accuracy: 0.9634 - val_loss: 0.1475 - val_accuracy: 0.9466
# Epoch 278/289
# 4177/4185 [============================>.] - ETA: 0s - loss: 0.0826 - accuracy: 0.9633
# Epoch 278: val_accuracy did not improve from 0.94776
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.0826 - accuracy: 0.9633 - val_loss: 0.1439 - val_accuracy: 0.9450
# Epoch 279/289
# 4184/4185 [============================>.] - ETA: 0s - loss: 0.0817 - accuracy: 0.9632
# Epoch 279: val_accuracy did not improve from 0.94776
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.0817 - accuracy: 0.9632 - val_loss: 0.1489 - val_accuracy: 0.9455
# Epoch 280/289
# 4180/4185 [============================>.] - ETA: 0s - loss: 0.0826 - accuracy: 0.9628
# Epoch 280: val_accuracy did not improve from 0.94776
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.0827 - accuracy: 0.9628 - val_loss: 0.1433 - val_accuracy: 0.9450
# Epoch 281/289
# 4179/4185 [============================>.] - ETA: 0s - loss: 0.0820 - accuracy: 0.9632
# Epoch 281: val_accuracy did not improve from 0.94776
# 4185/4185 [==============================] - 19s 4ms/step - loss: 0.0819 - accuracy: 0.9632 - val_loss: 0.1556 - val_accuracy: 0.9459
# Epoch 282/289
# 4173/4185 [============================>.] - ETA: 0s - loss: 0.0833 - accuracy: 0.9623
# Epoch 282: val_accuracy did not improve from 0.94776
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.0833 - accuracy: 0.9623 - val_loss: 0.1473 - val_accuracy: 0.9454
# Epoch 283/289
# 4176/4185 [============================>.] - ETA: 0s - loss: 0.0820 - accuracy: 0.9636
# Epoch 283: val_accuracy did not improve from 0.94776
# 4185/4185 [==============================] - 17s 4ms/step - loss: 0.0822 - accuracy: 0.9635 - val_loss: 0.1514 - val_accuracy: 0.9443
# Epoch 284/289
# 4182/4185 [============================>.] - ETA: 0s - loss: 0.0821 - accuracy: 0.9635
# Epoch 284: val_accuracy did not improve from 0.94776
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.0820 - accuracy: 0.9635 - val_loss: 0.1451 - val_accuracy: 0.9445
# Epoch 285/289
# 4184/4185 [============================>.] - ETA: 0s - loss: 0.0813 - accuracy: 0.9638
# Epoch 285: val_accuracy did not improve from 0.94776
# 4185/4185 [==============================] - 16s 4ms/step - loss: 0.0813 - accuracy: 0.9637 - val_loss: 0.1510 - val_accuracy: 0.9461
# Epoch 286/289
# 4182/4185 [============================>.] - ETA: 0s - loss: 0.0824 - accuracy: 0.9628
# Epoch 286: val_accuracy did not improve from 0.94776
# 4185/4185 [==============================] - 19s 5ms/step - loss: 0.0824 - accuracy: 0.9628 - val_loss: 0.1358 - val_accuracy: 0.9456
# Epoch 287/289
# 4185/4185 [==============================] - ETA: 0s - loss: 0.0821 - accuracy: 0.9635
# Epoch 287: val_accuracy did not improve from 0.94776
# 4185/4185 [==============================] - 19s 4ms/step - loss: 0.0821 - accuracy: 0.9635 - val_loss: 0.1539 - val_accuracy: 0.9469
# Epoch 288/289
# 4181/4185 [============================>.] - ETA: 0s - loss: 0.0814 - accuracy: 0.9637
# Epoch 288: val_accuracy did not improve from 0.94776
# 4185/4185 [==============================] - 19s 4ms/step - loss: 0.0814 - accuracy: 0.9637 - val_loss: 0.1469 - val_accuracy: 0.9470
# Epoch 289/289
# 4182/4185 [============================>.] - ETA: 0s - loss: 0.0816 - accuracy: 0.9634
# Epoch 289: val_accuracy did not improve from 0.94776
# 4185/4185 [==============================] - 18s 4ms/step - loss: 0.0816 - accuracy: 0.9634 - val_loss: 0.1466 - val_accuracy: 0.9452

# %%
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import load_model, Model

best_model =load_model(checkpoint_filepath)

# Display the summary of the loaded model
best_model.summary()

# Plot the architecture of the loaded model
plot_model(best_model, to_file='deep_model_best_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 256)               5376
#
#  dense_25 (Dense)            (None, 128)               32896
#
#  dropout_12 (Dropout)        (None, 128)               0
#
#  dense_26 (Dense)            (None, 64)                8256
#
#  dropout_13 (Dropout)        (None, 64)                0
#
#  dense_27 (Dense)            (None, 32)                2080
#
#  dropout_14 (Dropout)        (None, 32)                0
#
#  dense_28 (Dense)            (None, 16)                528
#
#  dropout_15 (Dropout)        (None, 16)                0
#
#  dense_29 (Dense)            (None, 8)                 136
#
#  dropout_16 (Dropout)        (None, 8)                 0
#
#  dense_30 (Dense)            (None, 4)                 36
#
#  dropout_17 (Dropout)        (None, 4)                 0
#
#  dense_31 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 49313 (192.63 KB)
# Trainable params: 49313 (192.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Testing Deep Model

# %%
import psutil
import time
from keras.models import load_model
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, average_precision_score
import tensorflow as tf

# Load the saved model
saved_model = load_model(checkpoint_filepath)

# Measure CPU and memory usage before prediction
cpu_usage_before = psutil.cpu_percent()
memory_usage_before = psutil.virtual_memory().used

# Record start time for prediction
start_time = time.time()

# Assuming X_test and y_test are your test data
# Predict on the test data
y_pred = saved_model.predict(X_test)

# Convert predicted probabilities to binary predictions (0 or 1)
y_pred_classes = (y_pred > 0.5).astype(int)

# Record end time for prediction
end_time = time.time()

# Measure CPU and memory usage after prediction
cpu_usage_after = psutil.cpu_percent()
memory_usage_after = psutil.virtual_memory().used

# Calculate prediction time
prediction_time = end_time - start_time

# Calculate performance metrics
accuracy = accuracy_score(y_test, y_pred_classes)
precision = precision_score(y_test, y_pred_classes)
recall = recall_score(y_test, y_pred_classes)
f1 = f1_score(y_test, y_pred_classes)
roc_auc = roc_auc_score(y_test, y_pred)
avg_precision = average_precision_score(y_test, y_pred)

# Compute confusion matrix
confusion_matrix = tf.math.confusion_matrix(y_test, y_pred_classes).numpy()

# Print performance metrics
print("Test Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("ROC AUC Score:", roc_auc)
print("Average Precision:", avg_precision)
print("Confusion Matrix:\n", confusion_matrix)

# Print CPU and memory usage, and prediction time
print("CPU usage before prediction:", cpu_usage_before)
print("Memory usage before prediction:", memory_usage_before)
print("CPU usage after prediction:", cpu_usage_after)
print("Memory usage after prediction:", memory_usage_after)
print("Prediction time:", prediction_time)
# Out:
# 291/291 [==============================] - 1s 1ms/step
# Test Accuracy: 0.9491397849462365
# Precision: 0.9597182478538411
# Recall: 0.9376344086021505
# F1 Score: 0.94854780811487
# ROC AUC Score: 0.9906023124060584
# Average Precision: 0.9906479529725836
# Confusion Matrix:
#  [[4467  183]
#  [ 290 4360]]
# CPU usage before prediction: 75.9
# Memory usage before prediction: 2463367168
# CPU usage after prediction: 56.1
# Memory usage after prediction: 2463367168
# Prediction time: 0.7799091339111328

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

# Calculate ROC curve
fpr, tpr, thresholds_roc = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Calculate Precision-Recall curve
precision, recall, thresholds_pr = precision_recall_curve(y_test, y_pred)
average_precision = average_precision_score(y_test, y_pred)

# Plot ROC curve and Precision-Recall curve as subplots
plt.figure(figsize=(15, 6))

# Plot ROC curve
plt.subplot(1, 2, 1)
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) - Shallow Model')
plt.legend(loc="lower right")

# Plot Precision-Recall curve
plt.subplot(1, 2, 2)
plt.plot(recall, precision, color='blue', lw=2, label='Precision-Recall curve (AP = %0.2f)' % average_precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Deep Model Validation

# %%
import psutil
import time
import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, average_precision_score
import tensorflow as tf
from keras.models import load_model

# Load the best model saved by ModelCheckpoint
best_model = load_model(checkpoint_filepath)

# Measure CPU and memory usage before validation
cpu_usage_before = psutil.cpu_percent()
memory_usage_before = psutil.virtual_memory().used

# Record start time for validation
start_time = time.time()

# Validate the loaded best model using validation data
evaluation = best_model.evaluate(X_val, y_val)

# Record end time for validation
end_time = time.time()

# Measure CPU and memory usage after validation
cpu_usage_after = psutil.cpu_percent()
memory_usage_after = psutil.virtual_memory().used

# Calculate validation time
validation_time = end_time - start_time

# Print the evaluation metrics
print("Validation Loss:", evaluation[0])
print("Validation Accuracy:", evaluation[1])

# Assuming y_pred is the predicted probabilities and y_pred_classes are the predicted classes
y_pred = best_model.predict(X_val)
y_pred_classes = np.round(y_pred)

# Compute additional performance metrics
precision = precision_score(y_val, y_pred_classes)
recall = recall_score(y_val, y_pred_classes)
f1 = f1_score(y_val, y_pred_classes)
roc_auc = roc_auc_score(y_val, y_pred)
avg_precision = average_precision_score(y_val, y_pred)

# Compute confusion matrix
confusion_matrix = tf.math.confusion_matrix(y_val, y_pred_classes).numpy()

# Print additional performance metrics
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("ROC AUC Score:", roc_auc)
print("Average Precision:", avg_precision)
print("Confusion Matrix:\n", confusion_matrix)

# Print CPU and memory usage, and validation time
print("CPU usage before validation:", cpu_usage_before)
print("Memory usage before validation:", memory_usage_before)
print("CPU usage after validation:", cpu_usage_after)
print("Memory usage after validation:", memory_usage_after)
print("Validation time:", validation_time)
# Out:
# 291/291 [==============================] - 1s 3ms/step - loss: 0.1481 - accuracy: 0.9471
# Validation Loss: 0.14811763167381287
# Validation Accuracy: 0.9470967650413513
# 291/291 [==============================] - 1s 2ms/step
# Precision: 0.9607712765957447
# Recall: 0.932258064516129
# F1 Score: 0.9462999345121154
# ROC AUC Score: 0.9899553243149497
# Average Precision: 0.989937981248856
# Confusion Matrix:
#  [[4473  177]
#  [ 315 4335]]
# CPU usage before validation: 42.4
# Memory usage before validation: 2537295872
# CPU usage after validation: 98.5
# Memory usage after validation: 2510188544
# Validation time: 1.345862865447998

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

# Calculate ROC curve
fpr, tpr, thresholds_roc = roc_curve(y_val, y_pred)
roc_auc = auc(fpr, tpr)

# Calculate Precision-Recall curve
precision, recall, thresholds_pr = precision_recall_curve(y_val, y_pred)
average_precision = average_precision_score(y_val, y_pred)

# Plot ROC curve and Precision-Recall curve as subplots
plt.figure(figsize=(15, 6))

# Plot ROC curve
plt.subplot(1, 2, 1)
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) - Shallow Model')
plt.legend(loc="lower right")

# Plot Precision-Recall curve
plt.subplot(1, 2, 2)
plt.plot(recall, precision, color='blue', lw=2, label='Precision-Recall curve (AP = %0.2f)' % average_precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

plt.tight_layout()
plt.show()

# %%
import datetime

# Get the current datetime
current_datetime = datetime.datetime.now()

# Add a time delta (5 hours and 30 minutes)
time_delta = datetime.timedelta(hours=5, minutes=30)
updated_datetime = current_datetime + time_delta

# Format the updated datetime
formatted_datetime = updated_datetime.strftime("%Y-%m-%d %H:%M:%S")
print("Updated Datetime:", formatted_datetime)
# Out:
# Updated Datetime: 2024-04-05 02:38:46

# %% [markdown]
# ## Save Hyperparameters 25

# %%
# Convert hp_array to DataFrame
df = pd.DataFrame(hp_array)
print(df)
# Save DataFrame to CSV
df.to_csv(f_hp_data, index=False)
print (f_hp_data, "saved")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-3bef2338ed2f> in <cell line: 2>()
#       1 # Convert hp_array to DataFrame
# ----> 2 df = pd.DataFrame(hp_array)
#       3 print(df)
#       4 # Save DataFrame to CSV
#       5 df.to_csv(f_hp_data, index=False)
#
# NameError: name 'hp_array' is not defined
